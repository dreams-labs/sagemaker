# %% [markdown]
# ### start

# %%
# pyright: reportMissingImports=false
# pyright: reportMissingModuleSource=false

import uuid
import random
import hashlib
import os
import sys
import gc
import time
import copy
import logging
import re
from itertools import chain,combinations
import pdb
import math
from pathlib import Path
import pickle
import cloudpickle
import datetime
from datetime import datetime,timedelta
import json
import warnings
import yaml
from typing import Dict,Union,List,Any,Tuple
import pytest
import importlib
from dotenv import load_dotenv
import pandas as pd
import numpy as np
import IPython
import requests
import warnings
import boto3
import matplotlib as plt

# load_dotenv(Path("../../../Local/.env"))

# Custom format function for displaying |numbers/
pd.set_option('display.float_format', lambda x: f'{x:.12g}')
# pd.reset_option('display.float_format')

# Suppress warnings
os.environ['PYDEVD_DISABLE_FILE_VALIDATION'] = '1'
warnings.filterwarnings('ignore', message='.*frozen modules.*')
warnings.filterwarnings("ignore", message="MallocStackLogging")

# silence pygame donation request
os.environ['PYGAME_HIDE_SUPPORT_PROMPT'] = "hide"
os.environ['LOGGING_FILE'] = "../../../Local/logs/wallet_modeling.log"
os.environ['NOTIFICATION_SOUNDS_DIR'] = "../../../Local"

# Dark mode charts
plt.rcParams['figure.facecolor'] = '#181818'  # Custom background color (dark gray in this case)
plt.rcParams['axes.facecolor'] = '#181818'
plt.rcParams['text.color'] = '#afc6ba'
plt.rcParams['axes.labelcolor'] = '#afc6ba'
plt.rcParams['xtick.color'] = '#afc6ba'
plt.rcParams['ytick.color'] = '#afc6ba'
plt.rcParams['axes.titlecolor'] = '#afc6ba'
plt.rcParams['text.usetex'] = False
plt.rcParams['mathtext.default'] = 'regular'

import utils as u
# Set the custom error handler
ipython = IPython.get_ipython()
# ipython.set_custom_exc((Exception,), u.notify_on_failure)

player = u.AmbientPlayer()
player.stop_all_players()

# configure logger
logger = u.setup_notebook_logger('../logs/notebook_logs.log')
logger.setLevel(logging.INFO)

# import local modules
# pyright: reportMissingImports=false
sys.path.append('..//src')

import sagemaker_wallets.wallet_modeler as wm
import sagemaker_wallets.wallet_preprocessor as wp
import sagemaker_wallets.workflow_orchestrator as wo
from utils import ConfigError
import utils as u

# reload all modules
modules = [
    wm, wp, wo,
    u
]

from IPython.core import ultratb
ultratb.VerboseTB._tb_highlight = "bg:#b45827"


# load all configs
sage_wallets_config = yaml.safe_load(Path('../config/sage_wallets_config.yaml').read_text(encoding='utf-8'))
sage_wallets_modeling_config = yaml.safe_load(Path('../config/sage_wallets_modeling_config.yaml').read_text(encoding='utf-8'))


u.export_code(
    code_directories=[
        # 'etls',
        'sagemaker_wallets',
    ],
    # include_config = True,
    # ipynb_notebook = 'DDA-769 coin model score dist toggle.ipynb'
)

[importlib.reload(module) for module in modules]
u.notify('retro')

logger.milestone("Good morning, let's get to work")
# Out:
# [15/Jul/25 15:46:15] INFO [utils.export_code:1667] Consolidation complete. All files are saved in temp/consolidated_code.py
# [15/Jul/25 15:46:15] MILESTONE [2965290251.<module>:113] Good morning, let's get to work

# %% [markdown]
# # Initial ETLs

# %% [markdown]
# # Code begins

# %% [markdown]
# ### Initiate orchestrator

# %%
[importlib.reload(module) for module in modules]
sage_wallets_config = yaml.safe_load(Path('../config/sage_wallets_config.yaml').read_text(encoding='utf-8'))
sage_wallets_modeling_config = yaml.safe_load(Path('../config/sage_wallets_modeling_config.yaml').read_text(encoding='utf-8'))


workflow_orch = wo.WalletWorkflowOrchestrator(sage_wallets_config)

# %% [markdown]
# ### Load, preprocess, and upload data

# %% [markdown]
# #### load data

# %%
[importlib.reload(module) for module in modules]
sage_wallets_config = yaml.safe_load(Path('../config/sage_wallets_config.yaml').read_text(encoding='utf-8'))
sage_wallets_modeling_config = yaml.safe_load(Path('../config/sage_wallets_modeling_config.yaml').read_text(encoding='utf-8'))

date_suffixes = [
    '231107',
    '240306'
]
workflow_orch.load_training_data(date_suffixes)
# Out:
# [12/Jul/25 14:33:33] MILESTONE [workflow_orchestrator.load_training_data:91] <PROD> Loading training data for 2 periods: ['231107', '240306']
# [12/Jul/25 14:33:34] INFO [workflow_orchestrator.load_training_data:109] Training data loaded successfully: 8 splits, 398,964 total rows

# %% [markdown]
# ##### inspect features

# %%
# Create combined NaN count and describe statistics
nan_counts = workflow_orch.training_data['x_train'].isna().sum()
describe_stats = workflow_orch.training_data['x_train'].describe().T

# Combine into single DataFrame
combined_stats = pd.concat([
    nan_counts.rename('nan_count'),
    describe_stats
], axis=1).sort_index()

u.display_full(combined_stats.sort_index())
# Out:
#                                                              nan_count count  \
# cluster|k5_cluster_k0                                                0 87727
# cluster|k5_cluster_k1                                                0 87727
# cluster|k5_cluster_k2                                                0 87727
# cluster|k5_cluster_k3                                                0 87727
# cluster|k5_cluster_k4                                                0 87727
# cw_cluster|k5_cluster_k0                                             0 87727
# cw_cluster|k5_cluster_k1                                             0 87727
# cw_cluster|k5_cluster_k2                                             0 87727
# cw_cluster|k5_cluster_k3                                             0 87727
# cw_cluster|k5_cluster_k4                                             0 87727
# cw_coin_trends|current_holders_in_profit_pct|w1                      0 87727
# cw_coin_trends|current_holders_in_profit_pct|w2                   5012 82715
# cw_coin_trends|current_holders_in_profit_pct|w3                   9185 78542
# cw_coin_trends|current_holders_in_profit_pct|w4                  18826 68901
# cw_coin_trends|current_holders_in_profit|w1                          0 87727
# cw_coin_trends|current_holders_in_profit|w2                       5012 82715
# cw_coin_trends|current_holders_in_profit|w3                       9185 78542
# cw_coin_trends|current_holders_in_profit|w4                      18826 68901
# cw_coin_trends|current_holders_pct_of_lifetime|w1                    0 87727
# cw_coin_trends|current_holders_pct_of_lifetime|w2                 5012 82715
# cw_coin_trends|current_holders_pct_of_lifetime|w3                 9185 78542
# cw_coin_trends|current_holders_pct_of_lifetime|w4                18826 68901
# cw_coin_trends|current_holders|w1                                    0 87727
# cw_coin_trends|current_holders|w2                                 5012 82715
# cw_coin_trends|current_holders|w3                                 9185 78542
# cw_coin_trends|current_holders|w4                                18826 68901
# cw_coin_trends|days_since_ath|w1                                     0 87727
# cw_coin_trends|days_since_ath|w2                                  5012 82715
# cw_coin_trends|days_since_ath|w3                                  9185 78542
# cw_coin_trends|days_since_ath|w4                                 18826 68901
# cw_coin_trends|days_since_launch|w1                                  0 87727
# cw_coin_trends|days_since_launch|w2                               5012 82715
# cw_coin_trends|days_since_launch|w3                               9185 78542
# cw_coin_trends|days_since_launch|w4                              18826 68901
# cw_coin_trends|lifetime_holders|w1                                   0 87727
# cw_coin_trends|lifetime_holders|w2                                5012 82715
# cw_coin_trends|lifetime_holders|w3                                9185 78542
# cw_coin_trends|lifetime_holders|w4                               18826 68901
# cw_coin_trends|price_pct_of_ath|w1                                   0 87727
# cw_coin_trends|price_pct_of_ath|w2                                5012 82715
# cw_coin_trends|price_pct_of_ath|w3                                9185 78542
# cw_coin_trends|price_pct_of_ath|w4                               18826 68901
# cw_mktcap|end_portfolio_wtd_market_cap/market_cap_filled|w1          0 87727
# cw_mktcap|end_portfolio_wtd_market_cap/market_cap_filled|w2      41251 46476
# cw_mktcap|end_portfolio_wtd_market_cap/market_cap_filled|w3      54231 33496
# cw_mktcap|end_portfolio_wtd_market_cap/market_cap_unadj|w1           0 87727
# cw_mktcap|end_portfolio_wtd_market_cap/market_cap_unadj|w2       42961 44766
# cw_mktcap|end_portfolio_wtd_market_cap/market_cap_unadj|w3       55832 31895
# cw_performance|crypto_net_gain/crypto_inflows/winsorized|w1          0 87727
# cw_performance|crypto_net_gain/crypto_inflows/winsorized|w2      35665 52062
# cw_performance|crypto_net_gain/crypto_inflows/winsorized|w3      49235 38492
# cw_performance|crypto_net_gain/crypto_inflows/winsorized|w4      63850 23877
# cw_scenario|ideal/relative_cash_buys/pct_rank|w1                     0 87727
# cw_scenario|ideal/relative_cash_buys/pct_rank|w2                 35665 52062
# cw_scenario|ideal/relative_cash_buys/pct_rank|w3                 49235 38492
# cw_scenario|ideal/relative_cash_buys/pct_rank|w4                 63850 23877
# cw_scenario|ideal/relative_cash_buys/pct|w1                          0 87727
# cw_scenario|ideal/relative_cash_buys/pct|w2                      35665 52062
# cw_scenario|ideal/relative_cash_buys/pct|w3                      49235 38492
# cw_scenario|ideal/relative_cash_buys/pct|w4                      63850 23877
# cw_scenario|ideal/relative_combined/pct|w1                           0 87727
# cw_scenario|ideal/relative_combined/pct|w2                       35665 52062
# cw_scenario|ideal/relative_combined/pct|w3                       49235 38492
# cw_scenario|ideal/relative_combined/pct|w4                       63850 23877
# cw_scenario|ideal/relative_net_gain_max_inv/winsorized|w1            0 87727
# cw_scenario|ideal/relative_net_gain_max_inv/winsorized|w2        35665 52062
# cw_scenario|ideal/relative_net_gain_max_inv/winsorized|w3        49235 38492
# cw_scenario|ideal/relative_net_gain_max_inv/winsorized|w4        63850 23877
# cw_scenario|net_perf/relative_cash_buys|w1                           0 87727
# cw_scenario|net_perf/relative_cash_buys|w2                       35665 52062
# cw_scenario|net_perf/relative_cash_buys|w3                       49235 38492
# cw_scenario|net_perf/relative_cash_buys|w4                       63850 23877
# cw_scenario|net_perf/relative_net_gains|w1                           0 87727
# cw_scenario|net_perf/relative_net_gains|w2                       35665 52062
# cw_scenario|net_perf/relative_net_gains|w3                       49235 38492
# cw_scenario|net_perf/relative_net_gains|w4                       63850 23877
# cw_scenario|worst/relative_net_gain_inflows/winsorized|w1            0 87727
# cw_scenario|worst/relative_net_gain_inflows/winsorized|w2        35665 52062
# cw_scenario|worst/relative_net_gain_inflows/winsorized|w3        49235 38492
# cw_scenario|worst/relative_net_gain_inflows/winsorized|w4        63850 23877
# cw_scenario|worst/relative_net_gains|w1                              0 87727
# cw_scenario|worst/relative_net_gains|w2                          35665 52062
# cw_scenario|worst/relative_net_gains|w3                          49235 38492
# cw_scenario|worst/relative_net_gains|w4                          63850 23877
# cw_timing|price_sma_2/lag_15/sell_weighted|w1                        0 87727
# cw_timing|price_sma_2/lag_15/sell_weighted|w2                        0 87727
# cw_timing|price_sma_2/lag_15/sell_weighted|w3                        0 87727
# cw_timing|price_sma_2/lag_15/sell_weighted|w4                        0 87727
# cw_timing|price_sma_2/lead_30/sell_weighted|w3                       0 87727
# cw_timing|price_sma_2/lead_30/sell_weighted|w4                       0 87727
# cw_timing|volume_sma_2/lead_7/buy_weighted|w1                        0 87727
# cw_timing|volume_sma_2/lead_7/buy_weighted|w2                        0 87727
# cw_timing|volume_sma_2/lead_7/buy_weighted|w3                        0 87727
# cw_timing|volume_sma_2/lead_7/buy_weighted|w4                        0 87727
# cw_trading|crypto_cash_sells|w1                                      0 87727
# cw_trading|crypto_cash_sells|w2                                      0 87727
# cw_transfers|buys_coin_age/mean|w1                                   0 87727
# cw_transfers|buys_coin_age/mean|w2                               35873 51854
# cw_transfers|buys_coin_age/mean|w3                               49453 38274
# cw_transfers|buys_coin_age/mean|w4                               64051 23676
# cw_transfers|earlybird_ratio/mean|w1                                 0 87727
# cw_transfers|earlybird_ratio/mean|w2                             35873 51854
# cw_transfers|earlybird_ratio/mean|w3                             49453 38274
# cw_transfers|earlybird_ratio/mean|w4                             64051 23676
# cw_transfers|first_buy/mean_rank|w1                                  0 87727
# cw_transfers|first_buy/mean_rank|w2                              35873 51854
# cw_transfers|first_buy/mean_rank|w3                              49453 38274
# cw_transfers|first_buy/mean_rank|w4                              64051 23676
# cw_transfers|initial_hold_time/mean|w1                               0 87727
# cw_transfers|initial_hold_time/mean|w2                           35873 51854
# cw_transfers|initial_hold_time/mean|w3                           49453 38274
# cw_transfers|initial_hold_time/mean|w4                           64051 23676
# macro|btc_mvrv_z_score_last|w1                                       0 87727
# macro|btc_mvrv_z_score_last|w2                                       0 87727
# macro|btc_mvrv_z_score_last|w3                                       0 87727
# macro|btc_mvrv_z_score_last|w4                                       0 87727
# macro|btc_mvrv_z_score_std|w1                                        0 87727
# macro|btc_mvrv_z_score_std|w2                                        0 87727
# macro|btc_mvrv_z_score_std|w3                                        0 87727
# macro|btc_mvrv_z_score_std|w4                                        0 87727
# macro|btc_price_std|w1                                               0 87727
# macro|btc_price_std|w2                                               0 87727
# macro|btc_price_std|w3                                               0 87727
# macro|btc_price_std|w4                                               0 87727
# macro|btc_vdd_multiple_std|w1                                        0 87727
# macro|btc_vdd_multiple_std|w2                                        0 87727
# macro|btc_vdd_multiple_std|w3                                        0 87727
# macro|btc_vdd_multiple_std|w4                                        0 87727
# macro|global_market_cap_rsi_30_last|w1                               0 87727
# macro|global_market_cap_rsi_30_last|w2                               0 87727
# macro|global_market_cap_rsi_30_last|w3                               0 87727
# macro|global_market_cap_rsi_30_last|w4                               0 87727
# macro|global_market_cap_std|w1                                       0 87727
# macro|global_market_cap_std|w2                                       0 87727
# macro|global_market_cap_std|w3                                       0 87727
# macro|global_market_cap_std|w4                                       0 87727
# macro|gtrends_memecoin_us_std|w1                                     0 87727
# macro|gtrends_memecoin_us_std|w2                                     0 87727
# macro|gtrends_memecoin_us_std|w3                                     0 87727
# macro|gtrends_memecoin_us_std|w4                                     0 87727
# mktcap|end_portfolio_wtd_market_cap/market_cap_filled|w1             0 87727
# mktcap|end_portfolio_wtd_market_cap/market_cap_filled|w2         14312 73415
# mktcap|end_portfolio_wtd_market_cap/market_cap_filled|w3         22440 65287
# mktcap|end_portfolio_wtd_market_cap/market_cap_filled|w4         35753 51974
# performance|crypto_net_gain/crypto_inflows/winsorized|w1             0 87727
# performance|crypto_net_gain/crypto_inflows/winsorized|w2          7641 80086
# performance|crypto_net_gain/crypto_inflows/winsorized|w3         14899 72828
# performance|crypto_net_gain/crypto_inflows/winsorized|w4         28734 58993
# scenario|ideal/relative_cash_buys/pct|w1                             0 87727
# scenario|ideal/relative_cash_buys/pct|w2                          7641 80086
# scenario|ideal/relative_cash_buys/pct|w3                         14899 72828
# scenario|ideal/relative_cash_buys/pct|w4                         28734 58993
# scenario|ideal/relative_combined/pct|w1                              0 87727
# scenario|ideal/relative_combined/pct|w2                           7641 80086
# scenario|ideal/relative_combined/pct|w3                          14899 72828
# scenario|ideal/relative_combined/pct|w4                          28734 58993
# scenario|worst/relative_combined/pct|w1                              0 87727
# scenario|worst/relative_combined/pct|w2                           7641 80086
# scenario|worst/relative_combined/pct|w3                          14899 72828
# scenario|worst/relative_combined/pct|w4                          28734 58993
# scenario|worst/relative_net_gains|w1                                 0 87727
# scenario|worst/relative_net_gains|w2                              7641 80086
# scenario|worst/relative_net_gains|w3                             14899 72828
# scenario|worst/relative_net_gains|w4                             28734 58993
# timing|btc_mvrv_z_score/lag_30/sell_weighted|w1                      0 87727
# timing|btc_mvrv_z_score/lag_30/sell_weighted|w2                      0 87727
# timing|btc_mvrv_z_score/lag_30/sell_weighted|w3                      0 87727
# timing|btc_mvrv_z_score/lag_30/sell_weighted|w4                      0 87727
# timing|btc_mvrv_z_score/lag_90/buy_weighted|w1                       0 87727
# timing|btc_mvrv_z_score/lag_90/buy_weighted|w2                       0 87727
# timing|btc_mvrv_z_score/lag_90/buy_weighted|w3                       0 87727
# timing|btc_mvrv_z_score/lag_90/buy_weighted|w4                       0 87727
# timing|btc_mvrv_z_score/lag_90/sell_weighted|w1                      0 87727
# timing|btc_mvrv_z_score/lag_90/sell_weighted|w2                      0 87727
# timing|btc_mvrv_z_score/lag_90/sell_weighted|w3                      0 87727
# timing|btc_mvrv_z_score/lag_90/sell_weighted|w4                      0 87727
# timing|btc_mvrv_z_score/lead_90/buy_weighted|w4                      0 87727
# timing|gtrends_memecoin_us/lag_15/buy_weighted|w1                    0 87727
# timing|gtrends_memecoin_us/lag_15/buy_weighted|w2                    0 87727
# timing|gtrends_memecoin_us/lag_15/buy_weighted|w3                    0 87727
# timing|gtrends_memecoin_us/lag_15/buy_weighted|w4                    0 87727
# timing|gtrends_memecoin_us/lag_15/sell_weighted|w1                   0 87727
# timing|gtrends_memecoin_us/lag_15/sell_weighted|w2                   0 87727
# timing|gtrends_memecoin_us/lag_15/sell_weighted|w3                   0 87727
# timing|gtrends_memecoin_us/lag_15/sell_weighted|w4                   0 87727
# timing|price_sma_2/lag_15/buy_weighted|w1                            0 87727
# timing|price_sma_2/lag_15/buy_weighted|w2                            0 87727
# timing|price_sma_2/lag_15/buy_weighted|w3                            0 87727
# timing|price_sma_2/lag_15/buy_weighted|w4                            0 87727
# timing|volume_sma_2/lead_7/buy_weighted|w1                           0 87727
# timing|volume_sma_2/lead_7/buy_weighted|w2                           0 87727
# timing|volume_sma_2/lead_7/buy_weighted|w3                           0 87727
# timing|volume_sma_2/lead_7/buy_weighted|w4                           0 87727
# timing|volume_sma_2/lead_7/sell_weighted|w1                          0 87727
# timing|volume_sma_2/lead_7/sell_weighted|w2                          0 87727
# timing|volume_sma_2/lead_7/sell_weighted|w3                          0 87727
# timing|volume_sma_2/lead_7/sell_weighted|w4                          0 87727
# trading|crypto_cash_sells|w1                                         0 87727
# trading|crypto_cash_sells|w2                                         0 87727
# trading|total_volume|w1                                              0 87727
# trading|total_volume|w2                                              0 87727
# transfers|buys_coin_age/mean|w1                                      0 87727
# transfers|buys_coin_age/mean|w2                                   7698 80029
# transfers|buys_coin_age/mean|w3                                  14976 72751
# transfers|buys_coin_age/mean|w4                                  28838 58889
# transfers|earlybird_ratio/median|w1                                  0 87727
# transfers|earlybird_ratio/median|w2                               7698 80029
# transfers|earlybird_ratio/median|w3                              14976 72751
# transfers|earlybird_ratio/median|w4                              28838 58889
# transfers|first_buy/mean_rank|w1                                     0 87727
# transfers|first_buy/mean_rank|w2                                  7698 80029
# transfers|first_buy/mean_rank|w3                                 14976 72751
# transfers|first_buy/mean_rank|w4                                 28838 58889
# transfers|initial_hold_time/median|w1                                0 87727
# transfers|initial_hold_time/median|w2                             7698 80029
# transfers|initial_hold_time/median|w3                            14976 72751
# transfers|initial_hold_time/median|w4                            28838 58889
# transfers|later_buyers/median|w1                                     0 87727
# transfers|later_buyers/median|w2                                  7698 80029
# transfers|later_buyers/median|w3                                 14976 72751
# transfers|later_buyers/median|w4                                 28838 58889
#
#                                                                           mean  \
# cluster|k5_cluster_k0                                           0.219521925975
# cluster|k5_cluster_k1                                             0.2671241465
# cluster|k5_cluster_k2                                           0.125377591847
# cluster|k5_cluster_k3                                           0.207507380852
# cluster|k5_cluster_k4                                           0.180468954826
# cw_cluster|k5_cluster_k0                                        0.413236517834
# cw_cluster|k5_cluster_k1                                        0.135705085094
# cw_cluster|k5_cluster_k2                                       0.0938023641524
# cw_cluster|k5_cluster_k3                                         0.14589579035
# cw_cluster|k5_cluster_k4                                        0.211360242571
# cw_coin_trends|current_holders_in_profit_pct|w1                 0.160139918327
# cw_coin_trends|current_holders_in_profit_pct|w2                 0.146240979433
# cw_coin_trends|current_holders_in_profit_pct|w3                 0.139986082911
# cw_coin_trends|current_holders_in_profit_pct|w4                 0.123462818563
# cw_coin_trends|current_holders_in_profit|w1                      2919.39367584
# cw_coin_trends|current_holders_in_profit|w2                      2423.21777344
# cw_coin_trends|current_holders_in_profit|w3                      2396.77368164
# cw_coin_trends|current_holders_in_profit|w4                      2172.68408203
# cw_coin_trends|current_holders_pct_of_lifetime|w1               0.416024506092
# cw_coin_trends|current_holders_pct_of_lifetime|w2               0.410105675459
# cw_coin_trends|current_holders_pct_of_lifetime|w3               0.413469344378
# cw_coin_trends|current_holders_pct_of_lifetime|w4                 0.3930965662
# cw_coin_trends|current_holders|w1                                21790.1017817
# cw_coin_trends|current_holders|w2                                20097.3144531
# cw_coin_trends|current_holders|w3                                19593.9257812
# cw_coin_trends|current_holders|w4                                19629.3085938
# cw_coin_trends|days_since_ath|w1                                 448.624653755
# cw_coin_trends|days_since_ath|w2                                 467.203765869
# cw_coin_trends|days_since_ath|w3                                 476.003448486
# cw_coin_trends|days_since_ath|w4                                 516.747680664
# cw_coin_trends|days_since_launch|w1                                599.8394109
# cw_coin_trends|days_since_launch|w2                              605.356140137
# cw_coin_trends|days_since_launch|w3                              606.845458984
# cw_coin_trends|days_since_launch|w4                              628.297912598
# cw_coin_trends|lifetime_holders|w1                               60866.0203472
# cw_coin_trends|lifetime_holders|w2                               58088.5429688
# cw_coin_trends|lifetime_holders|w3                               57087.1601562
# cw_coin_trends|lifetime_holders|w4                               57461.5742188
# cw_coin_trends|price_pct_of_ath|w1                              0.420136958361
# cw_coin_trends|price_pct_of_ath|w2                              0.363159894943
# cw_coin_trends|price_pct_of_ath|w3                              0.355277359486
# cw_coin_trends|price_pct_of_ath|w4                              0.268011748791
# cw_mktcap|end_portfolio_wtd_market_cap/market_cap_filled|w1          206401808
# cw_mktcap|end_portfolio_wtd_market_cap/market_cap_filled|w2          184696000
# cw_mktcap|end_portfolio_wtd_market_cap/market_cap_filled|w3          179667232
# cw_mktcap|end_portfolio_wtd_market_cap/market_cap_unadj|w1           206401808
# cw_mktcap|end_portfolio_wtd_market_cap/market_cap_unadj|w2           190169424
# cw_mktcap|end_portfolio_wtd_market_cap/market_cap_unadj|w3           186261184
# cw_performance|crypto_net_gain/crypto_inflows/winsorized|w1     0.210827335715
# cw_performance|crypto_net_gain/crypto_inflows/winsorized|w2    0.0737708061934
# cw_performance|crypto_net_gain/crypto_inflows/winsorized|w3     0.180120065808
# cw_performance|crypto_net_gain/crypto_inflows/winsorized|w4    0.0332873612642
# cw_scenario|ideal/relative_cash_buys/pct_rank|w1                -0.71313649416
# cw_scenario|ideal/relative_cash_buys/pct_rank|w2               -0.644400238991
# cw_scenario|ideal/relative_cash_buys/pct_rank|w3               -0.628486990929
# cw_scenario|ideal/relative_cash_buys/pct_rank|w4               -0.556470096111
# cw_scenario|ideal/relative_cash_buys/pct|w1                    -0.142847925425
# cw_scenario|ideal/relative_cash_buys/pct|w2                   -0.0731688663363
# cw_scenario|ideal/relative_cash_buys/pct|w3                    -0.142777562141
# cw_scenario|ideal/relative_cash_buys/pct|w4                      -0.1418877244
# cw_scenario|ideal/relative_combined/pct|w1                     -0.171344995499
# cw_scenario|ideal/relative_combined/pct|w2                    -0.0974570736289
# cw_scenario|ideal/relative_combined/pct|w3                     -0.186302483082
# cw_scenario|ideal/relative_combined/pct|w4                     -0.215390026569
# cw_scenario|ideal/relative_net_gain_max_inv/winsorized|w1       0.705585300922
# cw_scenario|ideal/relative_net_gain_max_inv/winsorized|w2       0.327030599117
# cw_scenario|ideal/relative_net_gain_max_inv/winsorized|w3        0.89663028717
# cw_scenario|ideal/relative_net_gain_max_inv/winsorized|w4         1.0560669899
# cw_scenario|net_perf/relative_cash_buys|w1                      0.407021969557
# cw_scenario|net_perf/relative_cash_buys|w2                      0.274136602879
# cw_scenario|net_perf/relative_cash_buys|w3                      0.366022974253
# cw_scenario|net_perf/relative_cash_buys|w4                      0.339505821466
# cw_scenario|net_perf/relative_net_gains|w1                      0.546154558659
# cw_scenario|net_perf/relative_net_gains|w2                      0.528305232525
# cw_scenario|net_perf/relative_net_gains|w3                      0.517109513283
# cw_scenario|net_perf/relative_net_gains|w4                      0.525711417198
# cw_scenario|worst/relative_net_gain_inflows/winsorized|w1       0.335069209337
# cw_scenario|worst/relative_net_gain_inflows/winsorized|w2       0.213284149766
# cw_scenario|worst/relative_net_gain_inflows/winsorized|w3       0.330173462629
# cw_scenario|worst/relative_net_gain_inflows/winsorized|w4       0.312717676163
# cw_scenario|worst/relative_net_gains|w1                          6147.85546875
# cw_scenario|worst/relative_net_gains|w2                          3825.61889648
# cw_scenario|worst/relative_net_gains|w3                          5614.77197266
# cw_scenario|worst/relative_net_gains|w4                          8985.56347656
# cw_timing|price_sma_2/lag_15/sell_weighted|w1                  0.0399351380765
# cw_timing|price_sma_2/lag_15/sell_weighted|w2                 0.00983837526292
# cw_timing|price_sma_2/lag_15/sell_weighted|w3                  0.0121876271442
# cw_timing|price_sma_2/lag_15/sell_weighted|w4                 0.00413736887276
# cw_timing|price_sma_2/lead_30/sell_weighted|w3                0.00725227082148
# cw_timing|price_sma_2/lead_30/sell_weighted|w4              -0.000821285066195
# cw_timing|volume_sma_2/lead_7/buy_weighted|w1                   0.145855277777
# cw_timing|volume_sma_2/lead_7/buy_weighted|w2                  0.0380777381361
# cw_timing|volume_sma_2/lead_7/buy_weighted|w3                  0.0600459203124
# cw_timing|volume_sma_2/lead_7/buy_weighted|w4                  0.0405472740531
# cw_trading|crypto_cash_sells|w1                                  9314.67578125
# cw_trading|crypto_cash_sells|w2                                  4608.92626953
# cw_transfers|buys_coin_age/mean|w1                                 599.8394109
# cw_transfers|buys_coin_age/mean|w2                               669.674547769
# cw_transfers|buys_coin_age/mean|w3                               714.786460783
# cw_transfers|buys_coin_age/mean|w4                               802.098918736
# cw_transfers|earlybird_ratio/mean|w1                             3.19273291175
# cw_transfers|earlybird_ratio/mean|w2                             3.72451349072
# cw_transfers|earlybird_ratio/mean|w3                             4.08365493726
# cw_transfers|earlybird_ratio/mean|w4                              4.5446121641
# cw_transfers|first_buy/mean_rank|w1                              36626.9845088
# cw_transfers|first_buy/mean_rank|w2                               39449.744687
# cw_transfers|first_buy/mean_rank|w3                              40739.5620264
# cw_transfers|first_buy/mean_rank|w4                              43316.3351918
# cw_transfers|initial_hold_time/mean|w1                           54.9855117798
# cw_transfers|initial_hold_time/mean|w2                           74.4300765991
# cw_transfers|initial_hold_time/mean|w3                           85.8124084473
# cw_transfers|initial_hold_time/mean|w4                           107.233779907
# macro|btc_mvrv_z_score_last|w1                                    1.4584903717
# macro|btc_mvrv_z_score_last|w2                                   1.00292086601
# macro|btc_mvrv_z_score_last|w3                                  0.944910347462
# macro|btc_mvrv_z_score_last|w4                                  0.588273823261
# macro|btc_mvrv_z_score_std|w1                                    1.60184049606
# macro|btc_mvrv_z_score_std|w2                                    1.60623383522
# macro|btc_mvrv_z_score_std|w3                                    1.61076152325
# macro|btc_mvrv_z_score_std|w4                                    1.61918950081
# macro|btc_price_std|w1                                           15511.6679688
# macro|btc_price_std|w2                                           15357.3095703
# macro|btc_price_std|w3                                           15267.0976562
# macro|btc_price_std|w4                                           15144.3740234
# macro|btc_vdd_multiple_std|w1                                     0.8236104846
# macro|btc_vdd_multiple_std|w2                                   0.824098289013
# macro|btc_vdd_multiple_std|w3                                   0.824636638165
# macro|btc_vdd_multiple_std|w4                                   0.829153954983
# macro|global_market_cap_rsi_30_last|w1                          0.663853168488
# macro|global_market_cap_rsi_30_last|w2                          0.547714412212
# macro|global_market_cap_rsi_30_last|w3                          0.541678130627
# macro|global_market_cap_rsi_30_last|w4                           0.58470505476
# macro|global_market_cap_std|w1                                    694833905664
# macro|global_market_cap_std|w2                                    690107645952
# macro|global_market_cap_std|w3                                    687486730240
# macro|global_market_cap_std|w4                                    684628639744
# macro|gtrends_memecoin_us_std|w1                                0.624825417995
# macro|gtrends_memecoin_us_std|w2                                0.578897714615
# macro|gtrends_memecoin_us_std|w3                                 0.54923337698
# macro|gtrends_memecoin_us_std|w4                                0.498364657164
# mktcap|end_portfolio_wtd_market_cap/market_cap_filled|w1             188639552
# mktcap|end_portfolio_wtd_market_cap/market_cap_filled|w2             148562432
# mktcap|end_portfolio_wtd_market_cap/market_cap_filled|w3             140979408
# mktcap|end_portfolio_wtd_market_cap/market_cap_filled|w4             125747232
# performance|crypto_net_gain/crypto_inflows/winsorized|w1        0.193475678563
# performance|crypto_net_gain/crypto_inflows/winsorized|w2       0.0383100621402
# performance|crypto_net_gain/crypto_inflows/winsorized|w3        0.155413925648
# performance|crypto_net_gain/crypto_inflows/winsorized|w4       0.0219463668764
# scenario|ideal/relative_cash_buys/pct|w1                       -0.177622705698
# scenario|ideal/relative_cash_buys/pct|w2                       -0.105690531433
# scenario|ideal/relative_cash_buys/pct|w3                        -0.19168651104
# scenario|ideal/relative_cash_buys/pct|w4                       -0.177915528417
# scenario|ideal/relative_combined/pct|w1                        -0.280995845795
# scenario|ideal/relative_combined/pct|w2                        -0.188161939383
# scenario|ideal/relative_combined/pct|w3                        -0.307841569185
# scenario|ideal/relative_combined/pct|w4                        -0.351897895336
# scenario|worst/relative_combined/pct|w1                         0.209058582783
# scenario|worst/relative_combined/pct|w2                         0.164929509163
# scenario|worst/relative_combined/pct|w3                         0.246446028352
# scenario|worst/relative_combined/pct|w4                         0.380020797253
# scenario|worst/relative_net_gains|w1                             29550.0488281
# scenario|worst/relative_net_gains|w2                             16971.8378906
# scenario|worst/relative_net_gains|w3                               24207.84375
# scenario|worst/relative_net_gains|w4                                35770.9375
# timing|btc_mvrv_z_score/lag_30/sell_weighted|w1                 0.113612622023
# timing|btc_mvrv_z_score/lag_30/sell_weighted|w2                 0.092906281352
# timing|btc_mvrv_z_score/lag_30/sell_weighted|w3                 0.116778440773
# timing|btc_mvrv_z_score/lag_30/sell_weighted|w4                 0.123485684395
# timing|btc_mvrv_z_score/lag_90/buy_weighted|w1                  0.326572835445
# timing|btc_mvrv_z_score/lag_90/buy_weighted|w2                   0.27261826396
# timing|btc_mvrv_z_score/lag_90/buy_weighted|w3                  0.327576190233
# timing|btc_mvrv_z_score/lag_90/buy_weighted|w4                  0.369105815887
# timing|btc_mvrv_z_score/lag_90/sell_weighted|w1                 0.255644500256
# timing|btc_mvrv_z_score/lag_90/sell_weighted|w2                 0.214319869876
# timing|btc_mvrv_z_score/lag_90/sell_weighted|w3                 0.273846805096
# timing|btc_mvrv_z_score/lag_90/sell_weighted|w4                 0.318491607904
# timing|btc_mvrv_z_score/lead_90/buy_weighted|w4                0.0108433058485
# timing|gtrends_memecoin_us/lag_15/buy_weighted|w1               0.406778327458
# timing|gtrends_memecoin_us/lag_15/buy_weighted|w2               0.175092202692
# timing|gtrends_memecoin_us/lag_15/buy_weighted|w3               0.266690086098
# timing|gtrends_memecoin_us/lag_15/buy_weighted|w4                0.44040980877
# timing|gtrends_memecoin_us/lag_15/sell_weighted|w1              0.311770291283
# timing|gtrends_memecoin_us/lag_15/sell_weighted|w2              0.137351125489
# timing|gtrends_memecoin_us/lag_15/sell_weighted|w3              0.222375951913
# timing|gtrends_memecoin_us/lag_15/sell_weighted|w4              0.378141921102
# timing|price_sma_2/lag_15/buy_weighted|w1                       0.108401067555
# timing|price_sma_2/lag_15/buy_weighted|w2                      0.0309018790722
# timing|price_sma_2/lag_15/buy_weighted|w3                      0.0623002685606
# timing|price_sma_2/lag_15/buy_weighted|w4                      0.0189974028617
# timing|volume_sma_2/lead_7/buy_weighted|w1                       0.16595813632
# timing|volume_sma_2/lead_7/buy_weighted|w2                     0.0559733211994
# timing|volume_sma_2/lead_7/buy_weighted|w3                      0.111587330699
# timing|volume_sma_2/lead_7/buy_weighted|w4                     0.0895094424486
# timing|volume_sma_2/lead_7/sell_weighted|w1                     0.110666960478
# timing|volume_sma_2/lead_7/sell_weighted|w2                    0.0330203659832
# timing|volume_sma_2/lead_7/sell_weighted|w3                    0.0659134089947
# timing|volume_sma_2/lead_7/sell_weighted|w4                    0.0510870628059
# trading|crypto_cash_sells|w1                                     83792.7265625
# trading|crypto_cash_sells|w2                                     48751.0507812
# trading|total_volume|w1                                              149594.75
# trading|total_volume|w2                                            94548.21875
# transfers|buys_coin_age/mean|w1                                     652.708536
# transfers|buys_coin_age/mean|w2                                  691.310254152
# transfers|buys_coin_age/mean|w3                                  714.271043091
# transfers|buys_coin_age/mean|w4                                  776.200853671
# transfers|earlybird_ratio/median|w1                              2.59904580697
# transfers|earlybird_ratio/median|w2                              3.04303882537
# transfers|earlybird_ratio/median|w3                              3.49157016275
# transfers|earlybird_ratio/median|w4                              4.19821933863
# transfers|first_buy/mean_rank|w1                                 32458.1226811
# transfers|first_buy/mean_rank|w2                                  32559.549267
# transfers|first_buy/mean_rank|w3                                  32517.517444
# transfers|first_buy/mean_rank|w4                                 32771.7529485
# transfers|initial_hold_time/median|w1                            52.0261497498
# transfers|initial_hold_time/median|w2                            65.1466445923
# transfers|initial_hold_time/median|w3                            75.0064849854
# transfers|initial_hold_time/median|w4                            97.7762756348
# transfers|later_buyers/median|w1                                 8494.44567807
# transfers|later_buyers/median|w2                                 11556.7164778
# transfers|later_buyers/median|w3                                 15042.1298882
# transfers|later_buyers/median|w4                                 20777.3209428
#
#                                                                          std  \
# cluster|k5_cluster_k0                                         0.413925117657
# cluster|k5_cluster_k1                                         0.442460245051
# cluster|k5_cluster_k2                                         0.331148458122
# cluster|k5_cluster_k3                                         0.405524280788
# cluster|k5_cluster_k4                                         0.384579766889
# cw_cluster|k5_cluster_k0                                      0.492417365792
# cw_cluster|k5_cluster_k1                                      0.342477082399
# cw_cluster|k5_cluster_k2                                      0.291555225639
# cw_cluster|k5_cluster_k3                                      0.353003723997
# cw_cluster|k5_cluster_k4                                      0.408275630572
# cw_coin_trends|current_holders_in_profit_pct|w1              0.0897758752108
# cw_coin_trends|current_holders_in_profit_pct|w2              0.0848697200418
# cw_coin_trends|current_holders_in_profit_pct|w3              0.0871225148439
# cw_coin_trends|current_holders_in_profit_pct|w4              0.0858568921685
# cw_coin_trends|current_holders_in_profit|w1                    3912.17098609
# cw_coin_trends|current_holders_in_profit|w2                    3349.29956055
# cw_coin_trends|current_holders_in_profit|w3                    3755.30273438
# cw_coin_trends|current_holders_in_profit|w4                    3620.84448242
# cw_coin_trends|current_holders_pct_of_lifetime|w1             0.157383993268
# cw_coin_trends|current_holders_pct_of_lifetime|w2             0.157474502921
# cw_coin_trends|current_holders_pct_of_lifetime|w3             0.169559076428
# cw_coin_trends|current_holders_pct_of_lifetime|w4             0.152457207441
# cw_coin_trends|current_holders|w1                              28999.1239234
# cw_coin_trends|current_holders|w2                              28245.3515625
# cw_coin_trends|current_holders|w3                              27946.2910156
# cw_coin_trends|current_holders|w4                              28437.4511719
# cw_coin_trends|days_since_ath|w1                               476.023467649
# cw_coin_trends|days_since_ath|w2                               470.840209961
# cw_coin_trends|days_since_ath|w3                               466.525665283
# cw_coin_trends|days_since_ath|w4                               459.086608887
# cw_coin_trends|days_since_launch|w1                            516.543861304
# cw_coin_trends|days_since_launch|w2                            510.784729004
# cw_coin_trends|days_since_launch|w3                            505.079559326
# cw_coin_trends|days_since_launch|w4                            486.523773193
# cw_coin_trends|lifetime_holders|w1                             83030.2672538
# cw_coin_trends|lifetime_holders|w2                              82647.046875
# cw_coin_trends|lifetime_holders|w3                             82045.5390625
# cw_coin_trends|lifetime_holders|w4                               81310.46875
# cw_coin_trends|price_pct_of_ath|w1                             0.34277048707
# cw_coin_trends|price_pct_of_ath|w2                            0.323623865843
# cw_coin_trends|price_pct_of_ath|w3                            0.337773323059
# cw_coin_trends|price_pct_of_ath|w4                            0.304979503155
# cw_mktcap|end_portfolio_wtd_market_cap/market_cap_filled|w1        217533408
# cw_mktcap|end_portfolio_wtd_market_cap/market_cap_filled|w2        219712944
# cw_mktcap|end_portfolio_wtd_market_cap/market_cap_filled|w3        221010832
# cw_mktcap|end_portfolio_wtd_market_cap/market_cap_unadj|w1         217533408
# cw_mktcap|end_portfolio_wtd_market_cap/market_cap_unadj|w2         221955728
# cw_mktcap|end_portfolio_wtd_market_cap/market_cap_unadj|w3         224327280
# cw_performance|crypto_net_gain/crypto_inflows/winsorized|w1   0.597848474979
# cw_performance|crypto_net_gain/crypto_inflows/winsorized|w2   0.372792959213
# cw_performance|crypto_net_gain/crypto_inflows/winsorized|w3   0.626397788525
# cw_performance|crypto_net_gain/crypto_inflows/winsorized|w4   0.500776588917
# cw_scenario|ideal/relative_cash_buys/pct_rank|w1              0.246925771236
# cw_scenario|ideal/relative_cash_buys/pct_rank|w2              0.248070016503
# cw_scenario|ideal/relative_cash_buys/pct_rank|w3              0.248202875257
# cw_scenario|ideal/relative_cash_buys/pct_rank|w4              0.246191084385
# cw_scenario|ideal/relative_cash_buys/pct|w1                   0.201431408525
# cw_scenario|ideal/relative_cash_buys/pct|w2                   0.132407128811
# cw_scenario|ideal/relative_cash_buys/pct|w3                   0.210759624839
# cw_scenario|ideal/relative_cash_buys/pct|w4                   0.196682155132
# cw_scenario|ideal/relative_combined/pct|w1                    0.217768341303
# cw_scenario|ideal/relative_combined/pct|w2                    0.153355464339
# cw_scenario|ideal/relative_combined/pct|w3                     0.24975182116
# cw_scenario|ideal/relative_combined/pct|w4                    0.290564119816
# cw_scenario|ideal/relative_net_gain_max_inv/winsorized|w1      1.42136311531
# cw_scenario|ideal/relative_net_gain_max_inv/winsorized|w2     0.586115837097
# cw_scenario|ideal/relative_net_gain_max_inv/winsorized|w3       2.2911863327
# cw_scenario|ideal/relative_net_gain_max_inv/winsorized|w4      3.28488874435
# cw_scenario|net_perf/relative_cash_buys|w1                    0.413351923227
# cw_scenario|net_perf/relative_cash_buys|w2                    0.366242229939
# cw_scenario|net_perf/relative_cash_buys|w3                    0.376009047031
# cw_scenario|net_perf/relative_cash_buys|w4                     0.33040329814
# cw_scenario|net_perf/relative_net_gains|w1                    0.306781858206
# cw_scenario|net_perf/relative_net_gains|w2                    0.319617450237
# cw_scenario|net_perf/relative_net_gains|w3                    0.306697845459
# cw_scenario|net_perf/relative_net_gains|w4                    0.285534441471
# cw_scenario|worst/relative_net_gain_inflows/winsorized|w1     0.508081316948
# cw_scenario|worst/relative_net_gain_inflows/winsorized|w2     0.320886522532
# cw_scenario|worst/relative_net_gain_inflows/winsorized|w3     0.535557150841
# cw_scenario|worst/relative_net_gain_inflows/winsorized|w4     0.396524637938
# cw_scenario|worst/relative_net_gains|w1                         45253.859375
# cw_scenario|worst/relative_net_gains|w2                         28404.453125
# cw_scenario|worst/relative_net_gains|w3                        42435.6835938
# cw_scenario|worst/relative_net_gains|w4                         72677.640625
# cw_timing|price_sma_2/lag_15/sell_weighted|w1                 0.161972522736
# cw_timing|price_sma_2/lag_15/sell_weighted|w2                 0.107289969921
# cw_timing|price_sma_2/lag_15/sell_weighted|w3                 0.108917787671
# cw_timing|price_sma_2/lag_15/sell_weighted|w4                0.0860545858741
# cw_timing|price_sma_2/lead_30/sell_weighted|w3                0.130739405751
# cw_timing|price_sma_2/lead_30/sell_weighted|w4                0.116735614836
# cw_timing|volume_sma_2/lead_7/buy_weighted|w1                  1.02232027054
# cw_timing|volume_sma_2/lead_7/buy_weighted|w2                 0.664575457573
# cw_timing|volume_sma_2/lead_7/buy_weighted|w3                 0.745105326176
# cw_timing|volume_sma_2/lead_7/buy_weighted|w4                 0.642181634903
# cw_trading|crypto_cash_sells|w1                                96110.0078125
# cw_trading|crypto_cash_sells|w2                                70861.4296875
# cw_transfers|buys_coin_age/mean|w1                             516.543861304
# cw_transfers|buys_coin_age/mean|w2                             503.068757599
# cw_transfers|buys_coin_age/mean|w3                             495.124722346
# cw_transfers|buys_coin_age/mean|w4                             478.718671712
# cw_transfers|earlybird_ratio/mean|w1                           5.09224078247
# cw_transfers|earlybird_ratio/mean|w2                           5.41262951031
# cw_transfers|earlybird_ratio/mean|w3                           5.68907953613
# cw_transfers|earlybird_ratio/mean|w4                            6.0816707321
# cw_transfers|first_buy/mean_rank|w1                             57695.244341
# cw_transfers|first_buy/mean_rank|w2                            61326.2692746
# cw_transfers|first_buy/mean_rank|w3                            61803.9635177
# cw_transfers|first_buy/mean_rank|w4                            62397.0220075
# cw_transfers|initial_hold_time/mean|w1                         114.029167175
# cw_transfers|initial_hold_time/mean|w2                         135.931930542
# cw_transfers|initial_hold_time/mean|w3                         148.311355591
# cw_transfers|initial_hold_time/mean|w4                         167.665786743
# macro|btc_mvrv_z_score_last|w1                                0.884416937828
# macro|btc_mvrv_z_score_last|w2                                0.490704983473
# macro|btc_mvrv_z_score_last|w3                                0.588633477688
# macro|btc_mvrv_z_score_last|w4                                0.382576048374
# macro|btc_mvrv_z_score_std|w1                                0.0176623631269
# macro|btc_mvrv_z_score_std|w2                                0.0170032568276
# macro|btc_mvrv_z_score_std|w3                                0.0159161295742
# macro|btc_mvrv_z_score_std|w4                                0.0133349904791
# macro|btc_price_std|w1                                         362.707092285
# macro|btc_price_std|w2                                         236.435470581
# macro|btc_price_std|w3                                         167.494934082
# macro|btc_price_std|w4                                          57.249168396
# macro|btc_vdd_multiple_std|w1                               0.00780435279012
# macro|btc_vdd_multiple_std|w2                               0.00882275216281
# macro|btc_vdd_multiple_std|w3                                0.0100685060024
# macro|btc_vdd_multiple_std|w4                                0.0101370587945
# macro|global_market_cap_rsi_30_last|w1                        0.200174480677
# macro|global_market_cap_rsi_30_last|w2                        0.111389227211
# macro|global_market_cap_rsi_30_last|w3                         0.12615801394
# macro|global_market_cap_rsi_30_last|w4                        0.148682132363
# macro|global_market_cap_std|w1                                   10406151168
# macro|global_market_cap_std|w2                                    6052212224
# macro|global_market_cap_std|w3                                    3702830336
# macro|global_market_cap_std|w4                                    1202587392
# macro|gtrends_memecoin_us_std|w1                              0.131603136659
# macro|gtrends_memecoin_us_std|w2                              0.115883983672
# macro|gtrends_memecoin_us_std|w3                              0.100710071623
# macro|gtrends_memecoin_us_std|w4                             0.0836058109999
# mktcap|end_portfolio_wtd_market_cap/market_cap_filled|w1           163997264
# mktcap|end_portfolio_wtd_market_cap/market_cap_filled|w2           156912832
# mktcap|end_portfolio_wtd_market_cap/market_cap_filled|w3           157926704
# mktcap|end_portfolio_wtd_market_cap/market_cap_filled|w4           166537248
# performance|crypto_net_gain/crypto_inflows/winsorized|w1      0.470130473375
# performance|crypto_net_gain/crypto_inflows/winsorized|w2      0.292140960693
# performance|crypto_net_gain/crypto_inflows/winsorized|w3      0.463005304337
# performance|crypto_net_gain/crypto_inflows/winsorized|w4      0.391700536013
# scenario|ideal/relative_cash_buys/pct|w1                      0.184422329068
# ...
# cw_coin_trends|current_holders_in_profit|w3                           29296
# cw_coin_trends|current_holders_in_profit|w4                           29296
# cw_coin_trends|current_holders_pct_of_lifetime|w1                         1
# cw_coin_trends|current_holders_pct_of_lifetime|w2                         1
# cw_coin_trends|current_holders_pct_of_lifetime|w3                         1
# cw_coin_trends|current_holders_pct_of_lifetime|w4                         1
# cw_coin_trends|current_holders|w1                                    197309
# cw_coin_trends|current_holders|w2                                    171661
# cw_coin_trends|current_holders|w3                                    171661
# cw_coin_trends|current_holders|w4                                    171128
# cw_coin_trends|days_since_ath|w1                                       2587
# cw_coin_trends|days_since_ath|w2                                       2557
# cw_coin_trends|days_since_ath|w3                                       2527
# cw_coin_trends|days_since_ath|w4                                       2467
# cw_coin_trends|days_since_launch|w1                                    2512
# cw_coin_trends|days_since_launch|w2                                    2482
# cw_coin_trends|days_since_launch|w3                                    2452
# cw_coin_trends|days_since_launch|w4                                    2392
# cw_coin_trends|lifetime_holders|w1                                   416716
# cw_coin_trends|lifetime_holders|w2                                   414453
# cw_coin_trends|lifetime_holders|w3                                   412584
# cw_coin_trends|lifetime_holders|w4                                   407082
# cw_coin_trends|price_pct_of_ath|w1                                        1
# cw_coin_trends|price_pct_of_ath|w2                                        1
# cw_coin_trends|price_pct_of_ath|w3                                        1
# cw_coin_trends|price_pct_of_ath|w4                                        1
# cw_mktcap|end_portfolio_wtd_market_cap/market_cap_filled|w1       967754176
# cw_mktcap|end_portfolio_wtd_market_cap/market_cap_filled|w2      1083069440
# cw_mktcap|end_portfolio_wtd_market_cap/market_cap_filled|w3      1233593728
# cw_mktcap|end_portfolio_wtd_market_cap/market_cap_unadj|w1        967754176
# cw_mktcap|end_portfolio_wtd_market_cap/market_cap_unadj|w2       1083069440
# cw_mktcap|end_portfolio_wtd_market_cap/market_cap_unadj|w3       1233593728
# cw_performance|crypto_net_gain/crypto_inflows/winsorized|w1   3.60663151741
# cw_performance|crypto_net_gain/crypto_inflows/winsorized|w2   3.47391843796
# cw_performance|crypto_net_gain/crypto_inflows/winsorized|w3   4.98406505585
# cw_performance|crypto_net_gain/crypto_inflows/winsorized|w4   3.82884144783
# cw_scenario|ideal/relative_cash_buys/pct_rank|w1            -0.371526628733
# cw_scenario|ideal/relative_cash_buys/pct_rank|w2            -0.349939912558
# cw_scenario|ideal/relative_cash_buys/pct_rank|w3             -0.25570037961
# cw_scenario|ideal/relative_cash_buys/pct_rank|w4            -0.164369419217
# cw_scenario|ideal/relative_cash_buys/pct|w1                              -0
# cw_scenario|ideal/relative_cash_buys/pct|w2                              -0
# cw_scenario|ideal/relative_cash_buys/pct|w3                              -0
# cw_scenario|ideal/relative_cash_buys/pct|w4                              -0
# cw_scenario|ideal/relative_combined/pct|w1                               -0
# cw_scenario|ideal/relative_combined/pct|w2                               -0
# cw_scenario|ideal/relative_combined/pct|w3                               -0
# cw_scenario|ideal/relative_combined/pct|w4                               -0
# cw_scenario|ideal/relative_net_gain_max_inv/winsorized|w1     11.6888504028
# cw_scenario|ideal/relative_net_gain_max_inv/winsorized|w2     9.41425895691
# cw_scenario|ideal/relative_net_gain_max_inv/winsorized|w3     21.8870220184
# cw_scenario|ideal/relative_net_gain_max_inv/winsorized|w4     55.0274391174
# cw_scenario|net_perf/relative_cash_buys|w1                                1
# cw_scenario|net_perf/relative_cash_buys|w2                                1
# cw_scenario|net_perf/relative_cash_buys|w3                                1
# cw_scenario|net_perf/relative_cash_buys|w4                                1
# cw_scenario|net_perf/relative_net_gains|w1                                1
# cw_scenario|net_perf/relative_net_gains|w2                                1
# cw_scenario|net_perf/relative_net_gains|w3                                1
# cw_scenario|net_perf/relative_net_gains|w4                                1
# cw_scenario|worst/relative_net_gain_inflows/winsorized|w1     4.32554244995
# cw_scenario|worst/relative_net_gain_inflows/winsorized|w2     4.28566169739
# cw_scenario|worst/relative_net_gain_inflows/winsorized|w3     5.98406505585
# cw_scenario|worst/relative_net_gain_inflows/winsorized|w4     3.97010445595
# cw_scenario|worst/relative_net_gains|w1                             6037055
# cw_scenario|worst/relative_net_gains|w2                           3147101.5
# cw_scenario|worst/relative_net_gains|w3                           4960833.5
# cw_scenario|worst/relative_net_gains|w4                           5075579.5
# cw_timing|price_sma_2/lag_15/sell_weighted|w1                0.678543806076
# cw_timing|price_sma_2/lag_15/sell_weighted|w2                0.674477875233
# cw_timing|price_sma_2/lag_15/sell_weighted|w3                0.678042769432
# cw_timing|price_sma_2/lag_15/sell_weighted|w4                0.695771157742
# cw_timing|price_sma_2/lead_30/sell_weighted|w3                3.77334833145
# cw_timing|price_sma_2/lead_30/sell_weighted|w4                3.79024982452
# cw_timing|volume_sma_2/lead_7/buy_weighted|w1                 20.2769374847
# cw_timing|volume_sma_2/lead_7/buy_weighted|w2                 20.2708282471
# cw_timing|volume_sma_2/lead_7/buy_weighted|w3                 20.4433517456
# cw_timing|volume_sma_2/lead_7/buy_weighted|w4                 20.6287345886
# cw_trading|crypto_cash_sells|w1                                     9013379
# cw_trading|crypto_cash_sells|w2                                    10460360
# cw_transfers|buys_coin_age/mean|w1                                     2512
# cw_transfers|buys_coin_age/mean|w2                                     2512
# cw_transfers|buys_coin_age/mean|w3                                     2512
# cw_transfers|buys_coin_age/mean|w4                                     2512
# cw_transfers|earlybird_ratio/mean|w1                                     20
# cw_transfers|earlybird_ratio/mean|w2                                     20
# cw_transfers|earlybird_ratio/mean|w3                                     20
# cw_transfers|earlybird_ratio/mean|w4                                     20
# cw_transfers|first_buy/mean_rank|w1                                  370271
# cw_transfers|first_buy/mean_rank|w2                                  368020
# cw_transfers|first_buy/mean_rank|w3                                  365918
# cw_transfers|first_buy/mean_rank|w4                                  361520
# cw_transfers|initial_hold_time/mean|w1                                 2175
# cw_transfers|initial_hold_time/mean|w2                                 2175
# cw_transfers|initial_hold_time/mean|w3                                 2175
# cw_transfers|initial_hold_time/mean|w4                                 2175
# macro|btc_mvrv_z_score_last|w1                                2.58916759491
# macro|btc_mvrv_z_score_last|w2                                 1.5530591011
# macro|btc_mvrv_z_score_last|w3                                 1.5530591011
# macro|btc_mvrv_z_score_last|w4                               0.999107718468
# macro|btc_mvrv_z_score_std|w1                                 1.64397358894
# macro|btc_mvrv_z_score_std|w2                                 1.64364719391
# macro|btc_mvrv_z_score_std|w3                                 1.64397358894
# macro|btc_mvrv_z_score_std|w4                                   1.644952178
# macro|btc_price_std|w1                                           15969.3125
# macro|btc_price_std|w2                                        15646.4453125
# macro|btc_price_std|w3                                        15484.8417969
# macro|btc_price_std|w4                                        15242.7958984
# macro|btc_vdd_multiple_std|w1                                0.850747942924
# macro|btc_vdd_multiple_std|w2                                0.852114796638
# macro|btc_vdd_multiple_std|w3                                0.852512896061
# macro|btc_vdd_multiple_std|w4                                0.853915631771
# macro|global_market_cap_rsi_30_last|w1                       0.905992746353
# macro|global_market_cap_rsi_30_last|w2                       0.771024346352
# macro|global_market_cap_rsi_30_last|w3                       0.771024346352
# macro|global_market_cap_rsi_30_last|w4                       0.771024346352
# macro|global_market_cap_std|w1                                 708429873152
# macro|global_market_cap_std|w2                                 697917898752
# macro|global_market_cap_std|w3                                 692565901312
# macro|global_market_cap_std|w4                                 689654005760
# macro|gtrends_memecoin_us_std|w1                               0.7642583251
# macro|gtrends_memecoin_us_std|w2                             0.691833138466
# macro|gtrends_memecoin_us_std|w3                             0.653159081936
# macro|gtrends_memecoin_us_std|w4                             0.572352647781
# mktcap|end_portfolio_wtd_market_cap/market_cap_filled|w1          967754176
# mktcap|end_portfolio_wtd_market_cap/market_cap_filled|w2         1083069568
# mktcap|end_portfolio_wtd_market_cap/market_cap_filled|w3         1233593728
# mktcap|end_portfolio_wtd_market_cap/market_cap_filled|w4         1387840128
# performance|crypto_net_gain/crypto_inflows/winsorized|w1      3.66342759132
# performance|crypto_net_gain/crypto_inflows/winsorized|w2      2.80973792076
# performance|crypto_net_gain/crypto_inflows/winsorized|w3       3.5598154068
# performance|crypto_net_gain/crypto_inflows/winsorized|w4      3.74611163139
# scenario|ideal/relative_cash_buys/pct|w1                                 -0
# scenario|ideal/relative_cash_buys/pct|w2                                 -0
# scenario|ideal/relative_cash_buys/pct|w3                                 -0
# scenario|ideal/relative_cash_buys/pct|w4                                 -0
# scenario|ideal/relative_combined/pct|w1                                  -0
# scenario|ideal/relative_combined/pct|w2                                  -0
# scenario|ideal/relative_combined/pct|w3                                  -0
# scenario|ideal/relative_combined/pct|w4                                  -0
# scenario|worst/relative_combined/pct|w1                       1.18712806702
# scenario|worst/relative_combined/pct|w2                       1.21570706367
# scenario|worst/relative_combined/pct|w3                       1.77129602432
# scenario|worst/relative_combined/pct|w4                       6.17903089523
# scenario|worst/relative_net_gains|w1                              6240840.5
# scenario|worst/relative_net_gains|w2                              4653088.5
# scenario|worst/relative_net_gains|w3                                5028661
# scenario|worst/relative_net_gains|w4                                7823584
# timing|btc_mvrv_z_score/lag_30/sell_weighted|w1                9.6218290329
# timing|btc_mvrv_z_score/lag_30/sell_weighted|w2               9.62182807922
# timing|btc_mvrv_z_score/lag_30/sell_weighted|w3                9.6218290329
# timing|btc_mvrv_z_score/lag_30/sell_weighted|w4                9.6218290329
# timing|btc_mvrv_z_score/lag_90/buy_weighted|w1                11.8861227036
# timing|btc_mvrv_z_score/lag_90/buy_weighted|w2                 16.655412674
# timing|btc_mvrv_z_score/lag_90/buy_weighted|w3                31.5648097992
# timing|btc_mvrv_z_score/lag_90/buy_weighted|w4                31.5648097992
# timing|btc_mvrv_z_score/lag_90/sell_weighted|w1               11.8861236572
# timing|btc_mvrv_z_score/lag_90/sell_weighted|w2                16.655412674
# timing|btc_mvrv_z_score/lag_90/sell_weighted|w3               31.5648097992
# timing|btc_mvrv_z_score/lag_90/sell_weighted|w4               31.5648097992
# timing|btc_mvrv_z_score/lead_90/buy_weighted|w4               10.7178077698
# timing|gtrends_memecoin_us/lag_15/buy_weighted|w1             1.00000007708
# timing|gtrends_memecoin_us/lag_15/buy_weighted|w2             1.00000008334
# timing|gtrends_memecoin_us/lag_15/buy_weighted|w3             1.00000008793
# timing|gtrends_memecoin_us/lag_15/buy_weighted|w4             1.00000009585
# timing|gtrends_memecoin_us/lag_15/sell_weighted|w1            1.00000009495
# timing|gtrends_memecoin_us/lag_15/sell_weighted|w2            1.00000008694
# timing|gtrends_memecoin_us/lag_15/sell_weighted|w3            1.00000008439
# timing|gtrends_memecoin_us/lag_15/sell_weighted|w4            1.00000009207
# timing|price_sma_2/lag_15/buy_weighted|w1                    0.678543806076
# timing|price_sma_2/lag_15/buy_weighted|w2                    0.674477875233
# timing|price_sma_2/lag_15/buy_weighted|w3                    0.686398148537
# timing|price_sma_2/lag_15/buy_weighted|w4                    0.695771157742
# timing|volume_sma_2/lead_7/buy_weighted|w1                    20.2769374847
# timing|volume_sma_2/lead_7/buy_weighted|w2                    20.2708282471
# timing|volume_sma_2/lead_7/buy_weighted|w3                    20.4433517456
# timing|volume_sma_2/lead_7/buy_weighted|w4                    20.2342433929
# timing|volume_sma_2/lead_7/sell_weighted|w1                   20.2769374847
# timing|volume_sma_2/lead_7/sell_weighted|w2                   20.2708301544
# timing|volume_sma_2/lead_7/sell_weighted|w3                   20.4433517456
# timing|volume_sma_2/lead_7/sell_weighted|w4                   20.2342414856
# trading|crypto_cash_sells|w1                                       13310145
# trading|crypto_cash_sells|w2                                       11626191
# trading|total_volume|w1                                            25311798
# trading|total_volume|w2                                            21666880
# transfers|buys_coin_age/mean|w1                                     2336.25
# transfers|buys_coin_age/mean|w2                                        2512
# transfers|buys_coin_age/mean|w3                                        2501
# transfers|buys_coin_age/mean|w4                                        2501
# transfers|earlybird_ratio/median|w1                                      20
# transfers|earlybird_ratio/median|w2                                      20
# transfers|earlybird_ratio/median|w3                                      20
# transfers|earlybird_ratio/median|w4                                      20
# transfers|first_buy/mean_rank|w1                              328789.666667
# transfers|first_buy/mean_rank|w2                                     367957
# transfers|first_buy/mean_rank|w3                                     366012
# transfers|first_buy/mean_rank|w4                                     357623
# transfers|initial_hold_time/median|w1                                  2077
# transfers|initial_hold_time/median|w2                                  2189
# transfers|initial_hold_time/median|w3                                  2159
# transfers|initial_hold_time/median|w4                                  2099
# transfers|later_buyers/median|w1                                     262286
# transfers|later_buyers/median|w2                                     348237
# transfers|later_buyers/median|w3                                     370270
# transfers|later_buyers/median|w4                                     348237

# %% [markdown]
# #### preprocess data

# %%
preprocessor = wp.SageWalletsPreprocessor(sage_wallets_config)
preprocessed_data = preprocessor.preprocess_training_data(workflow_orch.training_data)
# Out:
# [12/Jul/25 14:33:34] INFO [wallet_preprocessor.preprocess_training_data:42] Starting preprocessing for SageMaker XGBoost compatibility...
# [12/Jul/25 14:33:34] INFO [wallet_preprocessor._handle_missing_values:165] Filled NaN values in 100 columns for x_train.
# [12/Jul/25 14:33:34] INFO [wallet_preprocessor._combine_x_y_data:259] Merged y df with target var cw_crypto_net_gain/crypto_inflows/winsorized with X data.
# [12/Jul/25 14:33:34] INFO [wallet_preprocessor.preprocess_training_data:77] Preprocessed train: 87,727 rows × 222 cols.
# [12/Jul/25 14:33:34] INFO [wallet_preprocessor._handle_missing_values:165] Filled NaN values in 100 columns for x_test.
# [12/Jul/25 14:33:34] INFO [wallet_preprocessor._combine_x_y_data:259] Merged y df with target var cw_crypto_net_gain/crypto_inflows/winsorized with X data.
# [12/Jul/25 14:33:34] INFO [wallet_preprocessor.preprocess_training_data:77] Preprocessed test: 16,450 rows × 222 cols.
# [12/Jul/25 14:33:34] INFO [wallet_preprocessor._handle_missing_values:165] Filled NaN values in 100 columns for x_eval.
# [12/Jul/25 14:33:34] INFO [wallet_preprocessor._combine_x_y_data:259] Merged y df with target var cw_crypto_net_gain/crypto_inflows/winsorized with X data.
# [12/Jul/25 14:33:34] INFO [wallet_preprocessor.preprocess_training_data:77] Preprocessed eval: 5,485 rows × 222 cols.
# [12/Jul/25 14:33:34] INFO [wallet_preprocessor._handle_missing_values:165] Filled NaN values in 100 columns for x_val.
# [12/Jul/25 14:33:34] INFO [wallet_preprocessor._combine_x_y_data:259] Merged y df with target var cw_crypto_net_gain/crypto_inflows/winsorized with X data.
# [12/Jul/25 14:33:34] INFO [wallet_preprocessor.preprocess_training_data:77] Preprocessed val: 89,820 rows × 222 cols.

# %% [markdown]
# #### upload data

# %%
# Upload and retrieve URIs
workflow_orch.upload_training_data(preprocessed_data, overwrite_existing=True)
s3_uris = workflow_orch.retrieve_training_data_uris(date_suffixes)
# Out:
# [12/Jul/25 14:33:34] INFO [workflow_orchestrator.upload_training_data:152] <PROD> Ready to upload 8 preprocessed training data files across 2 date folders.
# [12/Jul/25 14:33:34] INFO [workflow_orchestrator.upload_training_data:154] Target variable: cw_crypto_net_gain_crypto_inflows_winsorized
# [12/Jul/25 14:33:34] INFO [workflow_orchestrator.upload_training_data:155] Target: s3://wallet-training-data/training-data-preprocessed/dda-897-td-col-ordering/[DATE]/
# [12/Jul/25 14:33:37] INFO [workflow_orchestrator.upload_training_data:187] Uploading train_cw_crypto_net_gain_crypto_inflows_winsorized for 231107: 87,727 rows
# [12/Jul/25 14:34:00] INFO [workflow_orchestrator.upload_training_data:196] Uploaded train to s3://wallet-training-data/training-data-preprocessed/dda-897-td-col-ordering/231107/train_cw_crypto_net_gain_crypto_inflows_winsorized.csv
# [12/Jul/25 14:34:00] INFO [workflow_orchestrator.upload_training_data:187] Uploading test_cw_crypto_net_gain_crypto_inflows_winsorized for 231107: 16,450 rows
# [12/Jul/25 14:34:04] INFO [workflow_orchestrator.upload_training_data:196] Uploaded test to s3://wallet-training-data/training-data-preprocessed/dda-897-td-col-ordering/231107/test_cw_crypto_net_gain_crypto_inflows_winsorized.csv
# [12/Jul/25 14:34:04] INFO [workflow_orchestrator.upload_training_data:187] Uploading eval_cw_crypto_net_gain_crypto_inflows_winsorized for 231107: 5,485 rows
# [12/Jul/25 14:34:06] INFO [workflow_orchestrator.upload_training_data:196] Uploaded eval to s3://wallet-training-data/training-data-preprocessed/dda-897-td-col-ordering/231107/eval_cw_crypto_net_gain_crypto_inflows_winsorized.csv
# [12/Jul/25 14:34:06] INFO [workflow_orchestrator.upload_training_data:187] Uploading val_cw_crypto_net_gain_crypto_inflows_winsorized for 231107: 89,820 rows
# [12/Jul/25 14:34:24] INFO [workflow_orchestrator.upload_training_data:196] Uploaded val to s3://wallet-training-data/training-data-preprocessed/dda-897-td-col-ordering/231107/val_cw_crypto_net_gain_crypto_inflows_winsorized.csv
# [12/Jul/25 14:34:24] INFO [workflow_orchestrator.upload_training_data:187] Uploading train_cw_crypto_net_gain_crypto_inflows_winsorized for 240306: 87,727 rows
# [12/Jul/25 14:34:47] INFO [workflow_orchestrator.upload_training_data:196] Uploaded train to s3://wallet-training-data/training-data-preprocessed/dda-897-td-col-ordering/240306/train_cw_crypto_net_gain_crypto_inflows_winsorized.csv
# [12/Jul/25 14:34:47] INFO [workflow_orchestrator.upload_training_data:187] Uploading test_cw_crypto_net_gain_crypto_inflows_winsorized for 240306: 16,450 rows
# [12/Jul/25 14:34:51] INFO [workflow_orchestrator.upload_training_data:196] Uploaded test to s3://wallet-training-data/training-data-preprocessed/dda-897-td-col-ordering/240306/test_cw_crypto_net_gain_crypto_inflows_winsorized.csv
# [12/Jul/25 14:34:51] INFO [workflow_orchestrator.upload_training_data:187] Uploading eval_cw_crypto_net_gain_crypto_inflows_winsorized for 240306: 5,485 rows
# [12/Jul/25 14:34:52] INFO [workflow_orchestrator.upload_training_data:196] Uploaded eval to s3://wallet-training-data/training-data-preprocessed/dda-897-td-col-ordering/240306/eval_cw_crypto_net_gain_crypto_inflows_winsorized.csv
# [12/Jul/25 14:34:52] INFO [workflow_orchestrator.upload_training_data:187] Uploading val_cw_crypto_net_gain_crypto_inflows_winsorized for 240306: 89,820 rows
# [12/Jul/25 14:35:14] INFO [workflow_orchestrator.upload_training_data:196] Uploaded val to s3://wallet-training-data/training-data-preprocessed/dda-897-td-col-ordering/240306/val_cw_crypto_net_gain_crypto_inflows_winsorized.csv

# %% [markdown]
# ### retrieve uris

# %%
date_suffixes = [
    '231107',
    # '240306'
]

# Generate URIs for specific dates without any prior setup
s3_uris = workflow_orch.retrieve_training_data_uris(date_suffixes)
s3_uris
# Out:
# {'231107': {'train': 's3://wallet-training-data/training-data-preprocessed/dda-897-td-col-ordering/231107/train_cw_crypto_net_gain_crypto_inflows_winsorized.csv',
#   'test': 's3://wallet-training-data/training-data-preprocessed/dda-897-td-col-ordering/231107/test_cw_crypto_net_gain_crypto_inflows_winsorized.csv',
#   'eval': 's3://wallet-training-data/training-data-preprocessed/dda-897-td-col-ordering/231107/eval_cw_crypto_net_gain_crypto_inflows_winsorized.csv',
#   'val': 's3://wallet-training-data/training-data-preprocessed/dda-897-td-col-ordering/231107/val_cw_crypto_net_gain_crypto_inflows_winsorized.csv'}}

# %% [markdown]
# ### dda 872 devspace

# %%
[importlib.reload(module) for module in modules]
sage_wallets_config = yaml.safe_load(Path('../config/sage_wallets_config.yaml').read_text(encoding='utf-8'))
sage_wallets_modeling_config = yaml.safe_load(Path('../config/sage_wallets_modeling_config.yaml').read_text(encoding='utf-8'))


modeler = wm.WalletModeler(sage_wallets_config, s3_uris)

# %%
modeler.train_model()
# Out:
# [12/Jul/25 14:35:15] INFO [wallet_modeler.train_model:55] Starting SageMaker XGBoost training
# [12/Jul/25 14:35:15] INFO [image_uris._processor:530] Ignoring unnecessary instance type: None.
# [12/Jul/25 14:35:15] INFO [wallet_modeler.train_model:100] Launching training job: wallet-xgb-231107-143515
# [12/Jul/25 14:35:15] INFO [telemetry_logging.wrapper:91] SageMaker Python SDK will collect telemetry to help us better understand our user's needs, diagnose issues, and deliver additional features.
# To opt out of telemetry, please disable via TelemetryOptOut parameter in SDK defaults config. For more information, refer to https://sagemaker.readthedocs.io/en/stable/overview.html#configuring-and-using-defaults-with-the-sagemaker-python-sdk.
# [12/Jul/25 14:35:15] INFO [session.submit:1053] Creating training-job with name: wallet-xgb-231107-143515
# 2025-07-12 21:35:19 Starting - Starting the training job...
# 2025-07-12 21:35:34 Starting - Preparing the instances for training...
# 2025-07-12 21:35:55 Downloading - Downloading input data...
# 2025-07-12 21:36:45 Downloading - Downloading the training image......
# 2025-07-12 21:37:41 Training - Training image download completed. Training in progress...../miniconda3/lib/python3.8/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# [2025-07-12 21:37:46.562 ip-10-0-91-152.us-west-2.compute.internal:7 INFO utils.py:28] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2025-07-12 21:37:46.583 ip-10-0-91-152.us-west-2.compute.internal:7 INFO profiler_config_parser.py:111] User has disabled profiler.
# [2025-07-12:21:37:46:INFO] Imported framework sagemaker_xgboost_container.training
# [2025-07-12:21:37:46:INFO] Failed to parse hyperparameter objective value reg:squarederror to Json.
# Returning the value itself
# [2025-07-12:21:37:46:INFO] No GPUs detected (normal if no gpus installed)
# [2025-07-12:21:37:46:INFO] Running XGBoost Sagemaker in algorithm mode
# [2025-07-12:21:37:46:INFO] Determined 0 GPU(s) available on the instance.
# [2025-07-12:21:37:46:INFO] Determined delimiter of CSV input is ','
# [2025-07-12:21:37:46:INFO] Determined delimiter of CSV input is ','
# [2025-07-12:21:37:46:INFO] files path: /opt/ml/input/data/train
# [2025-07-12:21:37:46:INFO] Determined delimiter of CSV input is ','
# [2025-07-12:21:37:48:INFO] files path: /opt/ml/input/data/validation
# [2025-07-12:21:37:48:INFO] Determined delimiter of CSV input is ','
# [2025-07-12:21:37:48:INFO] Single node training.
# [2025-07-12:21:37:48:INFO] Train matrix has 87727 rows and 221 columns
# [2025-07-12:21:37:48:INFO] Validation matrix has 5485 rows
# [2025-07-12 21:37:48.264 ip-10-0-91-152.us-west-2.compute.internal:7 INFO json_config.py:92] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2025-07-12 21:37:48.265 ip-10-0-91-152.us-west-2.compute.internal:7 INFO hook.py:206] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2025-07-12 21:37:48.266 ip-10-0-91-152.us-west-2.compute.internal:7 INFO hook.py:259] Saving to /opt/ml/output/tensors
# [2025-07-12 21:37:48.266 ip-10-0-91-152.us-west-2.compute.internal:7 INFO state_store.py:77] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2025-07-12:21:37:48:INFO] Debug hook created from config
# [2025-07-12 21:37:50.586 ip-10-0-91-152.us-west-2.compute.internal:7 INFO hook.py:427] Monitoring the collections: metrics
# [2025-07-12 21:37:50.589 ip-10-0-91-152.us-west-2.compute.internal:7 INFO hook.py:491] Hook is writing from the hook with pid: 7
# [0]#011train-rmse:0.42093#011validation-rmse:0.41810
# [1]#011train-rmse:0.35377#011validation-rmse:0.35160
# [2]#011train-rmse:0.30924#011validation-rmse:0.30668
# [3]#011train-rmse:0.28339#011validation-rmse:0.28024
# [4]#011train-rmse:0.26661#011validation-rmse:0.26435
# [5]#011train-rmse:0.25799#011validation-rmse:0.25705
# [6]#011train-rmse:0.25268#011validation-rmse:0.25176
# [7]#011train-rmse:0.24709#011validation-rmse:0.24643
# [8]#011train-rmse:0.24233#011validation-rmse:0.24168
# [9]#011train-rmse:0.24053#011validation-rmse:0.24003
# [10]#011train-rmse:0.23740#011validation-rmse:0.23732
# [11]#011train-rmse:0.23536#011validation-rmse:0.23606
# [12]#011train-rmse:0.23014#011validation-rmse:0.23155
# [13]#011train-rmse:0.22884#011validation-rmse:0.23057
# [14]#011train-rmse:0.22588#011validation-rmse:0.22806
# [15]#011train-rmse:0.22517#011validation-rmse:0.22748
# [16]#011train-rmse:0.22414#011validation-rmse:0.22681
# [17]#011train-rmse:0.22263#011validation-rmse:0.22531
# [18]#011train-rmse:0.21982#011validation-rmse:0.22278
# [19]#011train-rmse:0.21735#011validation-rmse:0.22060
# [20]#011train-rmse:0.21604#011validation-rmse:0.21942
# [21]#011train-rmse:0.21497#011validation-rmse:0.21858
# [22]#011train-rmse:0.21367#011validation-rmse:0.21766
# [23]#011train-rmse:0.21266#011validation-rmse:0.21719
# [24]#011train-rmse:0.21135#011validation-rmse:0.21654
# [25]#011train-rmse:0.21061#011validation-rmse:0.21628
# [26]#011train-rmse:0.20944#011validation-rmse:0.21548
# [27]#011train-rmse:0.20811#011validation-rmse:0.21466
# [28]#011train-rmse:0.20738#011validation-rmse:0.21441
# [29]#011train-rmse:0.20658#011validation-rmse:0.21400
# [30]#011train-rmse:0.20634#011validation-rmse:0.21393
# [31]#011train-rmse:0.20586#011validation-rmse:0.21385
# [32]#011train-rmse:0.20507#011validation-rmse:0.21349
# [33]#011train-rmse:0.20477#011validation-rmse:0.21350
# [34]#011train-rmse:0.20436#011validation-rmse:0.21365
# [35]#011train-rmse:0.20378#011validation-rmse:0.21335
# [36]#011train-rmse:0.20347#011validation-rmse:0.21328
# [37]#011train-rmse:0.20296#011validation-rmse:0.21321
# [38]#011train-rmse:0.20234#011validation-rmse:0.21310
# [39]#011train-rmse:0.20143#011validation-rmse:0.21253
# [40]#011train-rmse:0.20018#011validation-rmse:0.21148
# [41]#011train-rmse:0.19950#011validation-rmse:0.21120
# [42]#011train-rmse:0.19896#011validation-rmse:0.21121
# [43]#011train-rmse:0.19856#011validation-rmse:0.21111
# [44]#011train-rmse:0.19809#011validation-rmse:0.21094
# [45]#011train-rmse:0.19772#011validation-rmse:0.21094
# [46]#011train-rmse:0.19680#011validation-rmse:0.21041
# [47]#011train-rmse:0.19668#011validation-rmse:0.21049
# [48]#011train-rmse:0.19626#011validation-rmse:0.21044
# [49]#011train-rmse:0.19557#011validation-rmse:0.21024
# [50]#011train-rmse:0.19521#011validation-rmse:0.21000
# [51]#011train-rmse:0.19449#011validation-rmse:0.20958
# [52]#011train-rmse:0.19371#011validation-rmse:0.20956
# [53]#011train-rmse:0.19331#011validation-rmse:0.20930
# [54]#011train-rmse:0.19298#011validation-rmse:0.20911
# [55]#011train-rmse:0.19264#011validation-rmse:0.20932
# [56]#011train-rmse:0.19233#011validation-rmse:0.20936
# [57]#011train-rmse:0.19164#011validation-rmse:0.20906
# [58]#011train-rmse:0.19130#011validation-rmse:0.20894
# [59]#011train-rmse:0.19082#011validation-rmse:0.20932
# [60]#011train-rmse:0.19035#011validation-rmse:0.20920
# [61]#011train-rmse:0.19005#011validation-rmse:0.20905
# [62]#011train-rmse:0.18970#011validation-rmse:0.20909
# [63]#011train-rmse:0.18927#011validation-rmse:0.20917
# [64]#011train-rmse:0.18864#011validation-rmse:0.20907
# [65]#011train-rmse:0.18818#011validation-rmse:0.20897
# [66]#011train-rmse:0.18780#011validation-rmse:0.20888
# [67]#011train-rmse:0.18740#011validation-rmse:0.20891
# [68]#011train-rmse:0.18695#011validation-rmse:0.20859
# [69]#011train-rmse:0.18671#011validation-rmse:0.20867
# [70]#011train-rmse:0.18630#011validation-rmse:0.20865
# [71]#011train-rmse:0.18585#011validation-rmse:0.20870
# [72]#011train-rmse:0.18550#011validation-rmse:0.20856
# [73]#011train-rmse:0.18512#011validation-rmse:0.20830
# [74]#011train-rmse:0.18483#011validation-rmse:0.20835
# [75]#011train-rmse:0.18450#011validation-rmse:0.20811
# [76]#011train-rmse:0.18406#011validation-rmse:0.20807
# [77]#011train-rmse:0.18375#011validation-rmse:0.20798
# [78]#011train-rmse:0.18352#011validation-rmse:0.20798
# [79]#011train-rmse:0.18324#011validation-rmse:0.20776
# [80]#011train-rmse:0.18317#011validation-rmse:0.20776
# [81]#011train-rmse:0.18291#011validation-rmse:0.20760
# [82]#011train-rmse:0.18262#011validation-rmse:0.20766
# [83]#011train-rmse:0.18220#011validation-rmse:0.20755
# [84]#011train-rmse:0.18186#011validation-rmse:0.20743
# [85]#011train-rmse:0.18164#011validation-rmse:0.20741
# [86]#011train-rmse:0.18145#011validation-rmse:0.20735
# [87]#011train-rmse:0.18082#011validation-rmse:0.20749
# [88]#011train-rmse:0.18064#011validation-rmse:0.20742
# [89]#011train-rmse:0.18030#011validation-rmse:0.20725
# [90]#011train-rmse:0.17993#011validation-rmse:0.20758
# [91]#011train-rmse:0.17956#011validation-rmse:0.20742
#
# 2025-07-12 21:39:57 Uploading - Uploading generated training model[92]#011train-rmse:0.17928#011validation-rmse:0.20739
# [93]#011train-rmse:0.17914#011validation-rmse:0.20739
# [94]#011train-rmse:0.17893#011validation-rmse:0.20741
# [95]#011train-rmse:0.17856#011validation-rmse:0.20718
# [96]#011train-rmse:0.17824#011validation-rmse:0.20672
# [97]#011train-rmse:0.17791#011validation-rmse:0.20674
# [98]#011train-rmse:0.17773#011validation-rmse:0.20671
# [99]#011train-rmse:0.17740#011validation-rmse:0.20698
#
# 2025-07-12 21:40:15 Completed - Training job completed
# Training seconds: 260
# Billable seconds: 260
# [12/Jul/25 14:40:42] INFO [wallet_modeler.train_model:115] Training completed. Model stored at: s3://wallet-training-data/sagemaker-models/wallet-xgb-231107-143515/output/model.tar.gz
# {'model_uri': 's3://wallet-training-data/sagemaker-models/wallet-xgb-231107-143515/output/model.tar.gz',
#  'training_job_name': 'wallet-xgb-231107-143515'}

# %%
modeler.train_model()
# Out:
# [12/Jul/25 14:30:09] INFO [wallet_modeler.train_model:55] Starting SageMaker XGBoost training
# [12/Jul/25 14:30:09] INFO [image_uris._processor:530] Ignoring unnecessary instance type: None.
# [12/Jul/25 14:30:09] INFO [wallet_modeler.train_model:100] Launching training job: wallet-xgb-231107-143009
# [12/Jul/25 14:30:09] INFO [telemetry_logging.wrapper:91] SageMaker Python SDK will collect telemetry to help us better understand our user's needs, diagnose issues, and deliver additional features.
# To opt out of telemetry, please disable via TelemetryOptOut parameter in SDK defaults config. For more information, refer to https://sagemaker.readthedocs.io/en/stable/overview.html#configuring-and-using-defaults-with-the-sagemaker-python-sdk.
# [12/Jul/25 14:30:09] INFO [session.submit:1053] Creating training-job with name: wallet-xgb-231107-143009
# 2025-07-12 21:30:11 Starting - Starting the training job...
# 2025-07-12 21:30:26 Starting - Preparing the instances for training...
# 2025-07-12 21:30:48 Downloading - Downloading input data...
# 2025-07-12 21:31:33 Downloading - Downloading the training image......
# 2025-07-12 21:32:44 Training - Training image download completed. Training in progress.
# 2025-07-12 21:32:44 Uploading - Uploading generated training model/miniconda3/lib/python3.8/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# [2025-07-12 21:32:34.259 ip-10-0-100-103.us-west-2.compute.internal:8 INFO utils.py:28] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2025-07-12 21:32:34.283 ip-10-0-100-103.us-west-2.compute.internal:8 INFO profiler_config_parser.py:111] User has disabled profiler.
# [2025-07-12:21:32:34:INFO] Imported framework sagemaker_xgboost_container.training
# [2025-07-12:21:32:34:INFO] Failed to parse hyperparameter objective value reg:squarederror to Json.
# Returning the value itself
# [2025-07-12:21:32:34:INFO] No GPUs detected (normal if no gpus installed)
# [2025-07-12:21:32:34:INFO] Running XGBoost Sagemaker in algorithm mode
# [2025-07-12:21:32:34:INFO] Determined 0 GPU(s) available on the instance.
# [2025-07-12:21:32:34:INFO] Determined delimiter of CSV input is ','
# [2025-07-12:21:32:34:INFO] Determined delimiter of CSV input is ','
# [2025-07-12:21:32:34:INFO] files path: /opt/ml/input/data/train
# [2025-07-12:21:32:34:INFO] Determined delimiter of CSV input is ','
# [2025-07-12:21:32:34:INFO] files path: /opt/ml/input/data/validation
# [2025-07-12:21:32:34:INFO] Determined delimiter of CSV input is ','
# [2025-07-12:21:32:34:INFO] Single node training.
# [2025-07-12:21:32:34:INFO] Train matrix has 2000 rows and 221 columns
# [2025-07-12:21:32:34:INFO] Validation matrix has 2000 rows
# [2025-07-12 21:32:34.787 ip-10-0-100-103.us-west-2.compute.internal:8 INFO json_config.py:92] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2025-07-12 21:32:34.788 ip-10-0-100-103.us-west-2.compute.internal:8 INFO hook.py:206] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2025-07-12 21:32:34.789 ip-10-0-100-103.us-west-2.compute.internal:8 INFO hook.py:259] Saving to /opt/ml/output/tensors
# [2025-07-12 21:32:34.789 ip-10-0-100-103.us-west-2.compute.internal:8 INFO state_store.py:77] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2025-07-12:21:32:34:INFO] Debug hook created from config
# [2025-07-12 21:32:34.856 ip-10-0-100-103.us-west-2.compute.internal:8 INFO hook.py:427] Monitoring the collections: metrics
# [2025-07-12 21:32:34.860 ip-10-0-100-103.us-west-2.compute.internal:8 INFO hook.py:491] Hook is writing from the hook with pid: 8
# [0]#011train-rmse:0.40005#011validation-rmse:0.42251
# [1]#011train-rmse:0.33129#011validation-rmse:0.35964
# [2]#011train-rmse:0.28648#011validation-rmse:0.32299
# [3]#011train-rmse:0.25401#011validation-rmse:0.30213
# [4]#011train-rmse:0.23313#011validation-rmse:0.29099
# [5]#011train-rmse:0.22018#011validation-rmse:0.28678
# [6]#011train-rmse:0.20716#011validation-rmse:0.28253
# [7]#011train-rmse:0.19717#011validation-rmse:0.27864
# [8]#011train-rmse:0.19372#011validation-rmse:0.27726
# [9]#011train-rmse:0.18349#011validation-rmse:0.27535
# [10]#011train-rmse:0.17646#011validation-rmse:0.27501
# [11]#011train-rmse:0.17055#011validation-rmse:0.27377
# [12]#011train-rmse:0.16472#011validation-rmse:0.27393
# [13]#011train-rmse:0.16201#011validation-rmse:0.27420
# [14]#011train-rmse:0.15884#011validation-rmse:0.27437
# [15]#011train-rmse:0.15638#011validation-rmse:0.27483
# [16]#011train-rmse:0.14970#011validation-rmse:0.27562
# [17]#011train-rmse:0.14633#011validation-rmse:0.27587
# [18]#011train-rmse:0.14457#011validation-rmse:0.27601
# [19]#011train-rmse:0.14139#011validation-rmse:0.27628
# [20]#011train-rmse:0.13793#011validation-rmse:0.27729
# [21]#011train-rmse:0.13260#011validation-rmse:0.27783
# [22]#011train-rmse:0.12847#011validation-rmse:0.27793
# [23]#011train-rmse:0.12443#011validation-rmse:0.27845
# [24]#011train-rmse:0.11937#011validation-rmse:0.27906
# [25]#011train-rmse:0.11409#011validation-rmse:0.27957
# [26]#011train-rmse:0.11035#011validation-rmse:0.27953
# [27]#011train-rmse:0.10676#011validation-rmse:0.27974
# [28]#011train-rmse:0.10209#011validation-rmse:0.28023
# [29]#011train-rmse:0.09981#011validation-rmse:0.28018
# [30]#011train-rmse:0.09749#011validation-rmse:0.28014
# [31]#011train-rmse:0.09602#011validation-rmse:0.28027
# [32]#011train-rmse:0.09339#011validation-rmse:0.27993
# [33]#011train-rmse:0.08890#011validation-rmse:0.28036
# [34]#011train-rmse:0.08776#011validation-rmse:0.28048
# [35]#011train-rmse:0.08503#011validation-rmse:0.28096
# [36]#011train-rmse:0.08252#011validation-rmse:0.28106
# [37]#011train-rmse:0.07916#011validation-rmse:0.28137
# [38]#011train-rmse:0.07842#011validation-rmse:0.28147
# [39]#011train-rmse:0.07552#011validation-rmse:0.28162
# [40]#011train-rmse:0.07147#011validation-rmse:0.28161
# [41]#011train-rmse:0.06971#011validation-rmse:0.28152
# [42]#011train-rmse:0.06743#011validation-rmse:0.28168
# [43]#011train-rmse:0.06635#011validation-rmse:0.28158
# [44]#011train-rmse:0.06577#011validation-rmse:0.28173
# [45]#011train-rmse:0.06369#011validation-rmse:0.28176
# [46]#011train-rmse:0.06123#011validation-rmse:0.28206
# [47]#011train-rmse:0.05972#011validation-rmse:0.28218
# [48]#011train-rmse:0.05818#011validation-rmse:0.28216
# [49]#011train-rmse:0.05725#011validation-rmse:0.28212
# [50]#011train-rmse:0.05573#011validation-rmse:0.28221
# [51]#011train-rmse:0.05451#011validation-rmse:0.28216
# [52]#011train-rmse:0.05298#011validation-rmse:0.28236
# [53]#011train-rmse:0.05241#011validation-rmse:0.28233
# [54]#011train-rmse:0.04963#011validation-rmse:0.28191
# [55]#011train-rmse:0.04774#011validation-rmse:0.28190
# [56]#011train-rmse:0.04710#011validation-rmse:0.28182
# [57]#011train-rmse:0.04553#011validation-rmse:0.28181
# [58]#011train-rmse:0.04475#011validation-rmse:0.28206
# [59]#011train-rmse:0.04342#011validation-rmse:0.28233
# [60]#011train-rmse:0.04217#011validation-rmse:0.28240
# [61]#011train-rmse:0.04106#011validation-rmse:0.28240
# [62]#011train-rmse:0.04057#011validation-rmse:0.28243
# [63]#011train-rmse:0.03960#011validation-rmse:0.28237
# [64]#011train-rmse:0.03846#011validation-rmse:0.28227
# [65]#011train-rmse:0.03716#011validation-rmse:0.28219
# [66]#011train-rmse:0.03550#011validation-rmse:0.28217
# [67]#011train-rmse:0.03475#011validation-rmse:0.28227
# [68]#011train-rmse:0.03350#011validation-rmse:0.28209
# [69]#011train-rmse:0.03257#011validation-rmse:0.28210
# [70]#011train-rmse:0.03158#011validation-rmse:0.28214
# [71]#011train-rmse:0.03081#011validation-rmse:0.28215
# [72]#011train-rmse:0.03016#011validation-rmse:0.28200
# [73]#011train-rmse:0.02943#011validation-rmse:0.28200
# [74]#011train-rmse:0.02890#011validation-rmse:0.28195
# [75]#011train-rmse:0.02773#011validation-rmse:0.28183
# [76]#011train-rmse:0.02710#011validation-rmse:0.28188
# [77]#011train-rmse:0.02667#011validation-rmse:0.28187
# [78]#011train-rmse:0.02573#011validation-rmse:0.28180
# [79]#011train-rmse:0.02522#011validation-rmse:0.28185
# [80]#011train-rmse:0.02436#011validation-rmse:0.28180
# [81]#011train-rmse:0.02318#011validation-rmse:0.28185
# [82]#011train-rmse:0.02230#011validation-rmse:0.28184
# [83]#011train-rmse:0.02190#011validation-rmse:0.28181
# [84]#011train-rmse:0.02148#011validation-rmse:0.28181
# [85]#011train-rmse:0.02071#011validation-rmse:0.28178
# [86]#011train-rmse:0.02017#011validation-rmse:0.28179
# [87]#011train-rmse:0.01973#011validation-rmse:0.28181
# [88]#011train-rmse:0.01917#011validation-rmse:0.28186
# [89]#011train-rmse:0.01881#011validation-rmse:0.28188
# [90]#011train-rmse:0.01853#011validation-rmse:0.28185
# [91]#011train-rmse:0.01798#011validation-rmse:0.28186
# [92]#011train-rmse:0.01771#011validation-rmse:0.28178
# [93]#011train-rmse:0.01726#011validation-rmse:0.28174
# [94]#011train-rmse:0.01682#011validation-rmse:0.28175
# [95]#011train-rmse:0.01643#011validation-rmse:0.28174
# [96]#011train-rmse:0.01597#011validation-rmse:0.28174
# [97]#011train-rmse:0.01574#011validation-rmse:0.28173
# [98]#011train-rmse:0.01540#011validation-rmse:0.28171
# [99]#011train-rmse:0.01510#011validation-rmse:0.28174
#
# 2025-07-12 21:33:02 Completed - Training job completed
# Training seconds: 135
# Billable seconds: 135
# [12/Jul/25 14:33:33] INFO [wallet_modeler.train_model:115] Training completed. Model stored at: s3://wallet-training-data/sagemaker-models/wallet-xgb-231107-143009/output/model.tar.gz
# {'model_uri': 's3://wallet-training-data/sagemaker-models/wallet-xgb-231107-143009/output/model.tar.gz',
#  'training_job_name': 'wallet-xgb-231107-143009'}

# %%
workflow_orch.training_data['x_train'].shape
