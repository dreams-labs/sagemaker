# %% [markdown]
# ### start

# %%
# pyright: reportMissingImports=false
# pyright: reportMissingModuleSource=false

import uuid
import random
import hashlib
import os
import sys
import gc
import time
import copy
import logging
import re
from itertools import chain,combinations
import pdb
import math
from pathlib import Path
import datetime
from datetime import datetime,timedelta
import json
import warnings
import yaml
from typing import Dict,Union,List,Any,Tuple
import pytest
import importlib
from dotenv import load_dotenv
import pandas as pd
import numpy as np
import IPython
import requests
import warnings
import boto3
import matplotlib as plt
import sklearn

# load_dotenv(Path("../../../Local/.env"))

# Custom format function for displaying |numbers/
pd.set_option('display.float_format', lambda x: f'{x:.12g}')
# pd.reset_option('display.float_format')

# Suppress warnings
os.environ['PYDEVD_DISABLE_FILE_VALIDATION'] = '1'
warnings.filterwarnings('ignore', message='.*frozen modules.*')
warnings.filterwarnings("ignore", message="MallocStackLogging")

# silence pygame donation request
os.environ['PYGAME_HIDE_SUPPORT_PROMPT'] = "hide"
os.environ['LOGGING_FILE'] = "../../../Local/logs/wallet_modeling.log"
os.environ['NOTIFICATION_SOUNDS_DIR'] = "../../../Local"

# Dark mode charts
plt.rcParams['figure.facecolor'] = '#181818'  # Custom background color (dark gray in this case)
plt.rcParams['axes.facecolor'] = '#181818'
plt.rcParams['text.color'] = '#afc6ba'
plt.rcParams['axes.labelcolor'] = '#afc6ba'
plt.rcParams['xtick.color'] = '#afc6ba'
plt.rcParams['ytick.color'] = '#afc6ba'
plt.rcParams['axes.titlecolor'] = '#afc6ba'
plt.rcParams['text.usetex'] = False
plt.rcParams['mathtext.default'] = 'regular'

# import local modules
# pyright: reportMissingImports=false
sys.path.append('../src')

import sage_utils.config_validation as ucv
import sage_utils.s3_utils as s3u

import sage_wallet_insights.model_evaluation as sime

import sage_wallet_modeling.wallet_modeler as wm
from sage_wallet_modeling.wallet_preprocessor import SageWalletsPreprocessor
import sage_wallet_modeling.wallet_script_modeler as sm
import sage_wallet_modeling.workflow_orchestrator as wo

import script_modeling.entry_helpers as h
# import script_modeling.temporal_cv_model_entry as tme


# import data-science modules
sys.path.append(str(Path("..") / ".." / "data-science" / "src"))
import wallet_insights.model_evaluation as wime
import utils as u
from utils import ConfigError



# reload all modules
modules = [
    ucv, s3u,
    sime,
    wm, sm, wo,
    h,
    wime,
    u,
]

# import utils as u
# Set the custom error handler
ipython = IPython.get_ipython()
# ipython.set_custom_exc((Exception,), u.notify_on_failure)

player = u.AmbientPlayer()
player.stop_all_players()

# configure logger
logger = u.setup_notebook_logger('../logs/notebook_logs.log')
logger.setLevel(logging.INFO)

from IPython.core import ultratb
ultratb.VerboseTB._tb_highlight = "bg:#b45827"


# load all configs
sage_wallets_config = ucv.load_sage_wallets_config(Path('../config/sage_wallets_config.yaml'))
sage_wallets_modeling_config = ucv.load_sage_wallets_modeling_config(Path('../config/sage_wallets_modeling_config.yaml'))


u.export_code(
    code_directories=[
        # 'config_models',
        'sage_wallet_insights',
        'sage_wallet_modeling',
        'script_modeling',
        # 'sage_utils',
    ],
    # include_config = True,
    # ipynb_notebook = 'DDA-769 coin model score dist toggle.ipynb'
    output_file="temp/sagemaker_code.py"
)

[importlib.reload(module) for module in modules]
u.notify('retro')

logger.milestone("Good morning, let's get to work")
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /Library/Application Support/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /Users/jeremymeadow/Library/Application Support/sagemaker/config.yaml
# [06/Aug/25 23:03:47] INFO [utils.export_code:1672] Consolidation complete. All files are saved in temp/sagemaker_code.py
# [06/Aug/25 23:03:47] MILESTONE [2505902246.<module>:136] Good morning, let's get to work

# %% [markdown]
# # Model Training

# %% [markdown]
# ## Concatenated Model Sequence

# %%
[importlib.reload(module) for module in modules]
sage_wallets_config = yaml.safe_load(Path('../config/sage_wallets_config.yaml').read_text(encoding='utf-8'))
sage_wallets_modeling_config = yaml.safe_load(Path('../config/sage_wallets_modeling_config.yaml').read_text(encoding='utf-8'))


workflow_orch = wo.WalletWorkflowOrchestrator(
    sage_wallets_config,
    sage_wallets_modeling_config
)
workflow_orch.load_all_training_data()
# Out:
# [06/Aug/25 22:58:09] INFO [workflow_orchestrator.load_all_training_data:119] Auto-detected date_suffixes from config: ['240106', '240306', '230809', '230908', '231008', '231107', '231207', '240205', '240405', '240505', '240604', '240704', '240803', '240902']
# [06/Aug/25 22:58:10] MILESTONE [workflow_orchestrator.load_all_training_data:139] <DEV> Loading training data for 14 periods: ['240106', '240306', '230809', '230908', '231008', '231107', '231207', '240205', '240405', '240505', '240604', '240704', '240803', '240902']
# [06/Aug/25 22:58:10] INFO [workflow_orchestrator.load_all_training_data:155] Training data loaded successfully: 109,826 total rows and 1 offsets for each date_suffix.

# %% [markdown]
# #### preprocess and concatenate

# %%
workflow_orch.concatenate_all_preprocessed_data(repreprocess_offsets=True)
# workflow_orch.concatenate_all_preprocessed_data(repreprocess_offsets=False)
# Out:
# [06/Aug/25 22:58:11] INFO [workflow_orchestrator.preprocess_all_training_data:177] Preprocessing 14 date periods...
# [06/Aug/25 22:58:11] INFO [wallet_preprocessor.preprocess_training_data:77] Starting preprocessing for SageMaker XGBoost compatibility...
# [06/Aug/25 22:58:11] INFO [wallet_preprocessor._handle_missing_values:247] Filled NaN values in 102 columns for x_train.
# [06/Aug/25 22:58:11] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed train split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/240106/train.csv
# [06/Aug/25 22:58:11] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed train_y split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/240106/train_y.csv
# [06/Aug/25 22:58:11] INFO [wallet_preprocessor.preprocess_training_data:126] Preprocessed train: 1,000 rows × 231 cols.
# [06/Aug/25 22:58:11] INFO [wallet_preprocessor._handle_missing_values:247] Filled NaN values in 102 columns for x_test.
# [06/Aug/25 22:58:11] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed test split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/240106/test.csv
# [06/Aug/25 22:58:11] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed test_y split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/240106/test_y.csv
# [06/Aug/25 22:58:11] INFO [wallet_preprocessor.preprocess_training_data:126] Preprocessed test: 1,000 rows × 231 cols.
# [06/Aug/25 22:58:11] INFO [wallet_preprocessor._handle_missing_values:247] Filled NaN values in 102 columns for x_eval.
# [06/Aug/25 22:58:11] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed eval split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/240106/eval.csv
# [06/Aug/25 22:58:11] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed eval_y split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/240106/eval_y.csv
# [06/Aug/25 22:58:11] INFO [wallet_preprocessor.preprocess_training_data:126] Preprocessed eval: 1,000 rows × 231 cols.
# [06/Aug/25 22:58:11] INFO [wallet_preprocessor._handle_missing_values:247] Filled NaN values in 102 columns for x_val.
# [06/Aug/25 22:58:11] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed val split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/240106/val.csv
# [06/Aug/25 22:58:11] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed val_y split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/240106/val_y.csv
# [06/Aug/25 22:58:11] INFO [wallet_preprocessor.preprocess_training_data:126] Preprocessed val: 1,000 rows × 231 cols.
# [06/Aug/25 22:58:11] WARNING [wallet_preprocessor.preprocess_training_data:130] Index(['offset_date', 'balance|total_usd_balance|w1', 'cluster|k5_cluster_k0',
#        'cluster|k5_cluster_k1', 'cluster|k5_cluster_k2'],
#       dtype='object')
# [06/Aug/25 22:58:11] WARNING [wallet_preprocessor._compile_training_metadata:379] Index(['offset_date', 'balance|total_usd_balance|w1', 'cluster|k5_cluster_k0',
#        'cluster|k5_cluster_k1', 'cluster|k5_cluster_k2'],
#       dtype='object')
# [06/Aug/25 22:58:11] INFO [wallet_preprocessor.preprocess_training_data:137] Saved metadata to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/240106/metadata.json
# [06/Aug/25 22:58:11] MILESTONE [wallet_preprocessor.preprocess_training_data:139] Successfully preprocessed data for '240106'.
# [06/Aug/25 22:58:11] INFO [wallet_preprocessor.preprocess_training_data:77] Starting preprocessing for SageMaker XGBoost compatibility...
# [06/Aug/25 22:58:11] INFO [wallet_preprocessor._handle_missing_values:247] Filled NaN values in 102 columns for x_train.
# [06/Aug/25 22:58:11] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed train split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/240306/train.csv
# [06/Aug/25 22:58:11] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed train_y split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/240306/train_y.csv
# [06/Aug/25 22:58:11] INFO [wallet_preprocessor.preprocess_training_data:126] Preprocessed train: 1,000 rows × 231 cols.
# [06/Aug/25 22:58:11] INFO [wallet_preprocessor._handle_missing_values:247] Filled NaN values in 102 columns for x_test.
# [06/Aug/25 22:58:11] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed test split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/240306/test.csv
# [06/Aug/25 22:58:11] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed test_y split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/240306/test_y.csv
# [06/Aug/25 22:58:11] INFO [wallet_preprocessor.preprocess_training_data:126] Preprocessed test: 1,000 rows × 231 cols.
# [06/Aug/25 22:58:11] INFO [wallet_preprocessor._handle_missing_values:247] Filled NaN values in 102 columns for x_eval.
# [06/Aug/25 22:58:11] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed eval split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/240306/eval.csv
# [06/Aug/25 22:58:11] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed eval_y split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/240306/eval_y.csv
# [06/Aug/25 22:58:11] INFO [wallet_preprocessor.preprocess_training_data:126] Preprocessed eval: 1,000 rows × 231 cols.
# [06/Aug/25 22:58:11] INFO [wallet_preprocessor._handle_missing_values:247] Filled NaN values in 102 columns for x_val.
# [06/Aug/25 22:58:11] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed val split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/240306/val.csv
# [06/Aug/25 22:58:11] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed val_y split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/240306/val_y.csv
# [06/Aug/25 22:58:11] INFO [wallet_preprocessor.preprocess_training_data:126] Preprocessed val: 1,000 rows × 231 cols.
# [06/Aug/25 22:58:11] WARNING [wallet_preprocessor.preprocess_training_data:130] Index(['offset_date', 'balance|total_usd_balance|w1', 'cluster|k5_cluster_k0',
#        'cluster|k5_cluster_k1', 'cluster|k5_cluster_k2'],
#       dtype='object')
# [06/Aug/25 22:58:11] WARNING [wallet_preprocessor._compile_training_metadata:379] Index(['offset_date', 'balance|total_usd_balance|w1', 'cluster|k5_cluster_k0',
#        'cluster|k5_cluster_k1', 'cluster|k5_cluster_k2'],
#       dtype='object')
# [06/Aug/25 22:58:11] INFO [wallet_preprocessor.preprocess_training_data:137] Saved metadata to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/240306/metadata.json
# [06/Aug/25 22:58:11] MILESTONE [wallet_preprocessor.preprocess_training_data:139] Successfully preprocessed data for '240306'.
# [06/Aug/25 22:58:11] INFO [wallet_preprocessor.preprocess_training_data:77] Starting preprocessing for SageMaker XGBoost compatibility...
# [06/Aug/25 22:58:11] INFO [wallet_preprocessor._handle_missing_values:247] Filled NaN values in 102 columns for x_train.
# [06/Aug/25 22:58:11] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed train split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/230809/train.csv
# [06/Aug/25 22:58:11] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed train_y split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/230809/train_y.csv
# [06/Aug/25 22:58:11] INFO [wallet_preprocessor.preprocess_training_data:126] Preprocessed train: 1,000 rows × 231 cols.
# [06/Aug/25 22:58:11] INFO [wallet_preprocessor._handle_missing_values:247] Filled NaN values in 102 columns for x_test.
# [06/Aug/25 22:58:12] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed test split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/230809/test.csv
# [06/Aug/25 22:58:12] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed test_y split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/230809/test_y.csv
# [06/Aug/25 22:58:12] INFO [wallet_preprocessor.preprocess_training_data:126] Preprocessed test: 1,000 rows × 231 cols.
# [06/Aug/25 22:58:12] INFO [wallet_preprocessor._handle_missing_values:247] Filled NaN values in 102 columns for x_eval.
# [06/Aug/25 22:58:12] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed eval split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/230809/eval.csv
# [06/Aug/25 22:58:12] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed eval_y split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/230809/eval_y.csv
# [06/Aug/25 22:58:12] INFO [wallet_preprocessor.preprocess_training_data:126] Preprocessed eval: 669 rows × 231 cols.
# [06/Aug/25 22:58:12] INFO [wallet_preprocessor._handle_missing_values:247] Filled NaN values in 102 columns for x_val.
# [06/Aug/25 22:58:12] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed val split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/230809/val.csv
# [06/Aug/25 22:58:12] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed val_y split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/230809/val_y.csv
# [06/Aug/25 22:58:12] INFO [wallet_preprocessor.preprocess_training_data:126] Preprocessed val: 1,000 rows × 231 cols.
# [06/Aug/25 22:58:12] WARNING [wallet_preprocessor.preprocess_training_data:130] Index(['offset_date', 'balance|total_usd_balance|w1', 'cluster|k5_cluster_k0',
#        'cluster|k5_cluster_k1', 'cluster|k5_cluster_k2'],
#       dtype='object')
# [06/Aug/25 22:58:12] WARNING [wallet_preprocessor._compile_training_metadata:379] Index(['offset_date', 'balance|total_usd_balance|w1', 'cluster|k5_cluster_k0',
#        'cluster|k5_cluster_k1', 'cluster|k5_cluster_k2'],
#       dtype='object')
# [06/Aug/25 22:58:12] INFO [wallet_preprocessor.preprocess_training_data:137] Saved metadata to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/230809/metadata.json
# [06/Aug/25 22:58:12] MILESTONE [wallet_preprocessor.preprocess_training_data:139] Successfully preprocessed data for '230809'.
# [06/Aug/25 22:58:12] INFO [wallet_preprocessor.preprocess_training_data:77] Starting preprocessing for SageMaker XGBoost compatibility...
# [06/Aug/25 22:58:12] INFO [wallet_preprocessor._handle_missing_values:247] Filled NaN values in 102 columns for x_train.
# [06/Aug/25 22:58:12] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed train split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/230908/train.csv
# [06/Aug/25 22:58:12] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed train_y split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/230908/train_y.csv
# [06/Aug/25 22:58:12] INFO [wallet_preprocessor.preprocess_training_data:126] Preprocessed train: 1,000 rows × 231 cols.
# [06/Aug/25 22:58:12] INFO [wallet_preprocessor._handle_missing_values:247] Filled NaN values in 102 columns for x_test.
# [06/Aug/25 22:58:12] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed test split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/230908/test.csv
# [06/Aug/25 22:58:12] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed test_y split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/230908/test_y.csv
# [06/Aug/25 22:58:12] INFO [wallet_preprocessor.preprocess_training_data:126] Preprocessed test: 1,000 rows × 231 cols.
# [06/Aug/25 22:58:12] INFO [wallet_preprocessor._handle_missing_values:247] Filled NaN values in 102 columns for x_eval.
# [06/Aug/25 22:58:12] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed eval split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/230908/eval.csv
# [06/Aug/25 22:58:12] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed eval_y split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/230908/eval_y.csv
# [06/Aug/25 22:58:12] INFO [wallet_preprocessor.preprocess_training_data:126] Preprocessed eval: 585 rows × 231 cols.
# [06/Aug/25 22:58:12] INFO [wallet_preprocessor._handle_missing_values:247] Filled NaN values in 94 columns for x_val.
# [06/Aug/25 22:58:12] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed val split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/230908/val.csv
# [06/Aug/25 22:58:12] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed val_y split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/230908/val_y.csv
# [06/Aug/25 22:58:12] INFO [wallet_preprocessor.preprocess_training_data:126] Preprocessed val: 1,000 rows × 231 cols.
# [06/Aug/25 22:58:12] WARNING [wallet_preprocessor.preprocess_training_data:130] Index(['offset_date', 'balance|total_usd_balance|w1', 'cluster|k5_cluster_k0',
#        'cluster|k5_cluster_k1', 'cluster|k5_cluster_k2'],
#       dtype='object')
# [06/Aug/25 22:58:12] WARNING [wallet_preprocessor._compile_training_metadata:379] Index(['offset_date', 'balance|total_usd_balance|w1', 'cluster|k5_cluster_k0',
#        'cluster|k5_cluster_k1', 'cluster|k5_cluster_k2'],
#       dtype='object')
# [06/Aug/25 22:58:12] INFO [wallet_preprocessor.preprocess_training_data:137] Saved metadata to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/230908/metadata.json
# [06/Aug/25 22:58:12] MILESTONE [wallet_preprocessor.preprocess_training_data:139] Successfully preprocessed data for '230908'.
# [06/Aug/25 22:58:12] INFO [wallet_preprocessor.preprocess_training_data:77] Starting preprocessing for SageMaker XGBoost compatibility...
# [06/Aug/25 22:58:12] INFO [wallet_preprocessor._handle_missing_values:247] Filled NaN values in 94 columns for x_train.
# [06/Aug/25 22:58:12] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed train split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/231008/train.csv
# [06/Aug/25 22:58:12] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed train_y split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/231008/train_y.csv
# [06/Aug/25 22:58:12] INFO [wallet_preprocessor.preprocess_training_data:126] Preprocessed train: 1,000 rows × 231 cols.
# [06/Aug/25 22:58:12] INFO [wallet_preprocessor._handle_missing_values:247] Filled NaN values in 94 columns for x_test.
# [06/Aug/25 22:58:12] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed test split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/231008/test.csv
# [06/Aug/25 22:58:12] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed test_y split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/231008/test_y.csv
# [06/Aug/25 22:58:12] INFO [wallet_preprocessor.preprocess_training_data:126] Preprocessed test: 1,000 rows × 231 cols.
# [06/Aug/25 22:58:12] INFO [wallet_preprocessor._handle_missing_values:247] Filled NaN values in 94 columns for x_eval.
# [06/Aug/25 22:58:12] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed eval split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/231008/eval.csv
# [06/Aug/25 22:58:12] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed eval_y split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/231008/eval_y.csv
# [06/Aug/25 22:58:12] INFO [wallet_preprocessor.preprocess_training_data:126] Preprocessed eval: 660 rows × 231 cols.
# [06/Aug/25 22:58:12] INFO [wallet_preprocessor._handle_missing_values:247] Filled NaN values in 102 columns for x_val.
# [06/Aug/25 22:58:12] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed val split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/231008/val.csv
# [06/Aug/25 22:58:13] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed val_y split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/231008/val_y.csv
# [06/Aug/25 22:58:13] INFO [wallet_preprocessor.preprocess_training_data:126] Preprocessed val: 1,000 rows × 231 cols.
# [06/Aug/25 22:58:13] WARNING [wallet_preprocessor.preprocess_training_data:130] Index(['offset_date', 'balance|total_usd_balance|w1', 'cluster|k5_cluster_k0',
#        'cluster|k5_cluster_k1', 'cluster|k5_cluster_k2'],
#       dtype='object')
# [06/Aug/25 22:58:13] WARNING [wallet_preprocessor._compile_training_metadata:379] Index(['offset_date', 'balance|total_usd_balance|w1', 'cluster|k5_cluster_k0',
#        'cluster|k5_cluster_k1', 'cluster|k5_cluster_k2'],
#       dtype='object')
# [06/Aug/25 22:58:13] INFO [wallet_preprocessor.preprocess_training_data:137] Saved metadata to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/231008/metadata.json
# [06/Aug/25 22:58:13] MILESTONE [wallet_preprocessor.preprocess_training_data:139] Successfully preprocessed data for '231008'.
# [06/Aug/25 22:58:13] INFO [wallet_preprocessor.preprocess_training_data:77] Starting preprocessing for SageMaker XGBoost compatibility...
# [06/Aug/25 22:58:13] INFO [wallet_preprocessor._handle_missing_values:247] Filled NaN values in 102 columns for x_train.
# [06/Aug/25 22:58:13] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed train split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/231107/train.csv
# [06/Aug/25 22:58:13] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed train_y split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/231107/train_y.csv
# [06/Aug/25 22:58:13] INFO [wallet_preprocessor.preprocess_training_data:126] Preprocessed train: 1,000 rows × 231 cols.
# [06/Aug/25 22:58:13] INFO [wallet_preprocessor._handle_missing_values:247] Filled NaN values in 102 columns for x_test.
# [06/Aug/25 22:58:13] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed test split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/231107/test.csv
# [06/Aug/25 22:58:13] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed test_y split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/231107/test_y.csv
# [06/Aug/25 22:58:13] INFO [wallet_preprocessor.preprocess_training_data:126] Preprocessed test: 1,000 rows × 231 cols.
# [06/Aug/25 22:58:13] INFO [wallet_preprocessor._handle_missing_values:247] Filled NaN values in 102 columns for x_eval.
# [06/Aug/25 22:58:13] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed eval split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/231107/eval.csv
# [06/Aug/25 22:58:13] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed eval_y split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/231107/eval_y.csv
# [06/Aug/25 22:58:13] INFO [wallet_preprocessor.preprocess_training_data:126] Preprocessed eval: 999 rows × 231 cols.
# [06/Aug/25 22:58:13] INFO [wallet_preprocessor._handle_missing_values:247] Filled NaN values in 102 columns for x_val.
# [06/Aug/25 22:58:13] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed val split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/231107/val.csv
# [06/Aug/25 22:58:13] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed val_y split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/231107/val_y.csv
# [06/Aug/25 22:58:13] INFO [wallet_preprocessor.preprocess_training_data:126] Preprocessed val: 1,000 rows × 231 cols.
# [06/Aug/25 22:58:13] WARNING [wallet_preprocessor.preprocess_training_data:130] Index(['offset_date', 'balance|total_usd_balance|w1', 'cluster|k5_cluster_k0',
#        'cluster|k5_cluster_k1', 'cluster|k5_cluster_k2'],
#       dtype='object')
# [06/Aug/25 22:58:13] WARNING [wallet_preprocessor._compile_training_metadata:379] Index(['offset_date', 'balance|total_usd_balance|w1', 'cluster|k5_cluster_k0',
#        'cluster|k5_cluster_k1', 'cluster|k5_cluster_k2'],
#       dtype='object')
# [06/Aug/25 22:58:13] INFO [wallet_preprocessor.preprocess_training_data:137] Saved metadata to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/231107/metadata.json
# [06/Aug/25 22:58:13] MILESTONE [wallet_preprocessor.preprocess_training_data:139] Successfully preprocessed data for '231107'.
# [06/Aug/25 22:58:13] INFO [wallet_preprocessor.preprocess_training_data:77] Starting preprocessing for SageMaker XGBoost compatibility...
# [06/Aug/25 22:58:13] INFO [wallet_preprocessor._handle_missing_values:247] Filled NaN values in 101 columns for x_train.
# [06/Aug/25 22:58:13] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed train split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/231207/train.csv
# [06/Aug/25 22:58:13] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed train_y split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/231207/train_y.csv
# [06/Aug/25 22:58:13] INFO [wallet_preprocessor.preprocess_training_data:126] Preprocessed train: 1,000 rows × 231 cols.
# [06/Aug/25 22:58:13] INFO [wallet_preprocessor._handle_missing_values:247] Filled NaN values in 101 columns for x_test.
# [06/Aug/25 22:58:13] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed test split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/231207/test.csv
# [06/Aug/25 22:58:13] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed test_y split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/231207/test_y.csv
# [06/Aug/25 22:58:13] INFO [wallet_preprocessor.preprocess_training_data:126] Preprocessed test: 1,000 rows × 231 cols.
# [06/Aug/25 22:58:13] INFO [wallet_preprocessor._handle_missing_values:247] Filled NaN values in 102 columns for x_eval.
# [06/Aug/25 22:58:13] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed eval split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/231207/eval.csv
# [06/Aug/25 22:58:13] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed eval_y split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/231207/eval_y.csv
# [06/Aug/25 22:58:13] INFO [wallet_preprocessor.preprocess_training_data:126] Preprocessed eval: 1,000 rows × 231 cols.
# [06/Aug/25 22:58:13] INFO [wallet_preprocessor._handle_missing_values:247] Filled NaN values in 102 columns for x_val.
# [06/Aug/25 22:58:13] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed val split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/231207/val.csv
# [06/Aug/25 22:58:13] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed val_y split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/231207/val_y.csv
# [06/Aug/25 22:58:13] INFO [wallet_preprocessor.preprocess_training_data:126] Preprocessed val: 1,000 rows × 231 cols.
# [06/Aug/25 22:58:13] WARNING [wallet_preprocessor.preprocess_training_data:130] Index(['offset_date', 'balance|total_usd_balance|w1', 'cluster|k5_cluster_k0',
#        'cluster|k5_cluster_k1', 'cluster|k5_cluster_k2'],
#       dtype='object')
# [06/Aug/25 22:58:13] WARNING [wallet_preprocessor._compile_training_metadata:379] Index(['offset_date', 'balance|total_usd_balance|w1', 'cluster|k5_cluster_k0',
#        'cluster|k5_cluster_k1', 'cluster|k5_cluster_k2'],
#       dtype='object')
# [06/Aug/25 22:58:13] INFO [wallet_preprocessor.preprocess_training_data:137] Saved metadata to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/231207/metadata.json
# [06/Aug/25 22:58:13] MILESTONE [wallet_preprocessor.preprocess_training_data:139] Successfully preprocessed data for '231207'.
# [06/Aug/25 22:58:13] INFO [wallet_preprocessor.preprocess_training_data:77] Starting preprocessing for SageMaker XGBoost compatibility...
# [06/Aug/25 22:58:13] INFO [wallet_preprocessor._handle_missing_values:247] Filled NaN values in 102 columns for x_train.
# [06/Aug/25 22:58:13] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed train split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/240205/train.csv
# [06/Aug/25 22:58:13] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed train_y split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/240205/train_y.csv
# [06/Aug/25 22:58:13] INFO [wallet_preprocessor.preprocess_training_data:126] Preprocessed train: 1,000 rows × 231 cols.
# [06/Aug/25 22:58:13] INFO [wallet_preprocessor._handle_missing_values:247] Filled NaN values in 102 columns for x_test.
# [06/Aug/25 22:58:13] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed test split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/240205/test.csv
# [06/Aug/25 22:58:14] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed test_y split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/240205/test_y.csv
# [06/Aug/25 22:58:14] INFO [wallet_preprocessor.preprocess_training_data:126] Preprocessed test: 1,000 rows × 231 cols.
# [06/Aug/25 22:58:14] INFO [wallet_preprocessor._handle_missing_values:247] Filled NaN values in 102 columns for x_eval.
# [06/Aug/25 22:58:14] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed eval split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/240205/eval.csv
# [06/Aug/25 22:58:14] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed eval_y split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/240205/eval_y.csv
# [06/Aug/25 22:58:14] INFO [wallet_preprocessor.preprocess_training_data:126] Preprocessed eval: 1,000 rows × 231 cols.
# [06/Aug/25 22:58:14] INFO [wallet_preprocessor._handle_missing_values:247] Filled NaN values in 101 columns for x_val.
# [06/Aug/25 22:58:14] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed val split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/240205/val.csv
# [06/Aug/25 22:58:14] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed val_y split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/240205/val_y.csv
# [06/Aug/25 22:58:14] INFO [wallet_preprocessor.preprocess_training_data:126] Preprocessed val: 1,000 rows × 231 cols.
# [06/Aug/25 22:58:14] WARNING [wallet_preprocessor.preprocess_training_data:130] Index(['offset_date', 'balance|total_usd_balance|w1', 'cluster|k5_cluster_k0',
#        'cluster|k5_cluster_k1', 'cluster|k5_cluster_k2'],
#       dtype='object')
# [06/Aug/25 22:58:14] WARNING [wallet_preprocessor._compile_training_metadata:379] Index(['offset_date', 'balance|total_usd_balance|w1', 'cluster|k5_cluster_k0',
#        'cluster|k5_cluster_k1', 'cluster|k5_cluster_k2'],
#       dtype='object')
# [06/Aug/25 22:58:14] INFO [wallet_preprocessor.preprocess_training_data:137] Saved metadata to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/240205/metadata.json
# [06/Aug/25 22:58:14] MILESTONE [wallet_preprocessor.preprocess_training_data:139] Successfully preprocessed data for '240205'.
# [06/Aug/25 22:58:14] INFO [wallet_preprocessor.preprocess_training_data:77] Starting preprocessing for SageMaker XGBoost compatibility...
# [06/Aug/25 22:58:14] INFO [wallet_preprocessor._handle_missing_values:247] Filled NaN values in 101 columns for x_train.
# [06/Aug/25 22:58:14] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed train split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/240405/train.csv
# [06/Aug/25 22:58:14] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed train_y split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/240405/train_y.csv
# [06/Aug/25 22:58:14] INFO [wallet_preprocessor.preprocess_training_data:126] Preprocessed train: 1,000 rows × 231 cols.
# [06/Aug/25 22:58:14] INFO [wallet_preprocessor._handle_missing_values:247] Filled NaN values in 102 columns for x_test.
# [06/Aug/25 22:58:14] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed test split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/240405/test.csv
# [06/Aug/25 22:58:14] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed test_y split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/240405/test_y.csv
# [06/Aug/25 22:58:14] INFO [wallet_preprocessor.preprocess_training_data:126] Preprocessed test: 1,000 rows × 231 cols.
# [06/Aug/25 22:58:14] INFO [wallet_preprocessor._handle_missing_values:247] Filled NaN values in 102 columns for x_eval.
# [06/Aug/25 22:58:14] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed eval split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/240405/eval.csv
# [06/Aug/25 22:58:14] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed eval_y split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/240405/eval_y.csv
# [06/Aug/25 22:58:14] INFO [wallet_preprocessor.preprocess_training_data:126] Preprocessed eval: 1,000 rows × 231 cols.
# [06/Aug/25 22:58:14] INFO [wallet_preprocessor._handle_missing_values:247] Filled NaN values in 102 columns for x_val.
# [06/Aug/25 22:58:14] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed val split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/240405/val.csv
# [06/Aug/25 22:58:14] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed val_y split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/240405/val_y.csv
# [06/Aug/25 22:58:14] INFO [wallet_preprocessor.preprocess_training_data:126] Preprocessed val: 1,000 rows × 231 cols.
# [06/Aug/25 22:58:14] WARNING [wallet_preprocessor.preprocess_training_data:130] Index(['offset_date', 'balance|total_usd_balance|w1', 'cluster|k5_cluster_k0',
#        'cluster|k5_cluster_k1', 'cluster|k5_cluster_k2'],
#       dtype='object')
# [06/Aug/25 22:58:14] WARNING [wallet_preprocessor._compile_training_metadata:379] Index(['offset_date', 'balance|total_usd_balance|w1', 'cluster|k5_cluster_k0',
#        'cluster|k5_cluster_k1', 'cluster|k5_cluster_k2'],
#       dtype='object')
# [06/Aug/25 22:58:14] INFO [wallet_preprocessor.preprocess_training_data:137] Saved metadata to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/240405/metadata.json
# [06/Aug/25 22:58:14] MILESTONE [wallet_preprocessor.preprocess_training_data:139] Successfully preprocessed data for '240405'.
# [06/Aug/25 22:58:14] INFO [wallet_preprocessor.preprocess_training_data:77] Starting preprocessing for SageMaker XGBoost compatibility...
# [06/Aug/25 22:58:14] INFO [wallet_preprocessor._handle_missing_values:247] Filled NaN values in 101 columns for x_train.
# [06/Aug/25 22:58:14] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed train split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/240505/train.csv
# [06/Aug/25 22:58:14] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed train_y split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/240505/train_y.csv
# [06/Aug/25 22:58:14] INFO [wallet_preprocessor.preprocess_training_data:126] Preprocessed train: 1,000 rows × 231 cols.
# [06/Aug/25 22:58:14] INFO [wallet_preprocessor._handle_missing_values:247] Filled NaN values in 102 columns for x_test.
# [06/Aug/25 22:58:14] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed test split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/240505/test.csv
# [06/Aug/25 22:58:14] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed test_y split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/240505/test_y.csv
# [06/Aug/25 22:58:14] INFO [wallet_preprocessor.preprocess_training_data:126] Preprocessed test: 1,000 rows × 231 cols.
# [06/Aug/25 22:58:14] INFO [wallet_preprocessor._handle_missing_values:247] Filled NaN values in 102 columns for x_eval.
# [06/Aug/25 22:58:14] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed eval split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/240505/eval.csv
# [06/Aug/25 22:58:14] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed eval_y split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/240505/eval_y.csv
# [06/Aug/25 22:58:14] INFO [wallet_preprocessor.preprocess_training_data:126] Preprocessed eval: 1,000 rows × 231 cols.
# [06/Aug/25 22:58:14] INFO [wallet_preprocessor._handle_missing_values:247] Filled NaN values in 101 columns for x_val.
# [06/Aug/25 22:58:14] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed val split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/240505/val.csv
# [06/Aug/25 22:58:14] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed val_y split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/240505/val_y.csv
# [06/Aug/25 22:58:14] INFO [wallet_preprocessor.preprocess_training_data:126] Preprocessed val: 1,000 rows × 231 cols.
# [06/Aug/25 22:58:14] WARNING [wallet_preprocessor.preprocess_training_data:130] Index(['offset_date', 'balance|total_usd_balance|w1', 'cluster|k5_cluster_k0',
#        'cluster|k5_cluster_k1', 'cluster|k5_cluster_k2'],
#       dtype='object')
# [06/Aug/25 22:58:14] WARNING [wallet_preprocessor._compile_training_metadata:379] Index(['offset_date', 'balance|total_usd_balance|w1', 'cluster|k5_cluster_k0',
#        'cluster|k5_cluster_k1', 'cluster|k5_cluster_k2'],
#       dtype='object')
# [06/Aug/25 22:58:14] INFO [wallet_preprocessor.preprocess_training_data:137] Saved metadata to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/240505/metadata.json
# [06/Aug/25 22:58:14] MILESTONE [wallet_preprocessor.preprocess_training_data:139] Successfully preprocessed data for '240505'.
# [06/Aug/25 22:58:14] INFO [wallet_preprocessor.preprocess_training_data:77] Starting preprocessing for SageMaker XGBoost compatibility...
# [06/Aug/25 22:58:14] INFO [wallet_preprocessor._handle_missing_values:247] Filled NaN values in 102 columns for x_train.
# [06/Aug/25 22:58:15] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed train split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/240604/train.csv
# [06/Aug/25 22:58:15] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed train_y split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/240604/train_y.csv
# [06/Aug/25 22:58:15] INFO [wallet_preprocessor.preprocess_training_data:126] Preprocessed train: 1,000 rows × 231 cols.
# [06/Aug/25 22:58:15] INFO [wallet_preprocessor._handle_missing_values:247] Filled NaN values in 102 columns for x_test.
# [06/Aug/25 22:58:15] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed test split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/240604/test.csv
# [06/Aug/25 22:58:15] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed test_y split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/240604/test_y.csv
# [06/Aug/25 22:58:15] INFO [wallet_preprocessor.preprocess_training_data:126] Preprocessed test: 1,000 rows × 231 cols.
# [06/Aug/25 22:58:15] INFO [wallet_preprocessor._handle_missing_values:247] Filled NaN values in 101 columns for x_eval.
# [06/Aug/25 22:58:15] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed eval split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/240604/eval.csv
# [06/Aug/25 22:58:15] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed eval_y split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/240604/eval_y.csv
# [06/Aug/25 22:58:15] INFO [wallet_preprocessor.preprocess_training_data:126] Preprocessed eval: 1,000 rows × 231 cols.
# [06/Aug/25 22:58:15] INFO [wallet_preprocessor._handle_missing_values:247] Filled NaN values in 102 columns for x_val.
# [06/Aug/25 22:58:15] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed val split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/240604/val.csv
# [06/Aug/25 22:58:15] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed val_y split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/240604/val_y.csv
# [06/Aug/25 22:58:15] INFO [wallet_preprocessor.preprocess_training_data:126] Preprocessed val: 1,000 rows × 231 cols.
# [06/Aug/25 22:58:15] WARNING [wallet_preprocessor.preprocess_training_data:130] Index(['offset_date', 'balance|total_usd_balance|w1', 'cluster|k5_cluster_k0',
#        'cluster|k5_cluster_k1', 'cluster|k5_cluster_k2'],
#       dtype='object')
# [06/Aug/25 22:58:15] WARNING [wallet_preprocessor._compile_training_metadata:379] Index(['offset_date', 'balance|total_usd_balance|w1', 'cluster|k5_cluster_k0',
#        'cluster|k5_cluster_k1', 'cluster|k5_cluster_k2'],
#       dtype='object')
# [06/Aug/25 22:58:15] INFO [wallet_preprocessor.preprocess_training_data:137] Saved metadata to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/240604/metadata.json
# [06/Aug/25 22:58:15] MILESTONE [wallet_preprocessor.preprocess_training_data:139] Successfully preprocessed data for '240604'.
# [06/Aug/25 22:58:15] INFO [wallet_preprocessor.preprocess_training_data:77] Starting preprocessing for SageMaker XGBoost compatibility...
# [06/Aug/25 22:58:15] INFO [wallet_preprocessor._handle_missing_values:247] Filled NaN values in 102 columns for x_train.
# [06/Aug/25 22:58:15] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed train split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/240704/train.csv
# [06/Aug/25 22:58:15] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed train_y split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/240704/train_y.csv
# [06/Aug/25 22:58:15] INFO [wallet_preprocessor.preprocess_training_data:126] Preprocessed train: 1,000 rows × 231 cols.
# [06/Aug/25 22:58:15] INFO [wallet_preprocessor._handle_missing_values:247] Filled NaN values in 102 columns for x_test.
# [06/Aug/25 22:58:15] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed test split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/240704/test.csv
# [06/Aug/25 22:58:15] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed test_y split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/240704/test_y.csv
# [06/Aug/25 22:58:15] INFO [wallet_preprocessor.preprocess_training_data:126] Preprocessed test: 1,000 rows × 231 cols.
# [06/Aug/25 22:58:15] INFO [wallet_preprocessor._handle_missing_values:247] Filled NaN values in 102 columns for x_eval.
# [06/Aug/25 22:58:15] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed eval split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/240704/eval.csv
# [06/Aug/25 22:58:15] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed eval_y split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/240704/eval_y.csv
# [06/Aug/25 22:58:15] INFO [wallet_preprocessor.preprocess_training_data:126] Preprocessed eval: 1,000 rows × 231 cols.
# [06/Aug/25 22:58:15] INFO [wallet_preprocessor._handle_missing_values:247] Filled NaN values in 102 columns for x_val.
# [06/Aug/25 22:58:15] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed val split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/240704/val.csv
# [06/Aug/25 22:58:15] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed val_y split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/240704/val_y.csv
# [06/Aug/25 22:58:15] INFO [wallet_preprocessor.preprocess_training_data:126] Preprocessed val: 1,000 rows × 231 cols.
# [06/Aug/25 22:58:15] WARNING [wallet_preprocessor.preprocess_training_data:130] Index(['offset_date', 'balance|total_usd_balance|w1', 'cluster|k5_cluster_k0',
#        'cluster|k5_cluster_k1', 'cluster|k5_cluster_k2'],
#       dtype='object')
# [06/Aug/25 22:58:15] WARNING [wallet_preprocessor._compile_training_metadata:379] Index(['offset_date', 'balance|total_usd_balance|w1', 'cluster|k5_cluster_k0',
#        'cluster|k5_cluster_k1', 'cluster|k5_cluster_k2'],
#       dtype='object')
# [06/Aug/25 22:58:15] INFO [wallet_preprocessor.preprocess_training_data:137] Saved metadata to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/240704/metadata.json
# [06/Aug/25 22:58:15] MILESTONE [wallet_preprocessor.preprocess_training_data:139] Successfully preprocessed data for '240704'.
# [06/Aug/25 22:58:15] INFO [wallet_preprocessor.preprocess_training_data:77] Starting preprocessing for SageMaker XGBoost compatibility...
# [06/Aug/25 22:58:15] INFO [wallet_preprocessor._handle_missing_values:247] Filled NaN values in 102 columns for x_train.
# [06/Aug/25 22:58:15] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed train split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/240803/train.csv
# [06/Aug/25 22:58:15] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed train_y split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/240803/train_y.csv
# [06/Aug/25 22:58:15] INFO [wallet_preprocessor.preprocess_training_data:126] Preprocessed train: 1,000 rows × 231 cols.
# [06/Aug/25 22:58:15] INFO [wallet_preprocessor._handle_missing_values:247] Filled NaN values in 102 columns for x_test.
# [06/Aug/25 22:58:16] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed test split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/240803/test.csv
# [06/Aug/25 22:58:16] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed test_y split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/240803/test_y.csv
# [06/Aug/25 22:58:16] INFO [wallet_preprocessor.preprocess_training_data:126] Preprocessed test: 1,000 rows × 231 cols.
# [06/Aug/25 22:58:16] INFO [wallet_preprocessor._handle_missing_values:247] Filled NaN values in 102 columns for x_eval.
# [06/Aug/25 22:58:16] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed eval split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/240803/eval.csv
# [06/Aug/25 22:58:16] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed eval_y split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/240803/eval_y.csv
# [06/Aug/25 22:58:16] INFO [wallet_preprocessor.preprocess_training_data:126] Preprocessed eval: 1,000 rows × 231 cols.
# [06/Aug/25 22:58:16] INFO [wallet_preprocessor._handle_missing_values:247] Filled NaN values in 102 columns for x_val.
# [06/Aug/25 22:58:16] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed val split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/240803/val.csv
# [06/Aug/25 22:58:16] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed val_y split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/240803/val_y.csv
# [06/Aug/25 22:58:16] INFO [wallet_preprocessor.preprocess_training_data:126] Preprocessed val: 1,000 rows × 231 cols.
# [06/Aug/25 22:58:16] WARNING [wallet_preprocessor.preprocess_training_data:130] Index(['offset_date', 'balance|total_usd_balance|w1', 'cluster|k5_cluster_k0',
#        'cluster|k5_cluster_k1', 'cluster|k5_cluster_k2'],
#       dtype='object')
# [06/Aug/25 22:58:16] WARNING [wallet_preprocessor._compile_training_metadata:379] Index(['offset_date', 'balance|total_usd_balance|w1', 'cluster|k5_cluster_k0',
#        'cluster|k5_cluster_k1', 'cluster|k5_cluster_k2'],
#       dtype='object')
# [06/Aug/25 22:58:16] INFO [wallet_preprocessor.preprocess_training_data:137] Saved metadata to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/240803/metadata.json
# [06/Aug/25 22:58:16] MILESTONE [wallet_preprocessor.preprocess_training_data:139] Successfully preprocessed data for '240803'.
# [06/Aug/25 22:58:16] INFO [wallet_preprocessor.preprocess_training_data:77] Starting preprocessing for SageMaker XGBoost compatibility...
# [06/Aug/25 22:58:16] INFO [wallet_preprocessor._handle_missing_values:247] Filled NaN values in 102 columns for x_train.
# [06/Aug/25 22:58:16] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed train split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/240902/train.csv
# [06/Aug/25 22:58:16] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed train_y split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/240902/train_y.csv
# [06/Aug/25 22:58:16] INFO [wallet_preprocessor.preprocess_training_data:126] Preprocessed train: 1,000 rows × 231 cols.
# [06/Aug/25 22:58:16] INFO [wallet_preprocessor._handle_missing_values:247] Filled NaN values in 102 columns for x_test.
# [06/Aug/25 22:58:16] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed test split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/240902/test.csv
# [06/Aug/25 22:58:16] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed test_y split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/240902/test_y.csv
# [06/Aug/25 22:58:16] INFO [wallet_preprocessor.preprocess_training_data:126] Preprocessed test: 1,000 rows × 231 cols.
# [06/Aug/25 22:58:16] INFO [wallet_preprocessor._handle_missing_values:247] Filled NaN values in 102 columns for x_eval.
# [06/Aug/25 22:58:16] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed eval split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/240902/eval.csv
# [06/Aug/25 22:58:16] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed eval_y split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/240902/eval_y.csv
# [06/Aug/25 22:58:16] INFO [wallet_preprocessor.preprocess_training_data:126] Preprocessed eval: 1,000 rows × 231 cols.
# [06/Aug/25 22:58:16] INFO [wallet_preprocessor._handle_missing_values:247] Filled NaN values in 102 columns for x_val.
# [06/Aug/25 22:58:16] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed val split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/240902/val.csv
# [06/Aug/25 22:58:16] INFO [wallet_preprocessor._save_preprocessed_df:408] Saved preprocessed val_y split to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/240902/val_y.csv
# [06/Aug/25 22:58:16] INFO [wallet_preprocessor.preprocess_training_data:126] Preprocessed val: 1,000 rows × 231 cols.
# [06/Aug/25 22:58:16] WARNING [wallet_preprocessor.preprocess_training_data:130] Index(['offset_date', 'balance|total_usd_balance|w1', 'cluster|k5_cluster_k0',
#        'cluster|k5_cluster_k1', 'cluster|k5_cluster_k2'],
#       dtype='object')
# [06/Aug/25 22:58:16] WARNING [wallet_preprocessor._compile_training_metadata:379] Index(['offset_date', 'balance|total_usd_balance|w1', 'cluster|k5_cluster_k0',
#        'cluster|k5_cluster_k1', 'cluster|k5_cluster_k2'],
#       dtype='object')
# [06/Aug/25 22:58:16] INFO [wallet_preprocessor.preprocess_training_data:137] Saved metadata to ../s3_uploads/wallet_training_data_preprocessed/dda_947_x_in_cont_v6_dev/240902/metadata.json
# [06/Aug/25 22:58:16] MILESTONE [wallet_preprocessor.preprocess_training_data:139] Successfully preprocessed data for '240902'.
# [06/Aug/25 22:58:16] INFO [workflow_orchestrator.preprocess_all_training_data:202] Preprocessing complete for all 14 dates.
# [06/Aug/25 22:58:16] INFO [workflow_orchestrator.concatenate_all_preprocessed_data:226] Beginning concatenation of preprocessed data...
# [06/Aug/25 22:58:16] INFO [workflow_orchestrator.concatenate_all_preprocessed_data:271] Saved concatenated train.csv with 2000 rows to ../s3_uploads/wallet_training_data_concatenated/dda_947_x_in_cont_v6_dev/train.csv
# [06/Aug/25 22:58:17] INFO [workflow_orchestrator.concatenate_all_preprocessed_data:271] Saved concatenated eval.csv with 7913 rows to ../s3_uploads/wallet_training_data_concatenated/dda_947_x_in_cont_v6_dev/eval.csv
# [06/Aug/25 22:58:17] INFO [workflow_orchestrator.concatenate_all_preprocessed_data:271] Saved concatenated test.csv with 9000 rows to ../s3_uploads/wallet_training_data_concatenated/dda_947_x_in_cont_v6_dev/test.csv
# [06/Aug/25 22:58:18] INFO [workflow_orchestrator.concatenate_all_preprocessed_data:271] Saved concatenated val.csv with 6000 rows to ../s3_uploads/wallet_training_data_concatenated/dda_947_x_in_cont_v6_dev/val.csv
# [06/Aug/25 22:58:18] INFO [workflow_orchestrator.concatenate_all_preprocessed_data:274] Copying metadata for concatenated dataset...
# [06/Aug/25 22:58:18] INFO [workflow_orchestrator.concatenate_all_preprocessed_data:303] Saved concatenated metadata to ../s3_uploads/wallet_training_data_concatenated/dda_947_x_in_cont_v6_dev/metadata.json
# [06/Aug/25 22:58:19] INFO [workflow_orchestrator.concatenate_all_preprocessed_data:340] Saved concatenated train_y.csv with 2000 rows to ../s3_uploads/wallet_training_data_concatenated/dda_947_x_in_cont_v6_dev/train_y.csv
# [06/Aug/25 22:58:19] INFO [workflow_orchestrator.concatenate_all_preprocessed_data:340] Saved concatenated eval_y.csv with 7913 rows to ../s3_uploads/wallet_training_data_concatenated/dda_947_x_in_cont_v6_dev/eval_y.csv
# [06/Aug/25 22:58:19] INFO [workflow_orchestrator.concatenate_all_preprocessed_data:340] Saved concatenated test_y.csv with 9000 rows to ../s3_uploads/wallet_training_data_concatenated/dda_947_x_in_cont_v6_dev/test_y.csv
# [06/Aug/25 22:58:19] INFO [workflow_orchestrator.concatenate_all_preprocessed_data:340] Saved concatenated val_y.csv with 6000 rows to ../s3_uploads/wallet_training_data_concatenated/dda_947_x_in_cont_v6_dev/val_y.csv
# [06/Aug/25 22:58:19] INFO [workflow_orchestrator.None:206] (8.5s) Completed concatenate_all_preprocessed_data.

# %% [markdown]
# #### inspect features

# %%
local_s3 = sage_wallets_config['training_data']['local_s3_root']
local_dir = sage_wallets_config['training_data']['local_directory']
local_dir = f"{local_dir}_dev" if sage_wallets_config['training_data']['dataset'] == 'dev' else local_dir
df = pd.read_csv(f'{local_s3}/s3_uploads/wallet_training_data_concatenated/{local_dir}/eval.csv')
with open(f'{local_s3}/s3_uploads/wallet_training_data_concatenated/{local_dir}/metadata.json', 'r') as f:
    metadata = json.load(f)

df.columns = metadata['feature_columns']
u.display_full(df.describe().T)
# Out:
#                                                              count  \
# offset_date                                                   7912
# balance|total_usd_balance|w1                                  7912
# cluster|k5_cluster_k0                                         7912
# cluster|k5_cluster_k1                                         7912
# cluster|k5_cluster_k2                                         7912
# cluster|k5_cluster_k3                                         7912
# cluster|k5_cluster_k4                                         7912
# cw_balance|total_usd_balance|w1                               7912
# cw_cluster|k5_cluster_k0                                      7912
# cw_cluster|k5_cluster_k1                                      7912
# cw_cluster|k5_cluster_k2                                      7912
# cw_cluster|k5_cluster_k3                                      7912
# cw_cluster|k5_cluster_k4                                      7912
# cw_coin_trends|current_holders_in_profit_pct|w1               7912
# cw_coin_trends|current_holders_in_profit_pct|w2               7912
# cw_coin_trends|current_holders_in_profit_pct|w3               7912
# cw_coin_trends|current_holders_in_profit_pct|w4               7912
# cw_coin_trends|current_holders_in_profit|w1                   7912
# cw_coin_trends|current_holders_in_profit|w2                   7912
# cw_coin_trends|current_holders_in_profit|w3                   7912
# cw_coin_trends|current_holders_in_profit|w4                   7912
# cw_coin_trends|current_holders_pct_of_lifetime|w1             7912
# cw_coin_trends|current_holders_pct_of_lifetime|w2             7912
# cw_coin_trends|current_holders_pct_of_lifetime|w3             7912
# cw_coin_trends|current_holders_pct_of_lifetime|w4             7912
# cw_coin_trends|current_holders|w1                             7912
# cw_coin_trends|current_holders|w2                             7912
# cw_coin_trends|current_holders|w3                             7912
# cw_coin_trends|current_holders|w4                             7912
# cw_coin_trends|days_since_ath|w1                              7912
# cw_coin_trends|days_since_ath|w2                              7912
# cw_coin_trends|days_since_ath|w3                              7912
# cw_coin_trends|days_since_ath|w4                              7912
# cw_coin_trends|days_since_launch|w1                           7912
# cw_coin_trends|days_since_launch|w2                           7912
# cw_coin_trends|days_since_launch|w3                           7912
# cw_coin_trends|days_since_launch|w4                           7912
# cw_coin_trends|lifetime_holders|w1                            7912
# cw_coin_trends|lifetime_holders|w2                            7912
# cw_coin_trends|lifetime_holders|w3                            7912
# cw_coin_trends|lifetime_holders|w4                            7912
# cw_coin_trends|price_pct_of_ath|w1                            7912
# cw_coin_trends|price_pct_of_ath|w2                            7912
# cw_coin_trends|price_pct_of_ath|w3                            7912
# cw_coin_trends|price_pct_of_ath|w4                            7912
# cw_mktcap|end_portfolio_wtd_market_cap/market_cap_filled|w1   7912
# cw_mktcap|end_portfolio_wtd_market_cap/market_cap_filled|w2   7912
# cw_mktcap|end_portfolio_wtd_market_cap/market_cap_filled|w3   7912
# cw_mktcap|end_portfolio_wtd_market_cap/market_cap_unadj|w1    7912
# cw_mktcap|end_portfolio_wtd_market_cap/market_cap_unadj|w2    7912
# cw_mktcap|end_portfolio_wtd_market_cap/market_cap_unadj|w3    7912
# cw_performance|crypto_net_gain/crypto_inflows/winsorized|w1   7912
# cw_performance|crypto_net_gain/crypto_inflows/winsorized|w2   7912
# cw_performance|crypto_net_gain/crypto_inflows/winsorized|w3   7912
# cw_performance|crypto_net_gain/crypto_inflows/winsorized|w4   7912
# cw_scenario|ideal/relative_cash_buys/pct_rank|w1              7912
# cw_scenario|ideal/relative_cash_buys/pct_rank|w2              7912
# cw_scenario|ideal/relative_cash_buys/pct_rank|w3              7912
# cw_scenario|ideal/relative_cash_buys/pct_rank|w4              7912
# cw_scenario|ideal/relative_cash_buys/pct|w1                   7912
# cw_scenario|ideal/relative_cash_buys/pct|w2                   7912
# cw_scenario|ideal/relative_cash_buys/pct|w3                   7912
# cw_scenario|ideal/relative_cash_buys/pct|w4                   7912
# cw_scenario|ideal/relative_combined/pct|w1                    7912
# cw_scenario|ideal/relative_combined/pct|w2                    7912
# cw_scenario|ideal/relative_combined/pct|w3                    7912
# cw_scenario|ideal/relative_combined/pct|w4                    7912
# cw_scenario|ideal/relative_net_gain_max_inv/winsorized|w1     7912
# cw_scenario|ideal/relative_net_gain_max_inv/winsorized|w2     7912
# cw_scenario|ideal/relative_net_gain_max_inv/winsorized|w3     7912
# cw_scenario|ideal/relative_net_gain_max_inv/winsorized|w4     7912
# cw_scenario|net_perf/relative_cash_buys|w1                    7912
# cw_scenario|net_perf/relative_cash_buys|w2                    7912
# cw_scenario|net_perf/relative_cash_buys|w3                    7912
# cw_scenario|net_perf/relative_cash_buys|w4                    7912
# cw_scenario|net_perf/relative_net_gains|w1                    7912
# cw_scenario|net_perf/relative_net_gains|w2                    7912
# cw_scenario|net_perf/relative_net_gains|w3                    7912
# cw_scenario|net_perf/relative_net_gains|w4                    7912
# cw_scenario|worst/relative_net_gain_inflows/winsorized|w1     7912
# cw_scenario|worst/relative_net_gain_inflows/winsorized|w2     7912
# cw_scenario|worst/relative_net_gain_inflows/winsorized|w3     7912
# cw_scenario|worst/relative_net_gain_inflows/winsorized|w4     7912
# cw_scenario|worst/relative_net_gains|w1                       7912
# cw_scenario|worst/relative_net_gains|w2                       7912
# cw_scenario|worst/relative_net_gains|w3                       7912
# cw_scenario|worst/relative_net_gains|w4                       7912
# cw_timing|price_sma_2/lag_15/sell_weighted|w1                 7912
# cw_timing|price_sma_2/lag_15/sell_weighted|w2                 7912
# cw_timing|price_sma_2/lag_15/sell_weighted|w3                 7912
# cw_timing|price_sma_2/lag_15/sell_weighted|w4                 7912
# cw_timing|price_sma_2/lead_30/sell_weighted|w3                7912
# cw_timing|price_sma_2/lead_30/sell_weighted|w4                7912
# cw_timing|volume_sma_2/lead_7/buy_weighted|w1                 7912
# cw_timing|volume_sma_2/lead_7/buy_weighted|w2                 7912
# cw_timing|volume_sma_2/lead_7/buy_weighted|w3                 7912
# cw_timing|volume_sma_2/lead_7/buy_weighted|w4                 7912
# cw_trading|crypto_cash_sells|w1                               7912
# cw_trading|crypto_cash_sells|w2                               7912
# cw_trading|crypto_inflows|w1                                  7912
# cw_transfers|buys_coin_age/mean|w1                            7912
# cw_transfers|buys_coin_age/mean|w2                            7912
# cw_transfers|buys_coin_age/mean|w3                            7912
# cw_transfers|buys_coin_age/mean|w4                            7912
# cw_transfers|earlybird_ratio/mean|w1                          7912
# cw_transfers|earlybird_ratio/mean|w2                          7912
# cw_transfers|earlybird_ratio/mean|w3                          7912
# cw_transfers|earlybird_ratio/mean|w4                          7912
# cw_transfers|first_buy/mean_rank|w1                           7912
# cw_transfers|first_buy/mean_rank|w2                           7912
# cw_transfers|first_buy/mean_rank|w3                           7912
# cw_transfers|first_buy/mean_rank|w4                           7912
# cw_transfers|initial_hold_time/mean|w1                        7912
# cw_transfers|initial_hold_time/mean|w2                        7912
# cw_transfers|initial_hold_time/mean|w3                        7912
# cw_transfers|initial_hold_time/mean|w4                        7912
# macro|btc_mvrv_z_score_last|w1                                7912
# macro|btc_mvrv_z_score_last|w2                                7912
# macro|btc_mvrv_z_score_last|w3                                7912
# macro|btc_mvrv_z_score_last|w4                                7912
# macro|btc_mvrv_z_score_std|w1                                 7912
# macro|btc_mvrv_z_score_std|w2                                 7912
# macro|btc_mvrv_z_score_std|w3                                 7912
# macro|btc_mvrv_z_score_std|w4                                 7912
# macro|btc_price_std|w1                                        7912
# macro|btc_price_std|w2                                        7912
# macro|btc_price_std|w3                                        7912
# macro|btc_price_std|w4                                        7912
# macro|btc_vdd_multiple_last|w1                                7912
# macro|btc_vdd_multiple_last|w2                                7912
# macro|btc_vdd_multiple_last|w3                                7912
# macro|btc_vdd_multiple_last|w4                                7912
# macro|btc_vdd_multiple_std|w1                                 7912
# macro|btc_vdd_multiple_std|w2                                 7912
# macro|btc_vdd_multiple_std|w3                                 7912
# macro|btc_vdd_multiple_std|w4                                 7912
# macro|global_market_cap_rsi_30_last|w1                        7912
# macro|global_market_cap_rsi_30_last|w2                        7912
# macro|global_market_cap_rsi_30_last|w3                        7912
# macro|global_market_cap_rsi_30_last|w4                        7912
# macro|global_market_cap_std|w1                                7912
# macro|global_market_cap_std|w2                                7912
# macro|global_market_cap_std|w3                                7912
# macro|global_market_cap_std|w4                                7912
# macro|gtrends_memecoin_us_std|w1                              7912
# macro|gtrends_memecoin_us_std|w2                              7912
# macro|gtrends_memecoin_us_std|w3                              7912
# macro|gtrends_memecoin_us_std|w4                              7912
# mktcap|end_portfolio_wtd_market_cap/market_cap_filled|w1      7912
# mktcap|end_portfolio_wtd_market_cap/market_cap_filled|w2      7912
# mktcap|end_portfolio_wtd_market_cap/market_cap_filled|w3      7912
# mktcap|end_portfolio_wtd_market_cap/market_cap_filled|w4      7912
# performance|crypto_net_gain/crypto_inflows/winsorized|w1      7912
# performance|crypto_net_gain/crypto_inflows/winsorized|w2      7912
# performance|crypto_net_gain/crypto_inflows/winsorized|w3      7912
# performance|crypto_net_gain/crypto_inflows/winsorized|w4      7912
# scenario|ideal/relative_cash_buys/pct|w1                      7912
# scenario|ideal/relative_cash_buys/pct|w2                      7912
# scenario|ideal/relative_cash_buys/pct|w3                      7912
# scenario|ideal/relative_cash_buys/pct|w4                      7912
# scenario|ideal/relative_combined/pct|w1                       7912
# scenario|ideal/relative_combined/pct|w2                       7912
# scenario|ideal/relative_combined/pct|w3                       7912
# scenario|ideal/relative_combined/pct|w4                       7912
# scenario|worst/relative_combined/pct|w1                       7912
# scenario|worst/relative_combined/pct|w2                       7912
# scenario|worst/relative_combined/pct|w3                       7912
# scenario|worst/relative_combined/pct|w4                       7912
# scenario|worst/relative_net_gains|w1                          7912
# scenario|worst/relative_net_gains|w2                          7912
# scenario|worst/relative_net_gains|w3                          7912
# scenario|worst/relative_net_gains|w4                          7912
# timing|btc_mvrv_z_score/lag_30/sell_weighted|w1               7912
# timing|btc_mvrv_z_score/lag_30/sell_weighted|w2               7912
# timing|btc_mvrv_z_score/lag_30/sell_weighted|w3               7912
# timing|btc_mvrv_z_score/lag_30/sell_weighted|w4               7912
# timing|btc_mvrv_z_score/lag_90/buy_weighted|w1                7912
# timing|btc_mvrv_z_score/lag_90/buy_weighted|w2                7912
# timing|btc_mvrv_z_score/lag_90/buy_weighted|w3                7912
# timing|btc_mvrv_z_score/lag_90/buy_weighted|w4                7912
# timing|btc_mvrv_z_score/lag_90/sell_weighted|w1               7912
# timing|btc_mvrv_z_score/lag_90/sell_weighted|w2               7912
# timing|btc_mvrv_z_score/lag_90/sell_weighted|w3               7912
# timing|btc_mvrv_z_score/lag_90/sell_weighted|w4               7912
# timing|btc_mvrv_z_score/lead_90/buy_weighted|w4               7912
# timing|gtrends_memecoin_us/lag_15/buy_weighted|w1             7912
# timing|gtrends_memecoin_us/lag_15/buy_weighted|w2             7912
# timing|gtrends_memecoin_us/lag_15/buy_weighted|w3             7912
# timing|gtrends_memecoin_us/lag_15/buy_weighted|w4             7912
# timing|gtrends_memecoin_us/lag_15/sell_weighted|w1            7912
# timing|gtrends_memecoin_us/lag_15/sell_weighted|w2            7912
# timing|gtrends_memecoin_us/lag_15/sell_weighted|w3            7912
# timing|gtrends_memecoin_us/lag_15/sell_weighted|w4            7912
# timing|price_sma_2/lag_15/buy_weighted|w1                     7912
# timing|price_sma_2/lag_15/buy_weighted|w2                     7912
# timing|price_sma_2/lag_15/buy_weighted|w3                     7912
# timing|price_sma_2/lag_15/buy_weighted|w4                     7912
# timing|volume_sma_2/lead_7/buy_weighted|w1                    7912
# timing|volume_sma_2/lead_7/buy_weighted|w2                    7912
# timing|volume_sma_2/lead_7/buy_weighted|w3                    7912
# timing|volume_sma_2/lead_7/buy_weighted|w4                    7912
# timing|volume_sma_2/lead_7/sell_weighted|w1                   7912
# timing|volume_sma_2/lead_7/sell_weighted|w2                   7912
# timing|volume_sma_2/lead_7/sell_weighted|w3                   7912
# timing|volume_sma_2/lead_7/sell_weighted|w4                   7912
# trading|crypto_cash_sells|w1                                  7912
# trading|crypto_cash_sells|w2                                  7912
# trading|crypto_inflows|all_windows                            7912
# trading|total_volume|w1                                       7912
# trading|total_volume|w2                                       7912
# trading|unique_coins_traded|all_windows                       7912
# transfers|buys_coin_age/mean|w1                               7912
# transfers|buys_coin_age/mean|w2                               7912
# transfers|buys_coin_age/mean|w3                               7912
# transfers|buys_coin_age/mean|w4                               7912
# transfers|earlybird_ratio/median|w1                           7912
# transfers|earlybird_ratio/median|w2                           7912
# transfers|earlybird_ratio/median|w3                           7912
# transfers|earlybird_ratio/median|w4                           7912
# transfers|first_buy/mean_rank|w1                              7912
# transfers|first_buy/mean_rank|w2                              7912
# transfers|first_buy/mean_rank|w3                              7912
# transfers|first_buy/mean_rank|w4                              7912
# transfers|initial_hold_time/median|w1                         7912
# transfers|initial_hold_time/median|w2                         7912
# transfers|initial_hold_time/median|w3                         7912
# transfers|initial_hold_time/median|w4                         7912
# transfers|later_buyers/median|w1                              7912
# transfers|later_buyers/median|w2                              7912
# transfers|later_buyers/median|w3                              7912
# transfers|later_buyers/median|w4                              7912
#
#                                                                         mean  \
# offset_date                                                    1422.33822042
# balance|total_usd_balance|w1                                   155071.253381
# cluster|k5_cluster_k0                                         0.179726996967
# cluster|k5_cluster_k1                                         0.149898887765
# cluster|k5_cluster_k2                                         0.210187057634
# cluster|k5_cluster_k3                                         0.304095045501
# cluster|k5_cluster_k4                                         0.156092012133
# cw_balance|total_usd_balance|w1                                23540.0404095
# cw_cluster|k5_cluster_k0                                      0.142189079879
# cw_cluster|k5_cluster_k1                                       0.19868554095
# cw_cluster|k5_cluster_k2                                      0.207532861476
# cw_cluster|k5_cluster_k3                                      0.243680485339
# cw_cluster|k5_cluster_k4                                      0.207912032356
# cw_coin_trends|current_holders_in_profit_pct|w1               0.155603046015
# cw_coin_trends|current_holders_in_profit_pct|w2               0.119150631878
# cw_coin_trends|current_holders_in_profit_pct|w3              0.0579558415217
# cw_coin_trends|current_holders_in_profit_pct|w4             -0.0631904592966
# cw_coin_trends|current_holders_in_profit|w1                    2705.54208797
# cw_coin_trends|current_holders_in_profit|w2                    2389.95942872
# cw_coin_trends|current_holders_in_profit|w3                    2165.14004044
# cw_coin_trends|current_holders_in_profit|w4                    1864.27780586
# cw_coin_trends|current_holders_pct_of_lifetime|w1              0.39955047183
# cw_coin_trends|current_holders_pct_of_lifetime|w2             0.369630114292
# cw_coin_trends|current_holders_pct_of_lifetime|w3             0.301446185657
# cw_coin_trends|current_holders_pct_of_lifetime|w4             0.156434356171
# cw_coin_trends|current_holders|w1                              20869.8044742
# cw_coin_trends|current_holders|w2                              19155.5319767
# cw_coin_trends|current_holders|w3                               17940.968908
# cw_coin_trends|current_holders|w4                              15958.5312184
# cw_coin_trends|days_since_ath|w1                               499.138650152
# cw_coin_trends|days_since_ath|w2                               490.739130435
# cw_coin_trends|days_since_ath|w3                               475.625758342
# cw_coin_trends|days_since_ath|w4                               449.760743175
# cw_coin_trends|days_since_launch|w1                            665.692997978
# cw_coin_trends|days_since_launch|w2                            636.070525784
# cw_coin_trends|days_since_launch|w3                            607.526415571
# cw_coin_trends|days_since_launch|w4                            554.745449949
# cw_coin_trends|lifetime_holders|w1                             61055.8899141
# cw_coin_trends|lifetime_holders|w2                             56844.3714611
# cw_coin_trends|lifetime_holders|w3                             53511.6066734
# cw_coin_trends|lifetime_holders|w4                             47668.2633974
# cw_coin_trends|price_pct_of_ath|w1                            0.391314756713
# cw_coin_trends|price_pct_of_ath|w2                            0.339357158257
# cw_coin_trends|price_pct_of_ath|w3                            0.238999597467
# cw_coin_trends|price_pct_of_ath|w4                           0.0632949011936
# cw_mktcap|end_portfolio_wtd_market_cap/market_cap_filled|w1    192106219.733
# cw_mktcap|end_portfolio_wtd_market_cap/market_cap_filled|w2    110452995.983
# cw_mktcap|end_portfolio_wtd_market_cap/market_cap_filled|w3    76489015.2024
# cw_mktcap|end_portfolio_wtd_market_cap/market_cap_unadj|w1     192106219.733
# cw_mktcap|end_portfolio_wtd_market_cap/market_cap_unadj|w2     109693398.411
# cw_mktcap|end_portfolio_wtd_market_cap/market_cap_unadj|w3     76131169.9393
# cw_performance|crypto_net_gain/crypto_inflows/winsorized|w1   0.178201571898
# cw_performance|crypto_net_gain/crypto_inflows/winsorized|w2   0.107717607472
# cw_performance|crypto_net_gain/crypto_inflows/winsorized|w3  0.0786191348798
# cw_performance|crypto_net_gain/crypto_inflows/winsorized|w4  0.0324704678453
# cw_scenario|ideal/relative_cash_buys/pct_rank|w1             -0.668545129244
# cw_scenario|ideal/relative_cash_buys/pct_rank|w2             -0.567240752946
# cw_scenario|ideal/relative_cash_buys/pct_rank|w3             -0.499477066484
# cw_scenario|ideal/relative_cash_buys/pct_rank|w4             -0.338459289807
# cw_scenario|ideal/relative_cash_buys/pct|w1                  -0.102028510613
# cw_scenario|ideal/relative_cash_buys/pct|w2                 -0.0553089593971
# cw_scenario|ideal/relative_cash_buys/pct|w3                 -0.0666527793597
# cw_scenario|ideal/relative_cash_buys/pct|w4                  -0.060158682715
# cw_scenario|ideal/relative_combined/pct|w1                   -0.131740897898
# cw_scenario|ideal/relative_combined/pct|w2                  -0.0720306112946
# cw_scenario|ideal/relative_combined/pct|w3                  -0.0906721212182
# cw_scenario|ideal/relative_combined/pct|w4                  -0.0864126378509
# cw_scenario|ideal/relative_net_gain_max_inv/winsorized|w1     0.453094592198
# cw_scenario|ideal/relative_net_gain_max_inv/winsorized|w2       1.7874064935
# cw_scenario|ideal/relative_net_gain_max_inv/winsorized|w3      4.75698719335
# cw_scenario|ideal/relative_net_gain_max_inv/winsorized|w4      18.8761689738
# cw_scenario|net_perf/relative_cash_buys|w1                    0.326674823026
# cw_scenario|net_perf/relative_cash_buys|w2                    0.283268633525
# cw_scenario|net_perf/relative_cash_buys|w3                     0.33542116478
# cw_scenario|net_perf/relative_cash_buys|w4                    0.363450803773
# cw_scenario|net_perf/relative_net_gains|w1                    0.514802646663
# cw_scenario|net_perf/relative_net_gains|w2                     0.47747667031
# cw_scenario|net_perf/relative_net_gains|w3                    0.506717668784
# cw_scenario|net_perf/relative_net_gains|w4                    0.517985308723
# cw_scenario|worst/relative_net_gain_inflows/winsorized|w1     0.302855404648
# cw_scenario|worst/relative_net_gain_inflows/winsorized|w2     0.191597650132
# cw_scenario|worst/relative_net_gain_inflows/winsorized|w3     0.167489783011
# cw_scenario|worst/relative_net_gain_inflows/winsorized|w4     0.124410460618
# cw_scenario|worst/relative_net_gains|w1                        5805.71202278
# cw_scenario|worst/relative_net_gains|w2                        3508.03442401
# cw_scenario|worst/relative_net_gains|w3                        3275.95879833
# cw_scenario|worst/relative_net_gains|w4                        2633.68229529
# cw_timing|price_sma_2/lag_15/sell_weighted|w1                0.0338810023937
# cw_timing|price_sma_2/lag_15/sell_weighted|w2                0.0159449710767
# cw_timing|price_sma_2/lag_15/sell_weighted|w3                0.0149516756669
# cw_timing|price_sma_2/lag_15/sell_weighted|w4               0.00681997033588
# cw_timing|price_sma_2/lead_30/sell_weighted|w3              0.00679674407521
# cw_timing|price_sma_2/lead_30/sell_weighted|w4              0.00204428441667
# cw_timing|volume_sma_2/lead_7/buy_weighted|w1                0.0895721864696
# cw_timing|volume_sma_2/lead_7/buy_weighted|w2                0.0693360055455
# cw_timing|volume_sma_2/lead_7/buy_weighted|w3                0.0670354710498
# cw_timing|volume_sma_2/lead_7/buy_weighted|w4                0.0487454771705
# cw_trading|crypto_cash_sells|w1                                8965.58510294
# cw_trading|crypto_cash_sells|w2                                 6167.5654712
# cw_trading|crypto_inflows|w1                                    25645.893355
# cw_transfers|buys_coin_age/mean|w1                             665.692997978
# cw_transfers|buys_coin_age/mean|w2                             521.764155713
# cw_transfers|buys_coin_age/mean|w3                             438.186552073
# cw_transfers|buys_coin_age/mean|w4                             335.743806876
# cw_transfers|earlybird_ratio/mean|w1                           3.28009085607
# cw_transfers|earlybird_ratio/mean|w2                           2.42725102427
# cw_transfers|earlybird_ratio/mean|w3                           1.81197394894
# cw_transfers|earlybird_ratio/mean|w4                           1.01577389565
# cw_transfers|first_buy/mean_rank|w1                            35496.4876138
# cw_transfers|first_buy/mean_rank|w2                            27254.6037664
# cw_transfers|first_buy/mean_rank|w3                            22646.3901668
# cw_transfers|first_buy/mean_rank|w4                            16466.7671891
# cw_transfers|initial_hold_time/mean|w1                         69.6905965622
# cw_transfers|initial_hold_time/mean|w2                         57.8756319515
# cw_transfers|initial_hold_time/mean|w3                         50.0542214358
# cw_transfers|initial_hold_time/mean|w4                         39.2234580384
# macro|btc_mvrv_z_score_last|w1                                 1.46379546939
# macro|btc_mvrv_z_score_last|w2                                 1.21764835439
# macro|btc_mvrv_z_score_last|w3                                0.944584612874
# macro|btc_mvrv_z_score_last|w4                                0.746762502803
# macro|btc_mvrv_z_score_std|w1                                  1.59877361204
# macro|btc_mvrv_z_score_std|w2                                  1.60313641409
# macro|btc_mvrv_z_score_std|w3                                  1.60777621667
# macro|btc_mvrv_z_score_std|w4                                  1.61680521201
# macro|btc_price_std|w1                                         15176.1100166
# macro|btc_price_std|w2                                         14990.4300607
# macro|btc_price_std|w3                                         14875.1174301
# macro|btc_price_std|w4                                         14735.7881057
# macro|btc_vdd_multiple_last|w1                                 1.85983809403
# macro|btc_vdd_multiple_last|w2                                 1.56098334176
# macro|btc_vdd_multiple_last|w3                                  1.3380288549
# macro|btc_vdd_multiple_last|w4                                  1.1123418731
# macro|btc_vdd_multiple_std|w1                                 0.823291460794
# macro|btc_vdd_multiple_std|w2                                 0.821587886653
# macro|btc_vdd_multiple_std|w3                                 0.822832425341
# macro|btc_vdd_multiple_std|w4                                 0.827029312045
# macro|global_market_cap_rsi_30_last|w1                        0.605102439293
# macro|global_market_cap_rsi_30_last|w2                        0.614432724109
# macro|global_market_cap_rsi_30_last|w3                        0.550881436949
# macro|global_market_cap_rsi_30_last|w4                        0.564538456421
# macro|global_market_cap_std|w1                                  696382327270
# macro|global_market_cap_std|w2                                  690600532811
# macro|global_market_cap_std|w3                                  687578878703
# macro|global_market_cap_std|w4                                  684758110099
# macro|gtrends_memecoin_us_std|w1                              0.694941540651
# macro|gtrends_memecoin_us_std|w2                              0.604772387518
# macro|gtrends_memecoin_us_std|w3                              0.574772248807
# macro|gtrends_memecoin_us_std|w4                              0.514454023552
# mktcap|end_portfolio_wtd_market_cap/market_cap_filled|w1       180205481.591
# mktcap|end_portfolio_wtd_market_cap/market_cap_filled|w2       135864048.877
# mktcap|end_portfolio_wtd_market_cap/market_cap_filled|w3       106944294.866
# mktcap|end_portfolio_wtd_market_cap/market_cap_filled|w4       86223198.9811
# performance|crypto_net_gain/crypto_inflows/winsorized|w1       0.14251737428
# performance|crypto_net_gain/crypto_inflows/winsorized|w2      0.112580919707
# performance|crypto_net_gain/crypto_inflows/winsorized|w3     0.0875491767074
# performance|crypto_net_gain/crypto_inflows/winsorized|w4     0.0509260186724
# scenario|ideal/relative_cash_buys/pct|w1                     -0.144188868949
# scenario|ideal/relative_cash_buys/pct|w2                     -0.116574877824
# scenario|ideal/relative_cash_buys/pct|w3                     -0.140326679368
# scenario|ideal/relative_cash_buys/pct|w4                     -0.146895798677
# scenario|ideal/relative_combined/pct|w1                      -0.246890095589
# scenario|ideal/relative_combined/pct|w2                      -0.195843390385
# scenario|ideal/relative_combined/pct|w3                      -0.245050875392
# scenario|ideal/relative_combined/pct|w4                      -0.270514663195
# scenario|worst/relative_combined/pct|w1                       0.201633880621
# scenario|worst/relative_combined/pct|w2                       0.158063947059
# scenario|worst/relative_combined/pct|w3                       0.213608815171
# scenario|worst/relative_combined/pct|w4                       0.277349926956
# scenario|worst/relative_net_gains|w1                           32738.5133394
# scenario|worst/relative_net_gains|w2                           23019.4682028
# scenario|worst/relative_net_gains|w3                           23622.0069852
# scenario|worst/relative_net_gains|w4                           31488.8149899
# timing|btc_mvrv_z_score/lag_30/sell_weighted|w1                0.10070206504
# timing|btc_mvrv_z_score/lag_30/sell_weighted|w2              0.0653498504285
# timing|btc_mvrv_z_score/lag_30/sell_weighted|w3              0.0330040683939
# timing|btc_mvrv_z_score/lag_30/sell_weighted|w4              0.0975867292089
# timing|btc_mvrv_z_score/lag_90/buy_weighted|w1                0.222848142941
# timing|btc_mvrv_z_score/lag_90/buy_weighted|w2                0.166375847333
# timing|btc_mvrv_z_score/lag_90/buy_weighted|w3                0.172746288852
# timing|btc_mvrv_z_score/lag_90/buy_weighted|w4                0.379341960297
# timing|btc_mvrv_z_score/lag_90/sell_weighted|w1               0.195119740462
# timing|btc_mvrv_z_score/lag_90/sell_weighted|w2               0.130309822273
# timing|btc_mvrv_z_score/lag_90/sell_weighted|w3               0.137265574806
# timing|btc_mvrv_z_score/lag_90/sell_weighted|w4               0.327109137462
# timing|btc_mvrv_z_score/lead_90/buy_weighted|w4              0.0746987325181
# timing|gtrends_memecoin_us/lag_15/buy_weighted|w1             0.296221275256
# timing|gtrends_memecoin_us/lag_15/buy_weighted|w2             0.278330388865
# timing|gtrends_memecoin_us/lag_15/buy_weighted|w3             0.288441878193
# timing|gtrends_memecoin_us/lag_15/buy_weighted|w4             0.424075288098
# timing|gtrends_memecoin_us/lag_15/sell_weighted|w1            0.235460677439
# timing|gtrends_memecoin_us/lag_15/sell_weighted|w2            0.213670052484
# timing|gtrends_memecoin_us/lag_15/sell_weighted|w3            0.245132691165
# timing|gtrends_memecoin_us/lag_15/sell_weighted|w4            0.372223984391
# timing|price_sma_2/lag_15/buy_weighted|w1                    0.0904435395618
# timing|price_sma_2/lag_15/buy_weighted|w2                    0.0597553044141
# timing|price_sma_2/lag_15/buy_weighted|w3                    0.0503833083158
# timing|price_sma_2/lag_15/buy_weighted|w4                    0.0320601355705
# timing|volume_sma_2/lead_7/buy_weighted|w1                    0.103324674811
# timing|volume_sma_2/lead_7/buy_weighted|w2                    0.100685659613
# timing|volume_sma_2/lead_7/buy_weighted|w3                   0.0885928384324
# timing|volume_sma_2/lead_7/buy_weighted|w4                    0.092226474623
# timing|volume_sma_2/lead_7/sell_weighted|w1                  0.0831867904342
# timing|volume_sma_2/lead_7/sell_weighted|w2                  0.0610973794708
# timing|volume_sma_2/lead_7/sell_weighted|w3                  0.0659957968037
# timing|volume_sma_2/lead_7/sell_weighted|w4                  0.0476602360833
# trading|crypto_cash_sells|w1                                   91410.5986032
# trading|crypto_cash_sells|w2                                   60247.7295182
# trading|crypto_inflows|all_windows                             384350.670804
# trading|total_volume|w1                                        168532.757534
# trading|total_volume|w2                                        102825.022606
# trading|unique_coins_traded|all_windows                        11.7645348837
# transfers|buys_coin_age/mean|w1                                699.597428972
# transfers|buys_coin_age/mean|w2                                679.683754573
# transfers|buys_coin_age/mean|w3                                649.977688684
# transfers|buys_coin_age/mean|w4                                598.980271215
# transfers|earlybird_ratio/median|w1                            2.44266118716
# transfers|earlybird_ratio/median|w2                            2.58901803842
# transfers|earlybird_ratio/median|w3                            2.67897379259
# transfers|earlybird_ratio/median|w4                            2.54679530672
# transfers|first_buy/mean_rank|w1                               32839.7445611
# transfers|first_buy/mean_rank|w2                               31361.0836293
# transfers|first_buy/mean_rank|w3                               29023.0829911
# transfers|first_buy/mean_rank|w4                               25003.4021372
# transfers|initial_hold_time/median|w1                          57.0947295248
# transfers|initial_hold_time/median|w2                          60.9749747219
# transfers|initial_hold_time/median|w3                          63.6363751264
# transfers|initial_hold_time/median|w4                          65.7543604651
# transfers|later_buyers/median|w1                               8156.68547776
# transfers|later_buyers/median|w2                                10227.174229
# transfers|later_buyers/median|w3                               11872.8020096
# transfers|later_buyers/median|w4                               13832.3579373
#
#                                                                          std  \
# offset_date                                                    74.0919349879
# balance|total_usd_balance|w1                                   797245.340394
# cluster|k5_cluster_k0                                         0.383984165036
# cluster|k5_cluster_k1                                         0.356994844589
# cluster|k5_cluster_k2                                         0.407467106583
# cluster|k5_cluster_k3                                         0.460052169928
# cluster|k5_cluster_k4                                         0.362965490147
# cw_balance|total_usd_balance|w1                                106696.381138
# cw_cluster|k5_cluster_k0                                      0.349266035258
# cw_cluster|k5_cluster_k1                                      0.399035990681
# cw_cluster|k5_cluster_k2                                      0.405565977413
# cw_cluster|k5_cluster_k3                                      0.429329247918
# cw_cluster|k5_cluster_k4                                      0.405839175445
# cw_coin_trends|current_holders_in_profit_pct|w1              0.0840942296888
# cw_coin_trends|current_holders_in_profit_pct|w2               0.198603035948
# cw_coin_trends|current_holders_in_profit_pct|w3               0.306076315548
# cw_coin_trends|current_holders_in_profit_pct|w4                0.43101745194
# cw_coin_trends|current_holders_in_profit|w1                    3211.45443179
# cw_coin_trends|current_holders_in_profit|w2                    3301.49785108
# cw_coin_trends|current_holders_in_profit|w3                    3380.10641428
# cw_coin_trends|current_holders_in_profit|w4                     3496.1022227
# cw_coin_trends|current_holders_pct_of_lifetime|w1              0.14572784694
# cw_coin_trends|current_holders_pct_of_lifetime|w2             0.268891084561
# cw_coin_trends|current_holders_pct_of_lifetime|w3             0.393010908309
# cw_coin_trends|current_holders_pct_of_lifetime|w4             0.541137400044
# cw_coin_trends|current_holders|w1                              26416.9736303
# cw_coin_trends|current_holders|w2                               26249.483353
# cw_coin_trends|current_holders|w3                              26014.2224866
# cw_coin_trends|current_holders|w4                               25313.075919
# cw_coin_trends|days_since_ath|w1                               493.506286098
# cw_coin_trends|days_since_ath|w2                               484.315424187
# cw_coin_trends|days_since_ath|w3                               477.049508921
# cw_coin_trends|days_since_ath|w4                               468.636433117
# cw_coin_trends|days_since_launch|w1                            537.454184128
# cw_coin_trends|days_since_launch|w2                            537.000026087
# cw_coin_trends|days_since_launch|w3                            535.315822923
# cw_coin_trends|days_since_launch|w4                             527.45995556
# cw_coin_trends|lifetime_holders|w1                             82178.0170193
# cw_coin_trends|lifetime_holders|w2                             81095.7851825
# cw_coin_trends|lifetime_holders|w3                             79611.3532833
# cw_coin_trends|lifetime_holders|w4                             76096.6188948
# cw_coin_trends|price_pct_of_ath|w1                            0.331187807657
# cw_coin_trends|price_pct_of_ath|w2                            0.398524487814
# cw_coin_trends|price_pct_of_ath|w3                            0.468254257428
# cw_coin_trends|price_pct_of_ath|w4                            0.557348823771
# cw_mktcap|end_portfolio_wtd_market_cap/market_cap_filled|w1    201564624.337
# cw_mktcap|end_portfolio_wtd_market_cap/market_cap_filled|w2    171103978.055
# cw_mktcap|end_portfolio_wtd_market_cap/market_cap_filled|w3    141865307.932
# cw_mktcap|end_portfolio_wtd_market_cap/market_cap_unadj|w1     201564624.337
# cw_mktcap|end_portfolio_wtd_market_cap/market_cap_unadj|w2     171418387.135
# cw_mktcap|end_portfolio_wtd_market_cap/market_cap_unadj|w3     141956317.291
# cw_performance|crypto_net_gain/crypto_inflows/winsorized|w1     0.5129914482
# cw_performance|crypto_net_gain/crypto_inflows/winsorized|w2   0.417772896462
# cw_performance|crypto_net_gain/crypto_inflows/winsorized|w3   0.426321213715
# cw_performance|crypto_net_gain/crypto_inflows/winsorized|w4   0.364178008964
# cw_scenario|ideal/relative_cash_buys/pct_rank|w1              0.249565823555
# cw_scenario|ideal/relative_cash_buys/pct_rank|w2              0.234253035436
# cw_scenario|ideal/relative_cash_buys/pct_rank|w3              0.238231010144
# cw_scenario|ideal/relative_cash_buys/pct_rank|w4                 0.221654673
# cw_scenario|ideal/relative_cash_buys/pct|w1                   0.166505489651
# cw_scenario|ideal/relative_cash_buys/pct|w2                   0.127085979465
# cw_scenario|ideal/relative_cash_buys/pct|w3                   0.151613891287
# cw_scenario|ideal/relative_cash_buys/pct|w4                    0.15138689113
# cw_scenario|ideal/relative_combined/pct|w1                    0.187666314464
# cw_scenario|ideal/relative_combined/pct|w2                    0.144210485367
# cw_scenario|ideal/relative_combined/pct|w3                    0.188874195245
# cw_scenario|ideal/relative_combined/pct|w4                    0.203829741724
# cw_scenario|ideal/relative_net_gain_max_inv/winsorized|w1     0.878692845304
# cw_scenario|ideal/relative_net_gain_max_inv/winsorized|w2      3.40026983304
# cw_scenario|ideal/relative_net_gain_max_inv/winsorized|w3      6.58685498084
# cw_scenario|ideal/relative_net_gain_max_inv/winsorized|w4      17.9968468486
# cw_scenario|net_perf/relative_cash_buys|w1                    0.390634593067
# cw_scenario|net_perf/relative_cash_buys|w2                    0.321162496307
# cw_scenario|net_perf/relative_cash_buys|w3                    0.286954004146
# cw_scenario|net_perf/relative_cash_buys|w4                    0.217174073968
# cw_scenario|net_perf/relative_net_gains|w1                    0.309441178091
# cw_scenario|net_perf/relative_net_gains|w2                     0.28076610831
# cw_scenario|net_perf/relative_net_gains|w3                    0.244119173851
# cw_scenario|net_perf/relative_net_gains|w4                    0.179035061696
# cw_scenario|worst/relative_net_gain_inflows/winsorized|w1     0.443239903924
# cw_scenario|worst/relative_net_gain_inflows/winsorized|w2     0.380695694128
# cw_scenario|worst/relative_net_gain_inflows/winsorized|w3     0.388746143411
# cw_scenario|worst/relative_net_gain_inflows/winsorized|w4     0.331234464075
# cw_scenario|worst/relative_net_gains|w1                        31567.1288868
# cw_scenario|worst/relative_net_gains|w2                        24519.5329855
# cw_scenario|worst/relative_net_gains|w3                        27179.7335987
# cw_scenario|worst/relative_net_gains|w4                        18875.5733658
# cw_timing|price_sma_2/lag_15/sell_weighted|w1                 0.155652725436
# cw_timing|price_sma_2/lag_15/sell_weighted|w2                 0.121145390231
# cw_timing|price_sma_2/lag_15/sell_weighted|w3                 0.113549214786
# cw_timing|price_sma_2/lag_15/sell_weighted|w4                0.0948512147213
# cw_timing|price_sma_2/lead_30/sell_weighted|w3                0.144218762635
# cw_timing|price_sma_2/lead_30/sell_weighted|w4                0.148841217313
# cw_timing|volume_sma_2/lead_7/buy_weighted|w1                 0.965604878224
# cw_timing|volume_sma_2/lead_7/buy_weighted|w2                 0.751495935423
# cw_timing|volume_sma_2/lead_7/buy_weighted|w3                  0.71912999455
# cw_timing|volume_sma_2/lead_7/buy_weighted|w4                 0.689722243661
# cw_trading|crypto_cash_sells|w1                                61854.9437484
# cw_trading|crypto_cash_sells|w2                                87091.9614562
# cw_trading|crypto_inflows|w1                                   114372.912018
# cw_transfers|buys_coin_age/mean|w1                             537.454184128
# cw_transfers|buys_coin_age/mean|w2                             556.452282957
# cw_transfers|buys_coin_age/mean|w3                              548.81684886
# cw_transfers|buys_coin_age/mean|w4                             528.493412715
# cw_transfers|earlybird_ratio/mean|w1                           5.01445888913
# cw_transfers|earlybird_ratio/mean|w2                           5.00539687108
# cw_transfers|earlybird_ratio/mean|w3                           4.80567964084
# cw_transfers|earlybird_ratio/mean|w4                           4.36347230462
# cw_transfers|first_buy/mean_rank|w1                            55856.4395304
# cw_transfers|first_buy/mean_rank|w2                            52122.7868279
# cw_transfers|first_buy/mean_rank|w3                            48831.3276272
# cw_transfers|first_buy/mean_rank|w4                            43056.1648177
# cw_transfers|initial_hold_time/mean|w1                         129.573834782
# cw_transfers|initial_hold_time/mean|w2                         124.478241941
# cw_transfers|initial_hold_time/mean|w3                         120.186312902
# cw_transfers|initial_hold_time/mean|w4                         111.860664931
# macro|btc_mvrv_z_score_last|w1                                0.742452960494
# macro|btc_mvrv_z_score_last|w2                                0.654830251363
# macro|btc_mvrv_z_score_last|w3                                0.441551278032
# macro|btc_mvrv_z_score_last|w4                                0.350167475814
# macro|btc_mvrv_z_score_std|w1                                0.0114357155098
# macro|btc_mvrv_z_score_std|w2                                0.0117007485011
# macro|btc_mvrv_z_score_std|w3                                0.0113464197571
# macro|btc_mvrv_z_score_std|w4                                0.0103609025057
# macro|btc_price_std|w1                                         469.859260015
# macro|btc_price_std|w2                                         295.574655182
# macro|btc_price_std|w3                                         201.763211063
# macro|btc_price_std|w4                                         97.9496286556
# macro|btc_vdd_multiple_last|w1                                0.843898082119
# macro|btc_vdd_multiple_last|w2                                0.627381746637
# macro|btc_vdd_multiple_last|w3                                0.488008693944
# macro|btc_vdd_multiple_last|w4                                0.252056899411
# macro|btc_vdd_multiple_std|w1                               0.00749982281837
# macro|btc_vdd_multiple_std|w2                               0.00410373813886
# macro|btc_vdd_multiple_std|w3                               0.00521562803711
# macro|btc_vdd_multiple_std|w4                               0.00666051307492
# macro|global_market_cap_rsi_30_last|w1                         0.16646398096
# macro|global_market_cap_rsi_30_last|w2                         0.16340393837
# macro|global_market_cap_rsi_30_last|w3                        0.133348372363
# macro|global_market_cap_rsi_30_last|w4                         0.13809303004
# macro|global_market_cap_std|w1                                 15035782227.4
# macro|global_market_cap_std|w2                                 8192178847.42
# macro|global_market_cap_std|w3                                 4740721834.54
# macro|global_market_cap_std|w4                                 1029619761.64
# macro|gtrends_memecoin_us_std|w1                              0.220714425217
# macro|gtrends_memecoin_us_std|w2                             0.0850310714243
# macro|gtrends_memecoin_us_std|w3                             0.0623268305149
# macro|gtrends_memecoin_us_std|w4                             0.0672967057056
# mktcap|end_portfolio_wtd_market_cap/market_cap_filled|w1       152875087.236
# mktcap|end_portfolio_wtd_market_cap/market_cap_filled|w2       147949982.518
# mktcap|end_portfolio_wtd_market_cap/market_cap_filled|w3       134312302.819
# mktcap|end_portfolio_wtd_market_cap/market_cap_filled|w4       132958821.573
# performance|crypto_net_gain/crypto_inflows/winsorized|w1      0.366748842669
# performance|crypto_net_gain/crypto_inflows/winsorized|w2      0.359529893475
# performance|crypto_net_gain/crypto_inflows/winsorized|w3      0.374820770218
# performance|crypto_net_gain/crypto_inflows/winsorized|w4      0.402374559598
# scenario|ideal/relative_cash_buys/pct|w1                        0.1620640478
# scenario|ideal/relative_cash_buys/pct|w2                      0.157432779674
# scenario|ideal/relative_cash_buys/pct|w3                      0.178726614521
# scenario|ideal/relative_cash_buys/pct|w4                      0.190744547092
# scenario|ideal/relative_combined/pct|w1                       0.261183401522
# scenario|ideal/relative_combined/pct|w2                       0.249498413112
# scenario|ideal/relative_combined/pct|w3                       0.300881656188
# ...
# cw_coin_trends|current_holders_in_profit|w2                        21055
# cw_coin_trends|current_holders_in_profit|w3                        21055
# cw_coin_trends|current_holders_in_profit|w4                        29296
# cw_coin_trends|current_holders_pct_of_lifetime|w1             0.90587693
# cw_coin_trends|current_holders_pct_of_lifetime|w2                      1
# cw_coin_trends|current_holders_pct_of_lifetime|w3                      1
# cw_coin_trends|current_holders_pct_of_lifetime|w4                      1
# cw_coin_trends|current_holders|w1                                 197309
# cw_coin_trends|current_holders|w2                                 197309
# cw_coin_trends|current_holders|w3                                 171661
# cw_coin_trends|current_holders|w4                                 171128
# cw_coin_trends|days_since_ath|w1                                    2310
# cw_coin_trends|days_since_ath|w2                                    2280
# cw_coin_trends|days_since_ath|w3                                    2250
# cw_coin_trends|days_since_ath|w4                                    2190
# cw_coin_trends|days_since_launch|w1                                 2542
# cw_coin_trends|days_since_launch|w2                                 2512
# cw_coin_trends|days_since_launch|w3                                 2482
# cw_coin_trends|days_since_launch|w4                                 2422
# cw_coin_trends|lifetime_holders|w1                                419694
# cw_coin_trends|lifetime_holders|w2                                416716
# cw_coin_trends|lifetime_holders|w3                                414453
# cw_coin_trends|lifetime_holders|w4                                409863
# cw_coin_trends|price_pct_of_ath|w1                                     1
# cw_coin_trends|price_pct_of_ath|w2                                     1
# cw_coin_trends|price_pct_of_ath|w3                                     1
# cw_coin_trends|price_pct_of_ath|w4                                     1
# cw_mktcap|end_portfolio_wtd_market_cap/market_cap_filled|w1    967754200
# cw_mktcap|end_portfolio_wtd_market_cap/market_cap_filled|w2   1105072000
# cw_mktcap|end_portfolio_wtd_market_cap/market_cap_filled|w3    936997570
# cw_mktcap|end_portfolio_wtd_market_cap/market_cap_unadj|w1     967754200
# cw_mktcap|end_portfolio_wtd_market_cap/market_cap_unadj|w2    1105072000
# cw_mktcap|end_portfolio_wtd_market_cap/market_cap_unadj|w3     936997570
# cw_performance|crypto_net_gain/crypto_inflows/winsorized|w1    3.6066434
# cw_performance|crypto_net_gain/crypto_inflows/winsorized|w2    3.7347875
# cw_performance|crypto_net_gain/crypto_inflows/winsorized|w3    4.9840655
# cw_performance|crypto_net_gain/crypto_inflows/winsorized|w4     5.573401
# cw_scenario|ideal/relative_cash_buys/pct_rank|w1              -0.3716923
# cw_scenario|ideal/relative_cash_buys/pct_rank|w2             -0.35000908
# cw_scenario|ideal/relative_cash_buys/pct_rank|w3             -0.25549993
# cw_scenario|ideal/relative_cash_buys/pct_rank|w4             -0.16406417
# cw_scenario|ideal/relative_cash_buys/pct|w1                           -0
# cw_scenario|ideal/relative_cash_buys/pct|w2                           -0
# cw_scenario|ideal/relative_cash_buys/pct|w3                           -0
# cw_scenario|ideal/relative_cash_buys/pct|w4                           -0
# cw_scenario|ideal/relative_combined/pct|w1                            -0
# cw_scenario|ideal/relative_combined/pct|w2                            -0
# cw_scenario|ideal/relative_combined/pct|w3                            -0
# cw_scenario|ideal/relative_combined/pct|w4                            -0
# cw_scenario|ideal/relative_net_gain_max_inv/winsorized|w1       9.515196
# cw_scenario|ideal/relative_net_gain_max_inv/winsorized|w2     13.6110935
# cw_scenario|ideal/relative_net_gain_max_inv/winsorized|w3       21.78245
# cw_scenario|ideal/relative_net_gain_max_inv/winsorized|w4       55.26052
# cw_scenario|net_perf/relative_cash_buys|w1                             1
# cw_scenario|net_perf/relative_cash_buys|w2                             1
# cw_scenario|net_perf/relative_cash_buys|w3                             1
# cw_scenario|net_perf/relative_cash_buys|w4                             1
# cw_scenario|net_perf/relative_net_gains|w1                             1
# cw_scenario|net_perf/relative_net_gains|w2                             1
# cw_scenario|net_perf/relative_net_gains|w3                             1
# cw_scenario|net_perf/relative_net_gains|w4                             1
# cw_scenario|worst/relative_net_gain_inflows/winsorized|w1       4.318249
# cw_scenario|worst/relative_net_gain_inflows/winsorized|w2      4.7347875
# cw_scenario|worst/relative_net_gain_inflows/winsorized|w3      5.3907256
# cw_scenario|worst/relative_net_gain_inflows/winsorized|w4      6.0627723
# cw_scenario|worst/relative_net_gains|w1                        1417198.5
# cw_scenario|worst/relative_net_gains|w2                        809519.25
# cw_scenario|worst/relative_net_gains|w3                        1179193.5
# cw_scenario|worst/relative_net_gains|w4                         616444.2
# cw_timing|price_sma_2/lag_15/sell_weighted|w1                 0.66883206
# cw_timing|price_sma_2/lag_15/sell_weighted|w2                 0.66204625
# cw_timing|price_sma_2/lag_15/sell_weighted|w3                 0.65932035
# cw_timing|price_sma_2/lag_15/sell_weighted|w4                 0.66242754
# cw_timing|price_sma_2/lead_30/sell_weighted|w3                 3.4200275
# cw_timing|price_sma_2/lead_30/sell_weighted|w4                  3.680955
# cw_timing|volume_sma_2/lead_7/buy_weighted|w1                  20.221624
# cw_timing|volume_sma_2/lead_7/buy_weighted|w2                   20.06088
# cw_timing|volume_sma_2/lead_7/buy_weighted|w3                  20.107294
# cw_timing|volume_sma_2/lead_7/buy_weighted|w4                  19.372604
# cw_trading|crypto_cash_sells|w1                                2138007.5
# cw_trading|crypto_cash_sells|w2                                  4721831
# cw_trading|crypto_inflows|w1                                     4352245
# cw_transfers|buys_coin_age/mean|w1                                  2542
# cw_transfers|buys_coin_age/mean|w2                                  2542
# cw_transfers|buys_coin_age/mean|w3                                  2512
# cw_transfers|buys_coin_age/mean|w4                                  2501
# cw_transfers|earlybird_ratio/mean|w1                                  20
# cw_transfers|earlybird_ratio/mean|w2                                  20
# cw_transfers|earlybird_ratio/mean|w3                                  20
# cw_transfers|earlybird_ratio/mean|w4                                  20
# cw_transfers|first_buy/mean_rank|w1                               369616
# cw_transfers|first_buy/mean_rank|w2                               361449
# cw_transfers|first_buy/mean_rank|w3                               358491
# cw_transfers|first_buy/mean_rank|w4                               357240
# cw_transfers|initial_hold_time/mean|w1                              1944
# cw_transfers|initial_hold_time/mean|w2                              1914
# cw_transfers|initial_hold_time/mean|w3                              1884
# cw_transfers|initial_hold_time/mean|w4                              1824
# macro|btc_mvrv_z_score_last|w1                                 2.5891676
# macro|btc_mvrv_z_score_last|w2                                 2.5891676
# macro|btc_mvrv_z_score_last|w3                                 1.5530591
# macro|btc_mvrv_z_score_last|w4                                 1.5530591
# macro|btc_mvrv_z_score_std|w1                                  1.6182517
# macro|btc_mvrv_z_score_std|w2                                  1.6227075
# macro|btc_mvrv_z_score_std|w3                                  1.6269664
# macro|btc_mvrv_z_score_std|w4                                  1.6352473
# macro|btc_price_std|w1                                         16177.482
# macro|btc_price_std|w2                                         15592.515
# macro|btc_price_std|w3                                         15272.105
# macro|btc_price_std|w4                                         14929.011
# macro|btc_vdd_multiple_last|w1                                    3.4398
# macro|btc_vdd_multiple_last|w2                                    2.6859
# macro|btc_vdd_multiple_last|w3                                    2.1235
# macro|btc_vdd_multiple_last|w4                                    1.4808
# macro|btc_vdd_multiple_std|w1                                  0.8412623
# macro|btc_vdd_multiple_std|w2                                   0.830585
# macro|btc_vdd_multiple_std|w3                                  0.8334991
# macro|btc_vdd_multiple_std|w4                                  0.8393398
# macro|global_market_cap_rsi_30_last|w1                        0.90599275
# macro|global_market_cap_rsi_30_last|w2                        0.90599275
# macro|global_market_cap_rsi_30_last|w3                        0.77102435
# macro|global_market_cap_rsi_30_last|w4                        0.77102435
# macro|global_market_cap_std|w1                              730109300000
# macro|global_market_cap_std|w2                              708429900000
# macro|global_market_cap_std|w3                              697917900000
# macro|global_market_cap_std|w4                              687204100000
# macro|gtrends_memecoin_us_std|w1                               1.2366079
# macro|gtrends_memecoin_us_std|w2                               0.7642583
# macro|gtrends_memecoin_us_std|w3                              0.69183314
# macro|gtrends_memecoin_us_std|w4                               0.5855227
# mktcap|end_portfolio_wtd_market_cap/market_cap_filled|w1       967754200
# mktcap|end_portfolio_wtd_market_cap/market_cap_filled|w2      1105072000
# mktcap|end_portfolio_wtd_market_cap/market_cap_filled|w3       936997570
# mktcap|end_portfolio_wtd_market_cap/market_cap_filled|w4      1189641000
# performance|crypto_net_gain/crypto_inflows/winsorized|w1       3.6721506
# performance|crypto_net_gain/crypto_inflows/winsorized|w2       4.0995297
# performance|crypto_net_gain/crypto_inflows/winsorized|w3       3.6115792
# performance|crypto_net_gain/crypto_inflows/winsorized|w4       3.7775273
# scenario|ideal/relative_cash_buys/pct|w1                              -0
# scenario|ideal/relative_cash_buys/pct|w2                              -0
# scenario|ideal/relative_cash_buys/pct|w3                              -0
# scenario|ideal/relative_cash_buys/pct|w4                              -0
# scenario|ideal/relative_combined/pct|w1                               -0
# scenario|ideal/relative_combined/pct|w2                               -0
# scenario|ideal/relative_combined/pct|w3                               -0
# scenario|ideal/relative_combined/pct|w4                               -0
# scenario|worst/relative_combined/pct|w1                        1.2545407
# scenario|worst/relative_combined/pct|w2                        1.3256435
# scenario|worst/relative_combined/pct|w3                         1.636559
# scenario|worst/relative_combined/pct|w4                         2.424936
# scenario|worst/relative_net_gains|w1                             3300601
# scenario|worst/relative_net_gains|w2                           3930834.5
# scenario|worst/relative_net_gains|w3                           4054766.2
# scenario|worst/relative_net_gains|w4                           3608193.5
# timing|btc_mvrv_z_score/lag_30/sell_weighted|w1               0.60468006
# timing|btc_mvrv_z_score/lag_30/sell_weighted|w2                0.6046801
# timing|btc_mvrv_z_score/lag_30/sell_weighted|w3                0.8585401
# timing|btc_mvrv_z_score/lag_30/sell_weighted|w4                 5.531604
# timing|btc_mvrv_z_score/lag_90/buy_weighted|w1                 0.7781988
# timing|btc_mvrv_z_score/lag_90/buy_weighted|w2                 0.7781988
# timing|btc_mvrv_z_score/lag_90/buy_weighted|w3                 1.1799793
# timing|btc_mvrv_z_score/lag_90/buy_weighted|w4                 16.655413
# timing|btc_mvrv_z_score/lag_90/sell_weighted|w1                0.7781988
# timing|btc_mvrv_z_score/lag_90/sell_weighted|w2                0.7781988
# timing|btc_mvrv_z_score/lag_90/sell_weighted|w3                1.1799793
# timing|btc_mvrv_z_score/lag_90/sell_weighted|w4                   9.8367
# timing|btc_mvrv_z_score/lead_90/buy_weighted|w4                 8.768128
# timing|gtrends_memecoin_us/lag_15/buy_weighted|w1              1.0000001
# timing|gtrends_memecoin_us/lag_15/buy_weighted|w2              1.0000001
# timing|gtrends_memecoin_us/lag_15/buy_weighted|w3              1.0000001
# timing|gtrends_memecoin_us/lag_15/buy_weighted|w4              1.0000001
# timing|gtrends_memecoin_us/lag_15/sell_weighted|w1             1.0000001
# timing|gtrends_memecoin_us/lag_15/sell_weighted|w2             1.0000001
# timing|gtrends_memecoin_us/lag_15/sell_weighted|w3             1.0000001
# timing|gtrends_memecoin_us/lag_15/sell_weighted|w4             1.0000001
# timing|price_sma_2/lag_15/buy_weighted|w1                     0.66883206
# timing|price_sma_2/lag_15/buy_weighted|w2                      0.6620463
# timing|price_sma_2/lag_15/buy_weighted|w3                     0.65932035
# timing|price_sma_2/lag_15/buy_weighted|w4                     0.66293365
# timing|volume_sma_2/lead_7/buy_weighted|w1                     20.221624
# timing|volume_sma_2/lead_7/buy_weighted|w2                     19.263718
# timing|volume_sma_2/lead_7/buy_weighted|w3                     17.884706
# timing|volume_sma_2/lead_7/buy_weighted|w4                     19.195597
# timing|volume_sma_2/lead_7/sell_weighted|w1                    20.221624
# timing|volume_sma_2/lead_7/sell_weighted|w2                     19.80355
# timing|volume_sma_2/lead_7/sell_weighted|w3                    20.452381
# timing|volume_sma_2/lead_7/sell_weighted|w4                    19.364122
# trading|crypto_cash_sells|w1                                    13310145
# trading|crypto_cash_sells|w2                                    11626191
# trading|crypto_inflows|all_windows                              21093756
# trading|total_volume|w1                                         18404942
# trading|total_volume|w2                                         14744569
# trading|unique_coins_traded|all_windows                              326
# transfers|buys_coin_age/mean|w1                                     2194
# transfers|buys_coin_age/mean|w2                                     2442
# transfers|buys_coin_age/mean|w3                                     2442
# transfers|buys_coin_age/mean|w4                                     2444
# transfers|earlybird_ratio/median|w1                                   20
# transfers|earlybird_ratio/median|w2                                   20
# transfers|earlybird_ratio/median|w3                                   20
# transfers|earlybird_ratio/median|w4                                   20
# transfers|first_buy/mean_rank|w1                               314237.34
# transfers|first_buy/mean_rank|w2                                  353087
# transfers|first_buy/mean_rank|w3                                  353087
# transfers|first_buy/mean_rank|w4                                  362728
# transfers|initial_hold_time/median|w1                             1042.5
# transfers|initial_hold_time/median|w2                             1834.5
# transfers|initial_hold_time/median|w3                             1804.5
# transfers|initial_hold_time/median|w4                               1997
# transfers|later_buyers/median|w1                                  222235
# transfers|later_buyers/median|w2                                  311016
# transfers|later_buyers/median|w3                                  269735
# transfers|later_buyers/median|w4                                  305638

# %% [markdown]
# #### upload

# %%
concat_uris = workflow_orch.upload_concatenated_training_data(
    overwrite_existing=True,
    # splits=['val']
)

# %% [markdown]
# #### train

# %%
[importlib.reload(module) for module in modules]
sage_wallets_config = yaml.safe_load(Path('../config/sage_wallets_config.yaml').read_text(encoding='utf-8'))
sage_wallets_modeling_config = yaml.safe_load(Path('../config/sage_wallets_modeling_config.yaml').read_text(encoding='utf-8'))


workflow_orch = wo.WalletWorkflowOrchestrator(
    sage_wallets_config,
    sage_wallets_modeling_config
)
concat_uris = workflow_orch.upload_concatenated_training_data(overwrite_existing=False)
modeling_results = workflow_orch.train_concatenated_offsets_model(concat_uris)

# %% [markdown]
# #### evaluate HPO outcomes

# %%
player = u.AmbientPlayer()
player.stop_all_players()

# %%
[importlib.reload(module) for module in modules]
sage_wallets_config = yaml.safe_load(Path('../config/sage_wallets_config.yaml').read_text(encoding='utf-8'))
sage_wallets_modeling_config = yaml.safe_load(Path('../config/sage_wallets_modeling_config.yaml').read_text(encoding='utf-8'))


workflow_orch = wo.WalletWorkflowOrchestrator(
    sage_wallets_config,
    sage_wallets_modeling_config
)
workflow_orch.get_hpo_results('concat')

# %%
# Get the best hyperparameters
best_params = modeling_results['tuner'].best_training_job()

# Or more detailed info
analytics = modeling_results['tuner'].analytics()
best_job_df = analytics.dataframe()

# The best parameters are in the hyperparameters columns
print(best_params)
print(best_job_df.loc[0, ['eta', 'max_depth', 'subsample', 'FinalObjectiveValue']])

# %% [markdown]
# #### load existing model

# %%
[importlib.reload(module) for module in modules]
sage_wallets_config = yaml.safe_load(Path('../config/sage_wallets_config.yaml').read_text(encoding='utf-8'))
sage_wallets_modeling_config = yaml.safe_load(Path('../config/sage_wallets_modeling_config.yaml').read_text(encoding='utf-8'))

# Load S3 URIs
workflow_orch = wo.WalletWorkflowOrchestrator(sage_wallets_config,sage_wallets_modeling_config)
s3_uris = workflow_orch.retrieve_training_data_uris(['concat'])

# Create modeler with 'concat' as the date_suffix
concat_modeler = wm.WalletModeler(
    wallets_config=sage_wallets_config,
    modeling_config=sage_wallets_modeling_config,
    date_suffix='concat',
    s3_uris=s3_uris,
    override_approvals=None
)

# Step 2: Load the existing concatenated model
model_info = concat_modeler.load_existing_model(modeling_results['model_uri'])

# %% [markdown]
# #### predict

# %%
[importlib.reload(module) for module in modules]
sage_wallets_config = yaml.safe_load(Path('../config/sage_wallets_config.yaml').read_text(encoding='utf-8'))
sage_wallets_modeling_config = yaml.safe_load(Path('../config/sage_wallets_modeling_config.yaml').read_text(encoding='utf-8'))

pred_results = concat_modeler.batch_predict_test_and_val()

# %% [markdown]
# #### evaluate

# %%
model_info['model_uri']

# %%
[importlib.reload(module) for module in modules]
sage_wallets_config = yaml.safe_load(Path('../config/sage_wallets_config.yaml').read_text(encoding='utf-8'))
sage_wallets_modeling_config = yaml.safe_load(Path('../config/sage_wallets_modeling_config.yaml').read_text(encoding='utf-8'))

date_suffix = 'concat'
y_test_pred = sime.load_bt_sagemaker_predictions('test', sage_wallets_config, date_suffix)
y_test      = sime.load_concatenated_y('test', sage_wallets_config, sage_wallets_modeling_config)
y_val_pred  = sime.load_bt_sagemaker_predictions('val', sage_wallets_config, date_suffix)
y_val       = sime.load_concatenated_y('val', sage_wallets_config, sage_wallets_modeling_config)


target_var = sage_wallets_modeling_config['target']['target_var']
y_test.columns = [target_var]
y_val.columns = [target_var]

# Single function call for complete evaluation
evaluator = sime.create_concatenated_sagemaker_evaluator(
    sage_wallets_config,
    sage_wallets_modeling_config,
    model_info['model_uri'],
    y_test_pred,
    y_test,
    y_val_pred,
    y_val,
)

# %%
# auc pr 0.4 all history
logger.info(modeling_results['model_uri'])
evaluator.summary_report()
evaluator.plot_wallet_evaluation()
# u.notify('soft_twinkle_musical')

# %%
# auc pr 0.4 all history
logger.info(modeling_results['model_uri'])
evaluator.summary_report()
evaluator.plot_wallet_evaluation()
# u.notify('soft_twinkle_musical')

# %%
# auc pr 0.4 mktcap 20M-4B
logger.info(modeling_results['model_uri'])
evaluator.summary_report()
evaluator.plot_wallet_evaluation()
# u.notify('soft_twinkle_musical')

# %%
# auc pr mktcap 20M-4B, z score 1.5
evaluator.summary_report()
evaluator.plot_wallet_evaluation()
u.notify('soft_twinkle_musical')

# %%
# auc pr mktcap 20M-4B, inflows $5k
evaluator.summary_report()
evaluator.plot_wallet_evaluation()
u.notify('soft_twinkle_musical')

# %%
# auc pr mktcap 20M-4B, z score 1.5
evaluator.summary_report()
evaluator.plot_wallet_evaluation()
u.notify('soft_twinkle_musical')

# %% [markdown]
# ## Temporal cv model

# %%
[importlib.reload(module) for module in modules]
sage_wallets_config = yaml.safe_load(Path('../config/sage_wallets_config.yaml').read_text(encoding='utf-8'))
sage_wallets_modeling_config = yaml.safe_load(Path('../config/sage_wallets_modeling_config.yaml').read_text(encoding='utf-8'))


date_suffixes = [
    '231008',
    '231107',
    '240306',
    '241101',
    '250301'
]
workflow_orch = wo.WalletWorkflowOrchestrator(sage_wallets_config,sage_wallets_modeling_config)
workflow_orch.load_all_training_data(date_suffixes)
s3_uris = workflow_orch.retrieve_training_data_uris(date_suffixes)

# %%
sm.train_temporal_cv_script_model(sage_wallets_config,sage_wallets_modeling_config,cv_s3_uri)

# %% [markdown]
# ## Single Model Sequence

# %% [markdown]
# ### Train Single Model

# %% [markdown]
# #### retrieve file uris

# %%
[importlib.reload(module) for module in modules]
sage_wallets_config = yaml.safe_load(Path('../config/sage_wallets_config.yaml').read_text(encoding='utf-8'))
sage_wallets_modeling_config = yaml.safe_load(Path('../config/sage_wallets_modeling_config.yaml').read_text(encoding='utf-8'))

workflow_orch = wo.WalletWorkflowOrchestrator(sage_wallets_config,sage_wallets_modeling_config)



date_suffixes = [
    '231008',
    '231107',
    '240306',
    '250301'
]

# Generate URIs for specific dates without any prior setup
s3_uris = workflow_orch.retrieve_training_data_uris(date_suffixes)
s3_uris

# %% [markdown]
# #### train model

# %%
[importlib.reload(module) for module in modules]
sage_wallets_config = yaml.safe_load(Path('../config/sage_wallets_config.yaml').read_text(encoding='utf-8'))
sage_wallets_modeling_config = yaml.safe_load(Path('../config/sage_wallets_modeling_config.yaml').read_text(encoding='utf-8'))

date_suffix = '231008'

modeler = wm.WalletModeler(
    sage_wallets_config,
    sage_wallets_modeling_config,
    date_suffix,
    s3_uris
)

# %%
modeling_results = modeler.train_model()

# %% [markdown]
# ### Score validation set

# %% [markdown]
# #### get existing model uri

# %%
[importlib.reload(module) for module in modules]
sage_wallets_config = yaml.safe_load(Path('../config/sage_wallets_config.yaml').read_text(encoding='utf-8'))
sage_wallets_modeling_config = yaml.safe_load(Path('../config/sage_wallets_modeling_config.yaml').read_text(encoding='utf-8'))



date_suffix = '231008'

# Generate URIs for specific dates without any prior setup
workflow_orch = wo.WalletWorkflowOrchestrator(sage_wallets_config,sage_wallets_modeling_config)
s3_uris = workflow_orch.retrieve_training_data_uris([date_suffix])

# Launch modeler
modeler = wm.WalletModeler(
    sage_wallets_config,
    sage_wallets_modeling_config,
    date_suffix,
    s3_uris
)


model_metadata = modeler.load_existing_model()

# %% [markdown]
# #### predict with batch transform

# %%
transform_results = modeler.predict_with_batch_transform('val')

# %%
transform_results = modeler.predict_with_batch_transform('test')

# %% [markdown]
# ### Predict Using Endpoints

# %% [markdown]
# #### deploy endpoint for predictions

# %%
modeler.list_active_endpoints()

# %%
modeler.deploy_endpoint()

# %% [markdown]
# #### load and preprocess test/val dfs

# %%
x_test = pd.read_parquet(
    Path("../s3_uploads/wallet_training_data_queue") /
    sage_wallets_config['training_data']['local_directory'] /
    f"x_test_{date_suffix}.parquet"
)
x_val = pd.read_parquet(
    Path("../s3_uploads/wallet_training_data_queue") /
    sage_wallets_config['training_data']['local_directory'] /
    f"x_val_{date_suffix}.parquet"
)

# %%
preprocessor = SageWalletsPreprocessor(sage_wallets_config)
x_test_processed = preprocessor.preprocess_x_df(x_test)
x_val_processed = preprocessor.preprocess_x_df(x_val)

logger.info(f"Preprocessed X_test {x_test_processed.shape} and "
            f"X_val {x_val_processed.shape}.")

# %% [markdown]
# #### predict

# %%
y_test_pred = modeler.predict_using_endpoint(x_test_processed, 'test')
y_val_pred = modeler.predict_using_endpoint(x_val_processed, 'val')

# %% [markdown]
# #### delete all endpoints

# %%
modeler.delete_all_endpoints()

# %%
modeler.list_active_endpoints()
modeler.list_all_endpoints()

# %% [markdown]
# ## Script model training

# %%
[importlib.reload(module) for module in modules]
sage_wallets_config = yaml.safe_load(Path('../config/sage_wallets_config.yaml').read_text(encoding='utf-8'))
sage_wallets_modeling_config = yaml.safe_load(Path('../config/sage_wallets_modeling_config.yaml').read_text(encoding='utf-8'))


date_suffixes = [
    '231008',
    '231107',
    '240306',
    '250301'
]

date_suffix = '231008'


workflow_orch = wo.WalletWorkflowOrchestrator(sage_wallets_config,sage_wallets_modeling_config)
workflow_orch.load_all_training_data(date_suffixes)
s3_uris = workflow_orch.retrieve_training_data_uris(date_suffixes)

# %%
[importlib.reload(module) for module in modules]
sage_wallets_config = yaml.safe_load(Path('../config/sage_wallets_config.yaml').read_text(encoding='utf-8'))
sage_wallets_modeling_config = yaml.safe_load(Path('../config/sage_wallets_modeling_config.yaml').read_text(encoding='utf-8'))

date_suffix = '231008'

modeler = wm.WalletModeler(
    sage_wallets_config,
    sage_wallets_modeling_config,
    date_suffix,
    s3_uris
)

# %%
sm.train_single_period_script_model(
    sage_wallets_config,
    sage_wallets_modeling_config,
    date_suffix,
    s3_uris
)

# %%
from sagemaker.session import Session
from sagemaker.xgboost.estimator import XGBoost
from sagemaker.tuner import HyperparameterTuner, ContinuousParameter, IntegerParameter

s3_data = {
    "train":      s3_uris[date_suffix]['train'],
    "validation": s3_uris[date_suffix]['val']
}
model_output_path = (f"s3://wallet-script-models/model-outputs")

estimator = XGBoost(
    entry_point         = "script_mode_modeler.py",     # path relative to notebook
    source_dir          = "../src/script_modeling/",    # folder that holds the script
    base_job_name       = "dda-922-v4",                 # uploaded and immutable script version
    framework_version   = sage_wallets_modeling_config['framework']['version'],
    role                = sage_wallets_config['aws']['modeler_arn'],
    instance_type       = sage_wallets_modeling_config['metaparams']['instance_type'],
    instance_count      = sage_wallets_modeling_config['metaparams']['instance_count'],
    output_path         = model_output_path,
    hyperparameters = {
        "eta": 0.1,
        "max_depth": 6,
        "subsample": 1.0,
        "num_boost_round": 50,            # small for a smoke-test
        "early_stopping_rounds": 10
    },
    # metric_definitions=[                  # regex must match the print line
    #     {"Name": "cv_auc_pr", "Regex": "validation:cv_auc_pr=(.*)"}
    # ],
)

# one-shot fit (no tuning yet)
estimator.fit(s3_data, logs="All")

# %% [markdown]
# # Model Evaluation

# %% [markdown]
# ### Analyze predictions

# %%
[importlib.reload(module) for module in modules]
sage_wallets_config = yaml.safe_load(Path('../config/sage_wallets_config.yaml').read_text(encoding='utf-8'))
sage_wallets_modeling_config = yaml.safe_load(Path('../config/sage_wallets_modeling_config.yaml').read_text(encoding='utf-8'))


date_suffixes = [
    '231008',
    # '240306'
]
date_suffix = date_suffixes[0]

# %%
y_test_pred = sime.load_bt_sagemaker_predictions('test', sage_wallets_config, date_suffix)
y_val_pred = sime.load_bt_sagemaker_predictions('val', sage_wallets_config, date_suffix)

# %%
# Single function call for complete evaluation
evaluator = sime.run_sagemaker_evaluation(
    sage_wallets_config,
    sage_wallets_modeling_config,
    date_suffix,
    y_test_pred,
    y_val_pred
)

# %%
evaluator.y_validation

# %%
evaluator.y_validation_pred_proba

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

fpr, tpr, _ = roc_curve(evaluator.y_validation, evaluator.y_validation_pred_proba)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (AUC = {roc_auc:.3f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--', label='Random classifier')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve - Validation Set')
plt.legend(loc="lower right")
plt.grid(True, alpha=0.3)
plt.show()

# %%
evaluator.summary_report()
evaluator.plot_wallet_evaluation()

# %%
def load_sagemaker_predictions(
    data_type: str,
    sage_wallets_config: dict,
    sage_wallets_modeling_config: dict,
    date_suffix: str
) -> tuple[pd.Series, pd.Series]:
    """
    Load SageMaker predictions and corresponding actuals for a given data type.

    Params:
    - data_type (str): Either 'test' or 'val'
    - sage_wallets_config (dict): Configuration for training data paths
    - sage_wallets_modeling_config (dict): Configuration for model parameters
    - date_suffix (str): Date suffix for file naming

    Returns:
    - tuple: (predictions_series, actuals_series) with aligned indices
    """
    # Load predictions
    pred_path = Path(sage_wallets_modeling_config['metaparams']['endpoint_preds_dir']) / \
                f"endpoint_y_pred_{data_type}_{sage_wallets_config['training_data']['local_directory']}_{date_suffix}.csv"
    pred_df = pd.read_csv(pred_path)

    if 'score' not in pred_df.columns:
        raise ValueError(f"SageMaker predictions are missing the 'score' column. "
                        f"Available columns: {pred_df.columns}")
    pred_series = pred_df['score']

    # Load actuals
    training_data_path = (
        Path(f"../s3_uploads") / "wallet_training_data_queue" /
        f"{sage_wallets_config['training_data']['local_directory']}"
    )
    actuals_path = training_data_path / f"y_{data_type}_{date_suffix}.parquet"
    actuals_df = pd.read_parquet(actuals_path)

    if len(actuals_df.columns) > 1:
        raise ValueError(f"Found unexpected columns in y_{data_type}_df. "
                        f"Expected 1 column, found {actuals_df.columns}.")
    actuals_series = actuals_df.iloc[:, 0]

    # Validate lengths and align indices
    if len(pred_series) != len(actuals_series):
        raise ValueError(f"Length of y_{data_type}_pred ({len(pred_series)}) does "
                        f"not match length of y_{data_type}_true ({len(actuals_series)}).")

    pred_series.index = actuals_series.index

    return pred_series, actuals_series

# %%
# Load predictions and actuals
y_test_pred_series, y_test_true_series = load_sagemaker_predictions(
    'test', sage_wallets_config, sage_wallets_modeling_config, date_suffix
)
y_val_pred_series, y_val_true_series = load_sagemaker_predictions(
    'val', sage_wallets_config, sage_wallets_modeling_config, date_suffix
)

# Load remaining training data
training_data_path = (
    Path(f"../s3_uploads") / "wallet_training_data_queue" /
    f"{sage_wallets_config['training_data']['local_directory']}"
)
X_train = pd.read_parquet(training_data_path / f"x_train_{date_suffix}.parquet")
y_train = pd.read_parquet(training_data_path / f"y_train_{date_suffix}.parquet")
X_test = pd.read_parquet(training_data_path / f"x_test_{date_suffix}.parquet")
X_val = pd.read_parquet(training_data_path / f"x_val_{date_suffix}.parquet")

# Identify target variable and model type
target_variable = y_val_true_series.name or y_train.columns[0]
objective = sage_wallets_modeling_config['training']['hyperparameters']['objective']
model_type = 'regression' if objective[:3] == 'reg' else 'unknown'

# %%
# Create model_id and modeling_config
model_id = f"sagemaker_{sage_wallets_config['training_data']['local_directory']}_{date_suffix}"

modeling_config = {
    'target_variable': target_variable,
    'model_type': model_type,
    'returns_winsorization': 0.005,  # Default for winsorizing returns
    'training_data': {
        'modeling_period_duration': 30  # Default performance window
    },
    'sagemaker_metadata': {
        'objective': objective,
        'local_directory': sage_wallets_config['training_data']['local_directory'],
        'date_suffix': date_suffix
    }
}

# Create minimal wallet_model_results for SageMaker evaluation
wallet_model_results = {
    'model_id': model_id,
    'modeling_config': modeling_config,
    'model_type': model_type,

    # Training data
    'X_train': X_train,
    'X_test': X_test,
    'y_train': y_train,
    'y_test': y_test_true_series,
    'y_pred': y_test_pred_series,
    'training_cohort_pred': None,
    'training_cohort_actuals': None,

    # Validation data
    'X_validation': X_val,
    'y_validation': y_val_true_series,
    'y_validation_pred': y_val_pred_series,
    'validation_target_vars_df': None,

    # Fixed mock pipeline
    'pipeline': type('MockPipeline', (), {
        'named_steps': {'estimator': type('MockModel', (), {
            'get_params': lambda self: {'objective': objective}  # Accept self argument
        })()},
        '__getitem__': lambda self, key: type('MockTransformer', (), {
            'transform': lambda self, X: X  # Accept self argument
        })()
    })()
}

# Create evaluator
wallet_evaluator = wime.RegressorEvaluator(wallet_model_results)

# Run basic evaluation
wallet_evaluator.summary_report()
wallet_evaluator.plot_wallet_evaluation()

# %%
target_variable
